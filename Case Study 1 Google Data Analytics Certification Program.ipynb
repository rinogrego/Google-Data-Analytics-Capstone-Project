# %% [markdown]
# # Google Data Analytics Capstone Project
# ## Case Study 1 - How Does a Bike-Share Navigate Speedy Success?
#
# ### Capstone Project Description
# In this case study, you will perform data analysis for a **fictional** bike-share company in order to help them attract more riders. Along the way, you will perform numerous real-world tasks of a junior data analyst by following the steps of the data analysis process: **Ask, Prepare, Process, Analyze, Share, and Act**. By the time you are done, you will have a portfolio-ready case study to help you demonstrate your knowledge and skills to potential employers!
#
# [Course Section](https://www.coursera.org/learn/google-data-analytics-capstone/supplement/7PGIT/case-study-1-how-does-a-bike-share-navigate-speedy-success)
#
# [PDF](https://d3c33hcgiwev3.cloudfront.net/aacF81H_TsWnBfNR_x7FIg_36299b28fa0c4a5aba836111daad12f1_DAC8-Case-Study-1.pdf?Expires=1646524800&Signature=BJ7qCcmNP5tUM1JDULEDtgNZusWdgrO7sFQUunwd3DuQ~OFGgsmFbmFnAxmYgrkoRckUJBSoDjwv5z~DsXt7VwWf5IytuQLU0n08HRR1dDYA76diIbW6TSbTEhQy6IpTAkgdqSK7AY7-b1~1tr6oPWExq3bz78gG2VFKzGH7~CU_&Key-Pair-Id=APKAJLTNE6QMUY6HBC5A) for project details.

# %% [markdown]
# ### Personal Note Regarding This Project
#
# Google Data Analytics Certification Program not only give students SQL, Tableau, and Spreadsheet materials but also a course dedicated to basics of R programming language. Because of that the students are expected to do this project in either in R, SQL, Tableau, or Spreadsheet/Excel. But personally, I prefer to do this project in Python because that's my comfort area and the one I want to focus on keep improving on. That's why Python is used to finish this project.

# %% [markdown]
# ## Steps
# Google Data Analytics Certification Program is created based on the 6 steps of data analysis process:
# - Ask
# - Prepare
# - Process
# - Analyze
# - Share
# - Act
#
# These 6 steps are the foundation of the program. Each step have their own course in the program dedicated to learn about them. In the capstone project, the students are expected to use their knowledge and skills learned throughout the program to solve business problems. By applying the steps that have been (repeatedly) mentioned to the students, we are expected to be able to use them to solve any data analytic projects.
# I will try to imitate those 6 steps in order to finish this capstone project.

# %% [markdown]
# ### Expected Report after answering business questions:
# 1. A clear statement of the business task
# 2. A description of all data sources used
# 3. Documentation of any cleaning or manipulation of data
# 4. A summary of your analysis
# 5. Supporting visualizations and key findings
# 6. Your top three recommendations based on your analysis

# %% [markdown]
# ## Step 1: Ask

# %% [markdown]
# There are 3 questions that have been given in the project detail that will guide the future marketing program:
# 1. How do annual members and casual riders use Cyclistic bikes differently?
# 2. Why would casual riders buy Cyclistic annual memberships?
# 3. How can Cyclistic use digital media to influence casual riders to become members?
#
# **The project detail asks the students to answer the first question.**

# %% [markdown]
# ### Question 1: How do annual members and casual riders use Cyclistic bikes differently?

# %% [markdown]
# #### Guiding Questions:
# 1. What is the problem you are trying to solve?
# 2. How can your insights drive business decisions?
#
# #### Key Tasks
# 1. Identify the business task
# 2. Consider key stakeholders
#
# #### My Answer to the guiding questions and key tasks:
# 1. We are trying to know what makes annual members and casual riders use Cyclistic bikes differently.
# 2. The difference in the way annual members and casual riders use Cyclistic bikes may be a key to turn casual riders into annual members.
# 3. The business task is that we turn casual riders into annual members.
# 4. Key stakeholders are the director of marketing and the executive team.

# %% [markdown]
# ## Step 2: Prepare

# %% [markdown]
# In this step we are going to process the data that we need in order to answer business questions.
#
# Description from the project detail:
#
# You will use Cyclistic’s historical trip data to analyze and identify trends. [Download the previous 12 months of Cyclistic trip data here](https://divvy-tripdata.s3.amazonaws.com/index.html). (Note: The datasets have a different name because Cyclistic is a fictional company. For the purposes of this case study, the datasets are appropriate and will enable you to answer the business questions. The data has been made available by Motivate International Inc. under this [license](https://www.divvybikes.com/data-license-agreement).) This is public data that you can use to explore how different customer types are using Cyclistic bikes. But note that data-privacy issues prohibit you from using riders’ personally identifiable information. This means that you won’t be able to connect pass purchases to credit card numbers to determine if casual riders live in the Cyclistic service area or if they have purchased multiple single passes.
#
# **The date I started this project is 4th of March, 2022. So I will only download the dataset 12 months prior to that date.**

# %% [markdown]
# #### Guiding questions
# 1. Where is your data located?
# 2. How is the data organized?
# 3. Are there issues with bias or credibility in this data? [Does your data ROCCC](https://www.coursera.org/learn/data-preparation/lecture/lHirM/what-is-bad-data)?
# 4. How are you addressing licensing, privacy, security, and accessibility?
# 5. How did you verify the data’s integrity?
# 6. How does it help you answer your question?
# 7. Are there any problems with the data?
#
# #### Key tasks
# 1. Download data and store it appropriately.
# 2. Identify how it’s organized.
# 3. Sort and filter the data.
# 4. Determine the credibility of the data.

# %% [markdown]
# #### My Answer to the guiding questions and key tasks:
# ##### Answered after the prepare phase is done
# 1. The data is located in the folder with the name 'dataset'. The location of the folder is in the same level as the location of this .ipynb file in the directory. The __MACOSX folder in the dataset is removed.
#        ProjectFolder
#         |-dataset
#         |-Case Study 1 Google Data Analytics Certification Program.ipynb
#         |-DAC8-Case-Study-1.pdf
# 2. The data is organized with the name format: 'YYYYMM-divvy-tripdata'. Each .csv file contains data for the month specified in the name of the file.
# 3. ROCCC stands for: Reliable, Original, Comprehensive, Current, and Cited.
#     - Reliable is when the data is not biased (all kinds of bias), incomplete, or contain misinformation. It could also be data that are not graphically or visually misleading.
#     - Original is when the data can be located. In this case the data is clearly owned by divvybikes and can be taken from their official website.
#     - Comprehensive is when the data doesn't contain human error and can answer business questions.
#     - Current is when the data is up-to-date. Since we take the last 12 months of the data, then the data is reflects the up-to-date data.
#     - Cited is when the data that we use is cited. We have given the source of the data that we use in this project [in this link](https://divvy-tripdata.s3.amazonaws.com/index.html).
# 4. The licensing agreement can be seen [here](https://www.divvybikes.com/data-license-agreement).
# 5. I am not sure I will be ensuring data integrity for this project but at least I think the consistency could be maintained by checking the data type and the data format (like length). For python, applying lambda function and checking each value of a column is one way that I can think of.
# 6. The data can provide insights on things that cannot be seen normally.
# 7. Null values and minus difference of time spend when using the service.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
DATA_PATH = './dataset/'

dataframes = {}

import os

# saving all 12 .csv files to 1 dictionary containing dataframes
for filename in os.listdir(DATA_PATH):
    print('Processing', filename, end='\r')
    year = filename[:4]
    month = filename[4:6]
    dataframe_name = f"{month}-{year}"
    dataframes[dataframe_name] = pd.read_csv(f'{DATA_PATH}/{filename}')
    print(dataframe_name, 'process finished!                \n', end='\r')

# preview
dataframes["03-2021"].head()
# Out:
# 03-2021 process finished!
# 04-2021 process finished!
# 05-2021 process finished!
# 06-2021 process finished!
# 07-2021 process finished!
# 08-2021 process finished!
# 09-2021 process finished!
# 10-2021 process finished!
# 11-2021 process finished!
# 12-2021 process finished!
# 01-2022 process finished!
# 02-2022 process finished!
# ne-clea process finished!
#             ride_id rideable_type           started_at             ended_at  \
# 0  CFA86D4455AA1030  classic_bike  2021-03-16 08:32:30  2021-03-16 08:36:34
# 1  30D9DC61227D1AF3  classic_bike  2021-03-28 01:26:28  2021-03-28 01:36:55
# 2  846D87A15682A284  classic_bike  2021-03-11 21:17:29  2021-03-11 21:33:53
# 3  994D05AA75A168F2  classic_bike  2021-03-11 13:26:42  2021-03-11 13:55:41
# 4  DF7464FBE92D8308  classic_bike  2021-03-21 09:09:37  2021-03-21 09:27:33
#
#              start_station_name start_station_id  \
# 0  Humboldt Blvd & Armitage Ave            15651
# 1  Humboldt Blvd & Armitage Ave            15651
# 2         Shields Ave & 28th Pl            15443
# 3   Winthrop Ave & Lawrence Ave     TA1308000021
# 4      Glenwood Ave & Touhy Ave              525
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# 0              Stave St & Armitage Ave          13266  41.917513 -87.701809
# 1  Central Park Ave & Bloomingdale Ave          18017  41.917513 -87.701809
# 2                 Halsted St & 35th St   TA1308000043  41.842733 -87.635491
# 3               Broadway & Sheridan Rd          13323  41.968812 -87.657659
# 4            Chicago Ave & Sheridan Rd           E008  42.012701 -87.666058
#
#      end_lat    end_lng member_casual
# 0  41.917741 -87.691392        casual
# 1  41.914166 -87.716755        casual
# 2  41.830661 -87.647172        casual
# 3  41.952833 -87.649993        casual
# 4  42.050491 -87.677821        casual

# %%
# combine all the 12 data
dataframes['All'] = pd.concat(list(dataframes.values()))
dataframes['All'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10298211 entries, 0 to 4630224
# Data columns (total 18 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  Unnamed: 0          float64
#  14  clean_started_at    object
#  15  clean_ended_at      object
#  16  time_spent          object
#  17  distance_in_km      float64
# dtypes: float64(6), object(12)
# memory usage: 1.5+ GB

# %%
rows = [len(df) for df in dataframes.values()]
x = rows[0:12]
sum(x) == rows[-1]
# Out:
# False

# %% [markdown]
# It can be seen that the total rows of all of our data reach **56 millions**

# %% [markdown]
# Since we would like to know the difference in how do annual members and casual riders use Cyclistic bikes then we will query the data of both types of users. But before we split the data, we need to make sure that there are only 2 values in member_casual column.

# %%
df_all = dataframes['All'].copy()
df_all.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'Unnamed: 0', 'clean_started_at', 'clean_ended_at',
#        'time_spent', 'distance_in_km'],
#       dtype='object')

# %% [markdown]
# Checking all the columns with discrete values

# %%
list(set(df_all['member_casual'].values))
# Out:
# ['member', 'casual']

# %%
list(set(df_all['rideable_type'].values))
# Out:
# ['electric_bike', 'docked_bike', 'classic_bike']

# %%
list(set(df_all['start_station_name'].values))
# Out:
# [nan,
#  'Wabash Ave & Roosevelt Rd',
#  'Kostner Ave & Wrightwood Ave',
#  'Aberdeen St & Randolph St',
#  'Elizabeth St & 47th St',
#  'Lake Shore Dr & Diversey Pkwy',
#  'Mies van der Rohe Way & Chestnut St',
#  'St. Louis Ave & Fullerton Ave',
#  'Shedd Aquarium',
#  'Southport Ave & Clark St',
#  'Western Ave & Grace St',
#  'Princeton Ave & 47th St',
#  'Lincoln Ave & Fullerton Ave',
#  'Perry Ave & 69th St',
#  'Central Park Ave & North Ave',
#  'Stockton Dr & Wrightwood Ave',
#  'Halsted St & 37th St',
#  'Southport Ave & Irving Park Rd',
#  'Warren Park East',
#  'California Ave & 36th St',
#  'Milwaukee Ave & Cuyler Ave',
#  'Broadway & Belmont Ave',
#  'Humboldt Blvd & Armitage Ave',
#  'Pulaski Rd & Eddy St (Temp)',
#  'Elston Ave & George St',
#  'Dorchester Ave & 49th St',
#  'Latrobe Ave & Chicago Ave',
#  'Ashland Ave & 13th St',
#  'N Sheffield Ave & W Wellington Ave',
#  'Central Park Ave & Ogden Ave',
#  'Washtenaw Ave & Lawrence Ave',
#  'Halsted St & 69th St',
#  'Troy St & Elston Ave',
#  'Hoyne Ave & 34th St',
#  'Kildare Ave & Chicago Ave',
#  'Lockwood Ave & Wrightwood Ave',
#  'Adler Planetarium',
#  'Houston Ave & 92nd St',
#  'Larrabee St & Division St',
#  'State St & Randolph St',
#  'Hamlin Ave & 62nd Pl',
#  'Clark St & Newport St',
#  'Richmond St & 59th St',
#  'Campbell Ave & Montrose Ave',
#  'Rockwell St & Cermak Rd',
#  'Kedzie Ave & 45th St',
#  'Nordica & Medill',
#  'Stetson Ave & South Water St',
#  'Damen Ave & Madison St',
#  'Kedzie Ave & Foster Ave',
#  'Archer (Damen) Ave & 37th St',
#  'California Ave & Altgeld St',
#  'Artesian Ave & Hubbard St',
#  'W Washington Blvd & N Peoria St',
#  'Roscoe & Harlem',
#  'Wells St & Hubbard St',
#  'Streeter Dr & Grand Ave',
#  'Wentworth Ave & 33rd St',
#  'California Ave & Division St',
#  'Western Ave & Roscoe St',
#  'Western Ave & Granville Ave',
#  'Torrence Ave & 126th Pl',
#  'Avenue L & 114th St',
#  'Central Ave & Parker Ave',
#  'Oketo Ave & Addison St',
#  'Shabbona Park',
#  'Damen Ave & Thomas St (Augusta Blvd)',
#  'Hale Ave & 107th St',
#  'Constance Ave & 95th St',
#  'Burnham Harbor',
#  'Damen Ave & 59th St',
#  'Elston Ave & Cortland St',
#  'Damen Ave & Division St',
#  'Washtenaw Ave & Peterson Ave',
#  'South Shore Dr & 71st St',
#  'Greenview Ave & Diversey Pkwy',
#  'Wells St & Elm St',
#  'Pine Grove Ave & Waveland Ave',
#  'Dearborn St & Van Buren St',
#  'Keystone Ave & Fullerton Ave',
#  'Broadway & Ridge Ave',
#  '63rd St Beach',
#  'Indiana Ave & 31st St',
#  'Fort Dearborn Dr & 31st St',
#  'Laramie Ave & Gladys Ave',
#  'Kildare Ave & 55th St',
#  'Dodge Ave & Church St',
#  'Manor Ave & Leland Ave',
#  'Smith Park',
#  'Ashland Ave & Wrightwood Ave',
#  'Halsted St & 18th St (Temp)',
#  'Christiana Ave & Lawrence Ave',
#  'Valli Produce - Evanston Plaza',
#  'Ashland Ave & Pershing Rd',
#  'DuSable Lake Shore Dr & Monroe St',
#  'Kedzie Ave & George St',
#  'Cottage Grove Ave & 83rd St',
#  'Clark St & Chicago Ave',
#  'State St & Kinzie St',
#  'Halsted St & 21st St',
#  'Wells St & Evergreen Ave',
#  'Paulina St & Montrose Ave',
#  'Central Ave & Lake St',
#  'Western Ave & 24th St',
#  'Lake Park Ave & 35th St',
#  'Kildare Ave & 26th St',
#  'Seeley Ave & Roscoe St',
#  'LaSalle St & Washington St',
#  'Elizabeth St & 92nd St',
#  'S Wentworth Ave & W 111th St',
#  'Clybourn Ave & Division St',
#  'Dearborn Pkwy & Delaware Pl',
#  'New St & Illinois St',
#  'Sacramento Blvd & Addison St',
#  'Walden Pkwy & 100th St',
#  'Central Park & Augusta Blvd',
#  'Lavergne Ave & Division St',
#  'Jeffery Blvd & 67th St',
#  'Dusable Harbor',
#  'Sheffield Ave & Wrightwood Ave',
#  'Wilton Ave & Diversey Pkwy',
#  'Lamon Ave & Armitage Ave',
#  'Panama Ave & Grace St',
#  'Calumet Ave & 71st St',
#  'Harper Ave & 59th St',
#  'Wallace St & 35th St',
#  'Racine Ave & Belmont Ave',
#  'Mulligan Ave & Wellington Ave',
#  'Western Ave & Leland Ave',
#  'Halsted St & Dickens Ave',
#  'Ashland Ave & Chicago Ave',
#  'Stony Island Ave & 82nd St',
#  'Eberhart Ave & 131st St',
#  'Commercial Ave & 100th St',
#  'Austin Blvd & Madison St',
#  'Washtenaw Ave & Madison St',
#  'Clark St & Columbia Ave',
#  'Western Ave & 62nd St',
#  'Michigan Ave & Lake St',
#  'Chicago Ave & Sheridan Rd',
#  'N Shore Channel Trail & Argyle St',
#  'Broadway & Barry Ave',
#  'Fairfield Ave & Roosevelt Rd',
#  'Damen Ave & Pierce Ave',
#  'Shields Ave & 43rd St',
#  'Lake Shore Dr & North Blvd',
#  'Orleans St & Chestnut St (NEXT Apts)',
#  'Indiana Ave & Roosevelt Rd',
#  'Calumet Ave & 33rd St',
#  'W Armitage Ave & N Sheffield Ave',
#  'Kilbourn & Roscoe',
#  'Harding Ave & 26th St',
#  'Paulina St & Flournoy St',
#  'Damen Ave & 33rd St',
#  'Washtenaw Ave & Polk St',
#  'Torrence Ave & 106th St',
#  'Sheridan Rd & Greenleaf Ave',
#  'Ashland Ave & 50th St',
#  'Central Ave & Harrison St',
#  'Talman Ave & Addison St',
#  'Harlem & Irving Park',
#  'Clark St & Randolph St',
#  'Richmond St & Lincoln Ave',
#  'W 103rd St & S Avers Ave',
#  'Lakeview Ave & Fullerton Pkwy',
#  'Racine Ave & 15th St',
#  'Rockwell St & Eastwood Ave',
#  'Kilpatrick Ave & Parker Ave',
#  'Maplewood Ave & Peterson Ave',
#  'Burnham Greenway & 105th St',
#  'Michigan Ave & Pearson St',
#  'Marshfield Ave & Cortland St',
#  'Halsted St & Archer Ave',
#  'Woodlawn & 103rd - Olive Harvey Vaccination Site',
#  'Francisco Ave & Hollywood Ave',
#  'Commercial Ave & 83rd St',
#  'Ashland Ave & Archer Ave',
#  'Wolcott Ave & Polk St',
#  'California Ave & Milwaukee Ave',
#  'Leavitt St & Division St',
#  'Laramie Ave & Kinzie St',
#  'Southport Ave & Belmont Ave',
#  'Ogden Ave & Chicago Ave',
#  'Menard Ave & North Ave',
#  'Woodlawn Ave & 75th St',
#  'S Aberdeen St & W 106th St',
#  'Major Taylor Trail & 115th St',
#  'Hermitage Ave & Polk St',
#  'Whipple St & Roosevelt Rd',
#  'Buckingham Fountain',
#  'Knox Ave & Montrose Ave',
#  'Central Ave & Roscoe St',
#  'Wood St & Augusta Blvd',
#  'Paulina St & 18th St',
#  'California Ave & North Ave',
#  'Eggleston Ave & 92nd St',
#  'Hampden Ct & Diversey Ave',
#  'California Ave & Marquette Rd',
#  'Federal St & Polk St',
#  'State St & Chicago Ave',
#  'Rockwell St & Archer Ave',
#  'Kilbourn & Belden',
#  'Winchester (Ravenswood) Ave & Balmoral Ave',
#  'Cicero Ave & Lake St',
#  'St Louis Ave & 59th St',
#  'Calumet Ave & 51st St',
#  'Albany Ave & Bloomingdale Ave',
#  'Cityfront Plaza Dr & Pioneer Ct',
#  'State St & 29th St',
#  'Eckhart Park',
#  'Halsted St & 47th Pl',
#  'Damen Ave & Walnut (Lake) St',
#  'Francisco Ave & Montrose Ave',
#  'Normal Ave & Archer Ave',
#  'Leamington Ave & Hirsch St',
#  'Halsted St & 96th St',
#  'Troy St & Grace St',
#  'Ashland Ave & Division St',
#  'California Ave & 29th St',
#  'Ashland Ave & Wellington Ave',
#  'Sedgwick St & Webster Ave',
#  'Financial Pl & Ida B Wells Dr',
#  'Broadway & Granville Ave',
#  'Lake Park Ave & 56th St',
#  'Elizabeth St & 59th St',
#  'Tripp Ave & 65th St',
#  'Lincoln Ave & Peterson Ave',
#  'Broadway & Wilson - Truman College Vaccination Site',
#  'Orange & Addison',
#  'Stony Island Ave & 90th St',
#  'Morgan St & Pershing Rd',
#  'Cottage Grove Ave & 63rd St',
#  'Baltimore Ave & 87th St',
#  'Ashland Ave & Belle Plaine Ave',
#  'Ashland Ave & Garfield Blvd',
#  'Damen Ave & Wabansia Ave',
#  'Clyde Ave & 87th St',
#  'MLK Jr Dr & Pershing Rd',
#  'Lincoln Ave & Belmont Ave',
#  'Virginia Ave & Catalpa Ave',
#  'McClurg Ct & Ohio St',
#  'State St & 54th St',
#  'Carpenter St & 63rd St',
#  'Southport Ave & Clybourn Ave',
#  'Eberhart Ave & 61st St',
#  'Damen Ave & Sunnyside Ave',
#  'Greenwood Ave & 97th St',
#  'Ellis Ave & 58th St',
#  'Clark St & Ida B Wells Dr',
#  'Stewart Ave & 83rd St',
#  'Pine Grove Ave & Irving Park Rd',
#  'Wells St & 19th St',
#  'Halsted St & Roscoe St',
#  'Clark St & Armitage Ave',
#  'Damen Ave & Grand Ave',
#  'Greenwood Ave & 91st St',
#  'Sheffield Ave & Waveland Ave',
#  '2112 W Peterson Ave',
#  'Bernard St & Elston Ave',
#  'Walsh Park',
#  'Drake Ave & Addison St',
#  'Michigan Ave & Oak St',
#  'Ellis Ave & 55th St',
#  'Kingsbury St & Kinzie St',
#  'Lincoln Ave & Addison St',
#  'California Ave & Francis Pl (Temp)',
#  'Southport Ave & Roscoe St',
#  'Meade Ave & Diversey Ave',
#  'Western Ave & Fillmore St',
#  'Racine Ave & Fullerton Ave',
#  'Halsted St & Maxwell St',
#  'Evanston Civic Center',
#  'Clinton St & Roosevelt Rd',
#  'Millard Ave & 26th St',
#  'Fairbanks Ct & Grand Ave',
#  'Vincennes Ave & 75th St',
#  'Altgeld Gardens',
#  'Museum of Science and Industry',
#  'Daley Center Plaza',
#  'Long Ave & Belden Ave',
#  'Big Marsh Park',
#  'Oakley Ave & Touhy Ave',
#  'Ashland Ave & McDowell Ave',
#  'W Oakdale Ave & N Broadway',
#  'LaSalle Dr & Huron St',
#  'Western Ave & Winnebago Ave',
#  'Ogden Ave & Roosevelt Rd',
#  'Wabash Ave & Grand Ave',
#  'Wabash Ave & Cermak Rd',
#  'Sacramento Blvd & Franklin Blvd',
#  'WEST CHI-WATSON',
#  '900 W Harrison St',
#  'Kenneth Ave & 50th St',
#  'Sedgwick St & North Ave',
#  'Vernon Ave & 79th St',
#  'Bloomingdale Ave & Harlem Ave',
#  'Dayton St & North Ave',
#  'Ashland Ave & Blackhawk St',
#  'Clark St & Lincoln Ave',
#  'Ravenswood Ave & Berteau Ave',
#  'California Ave & Lake St',
#  'Clark St & Schreiber Ave',
#  'Michigan Ave & Jackson Blvd',
#  'Sacramento Blvd & Polk St',
#  'Maplewood Ave & 59th St',
#  'Meade Ave & Addison St',
#  'Cicero Ave & Grace St',
#  'Damen Ave & Coulter St',
#  'Loomis St & 89th St',
#  'Wood St & Taylor St (Temp)',
#  'Southport Ave & Waveland Ave',
#  'Prairie Ave & 43rd St',
#  'Central Park Ave & Bloomingdale Ave',
#  'Kilpatrick Ave & Grand Ave',
#  'Sedgwick St & Schiller St',
#  'N Shore Channel Trail & Argyle Ave',
#  'Lyft Driver Center Private Rack',
#  'Wood St & Hubbard St',
#  'Spaulding Ave & 63rd St',
#  'DIVVY CASSETTE REPAIR MOBILE STATION',
#  'State St & 95th St',
#  'Sheridan Rd & Noyes St (NU)',
#  'MLK Jr Dr & 63rd St',
#  'Springfield Ave & 47th St',
#  'Racine Ave & 35th St',
#  'Wilton Ave & Belmont Ave',
#  'Wood St & Chicago Ave',
#  'Cherry Ave & Blackhawk St',
#  'Honore St & Division St',
#  'Kedzie Ave & 104th St',
#  'Racine Ave & 65th St',
#  'State St & 76th St',
#  'Halsted St & 104th St',
#  'Damen Ave & Wellington Ave',
#  'Troy St & North Ave',
#  'Stony Island Ave & 71st St',
#  'Canal St & Monroe St',
#  'Damen Ave & Cullerton St',
#  'Albany Ave & Belmont Ave',
#  'Sacramento Ave & 25th St',
#  'Karlov Ave & Madison St',
#  'Kosciuszko Park',
#  'Evans Ave & 75th St',
#  'Southport Ave & Wrightwood Ave',
#  'Franklin St & Chicago Ave',
#  'Damen Ave & Pershing Rd',
#  'Wood St & 35th St',
#  'Kedzie Ave & 21st St',
#  'Seeley Ave & Garfield Blvd',
#  'Lakefront Trail & Wilson Ave',
#  'Columbus Dr & Randolph St',
#  'Halsted St & North Branch St',
#  'Calumet Ave & 35th St',
#  'Western Ave & Ardmore Ave',
#  'Kostner Ave & Lake St',
#  'Sheffield Ave & Kingsbury St',
#  'Sheridan Rd & Montrose Ave',
#  'Monticello Ave & Irving Park Rd',
#  'Blue Island Ave & 18th St',
#  'Michigan Ave & 14th St',
#  'Franklin St & Illinois St',
#  'Morgan St & Polk St',
#  'Wabash Ave & 16th St',
#  'Racine Ave & Wrightwood Ave',
#  'Clifton Ave & Armitage Ave',
#  'Lincoln Ave & Diversey Pkwy',
#  'Avers Ave & Belmont Ave',
#  'Leavitt St & Armitage Ave',
#  'State St & 19th St',
#  'Pulaski & Ann Lurie Pl',
#  'Kedzie Ave & Leland Ave',
#  'Loomis St & Archer Ave',
#  'Michigan Ave & Washington St',
#  'N Carpenter St & W Lake St',
#  'Kilbourn Ave & Milwaukee Ave',
#  'Loomis St & Jackson Blvd',
#  'Delano Ct & Roosevelt Rd',
#  'Kostner Ave & Adams St',
#  'Cottage Grove Ave & Oakwood Blvd',
#  'Glenwood Ave & Touhy Ave',
#  'Vincennes Ave & 104th St',
#  'Lake Shore Dr & Monroe St',
#  'Commercial Ave & 130th St',
#  'Vernon Ave & 75th St',
#  'Campbell Ave & 51st St',
#  'Theater on the Lake',
#  'East End Ave & 87th St',
#  'Central Ave & Madison St',
#  'Cannon Dr & Fullerton Ave',
#  'Clark St & 9th St (AMLI)',
#  'Halsted St & 73rd St',
#  'Marshfield Ave & 44th St',
#  'Broadway & Argyle St',
#  'MLK Jr Dr & 47th St',
#  'DuSable Lake Shore Dr & Belmont Ave',
#  'Throop St & 52nd St',
#  'Ashland Ave & Grand Ave',
#  'Orleans St & Elm St',
#  'Halsted St & 18th St',
#  'Exchange Ave & 79th St',
#  'Broadway & Thorndale Ave',
#  'Ashland Ave & Augusta Blvd',
#  'Benson Ave & Church St',
#  'Loomis St & Lexington St',
#  'Clarendon Ave & Gordon Ter',
#  'Central Park Ave & Douglas Blvd',
#  'Pulaski Rd & 21st St',
#  'Yates Blvd & 75th St',
#  'Olive Harvey College',
#  'Tripp Ave & 31st St',
#  'Clark St & Elm St',
#  'Racine Ave & Garfield Blvd',
#  'Clark St & Montrose Ave',
#  'St. Clair St & Erie St',
#  'Halsted St & 51st St',
#  'Sheridan Rd & Columbia Ave',
#  'State St & Pearson St',
#  'Ridge Blvd & Touhy Ave',
#  'Broadway & Cornelia Ave',
#  'Leavitt St & Chicago Ave',
#  'Richmond St & Diversey Ave',
#  'Michigan Ave & 71st St',
#  'Rockwell St & 57th St',
#  'McCormick Place',
#  'South Shore Dr & 74th St',
#  'Damen Ave & Charleston St',
#  'California Ave & 26th St',
#  'Fairfield Ave & 44th St',
#  'N Paulina St & Lincoln Ave',
#  'Drake Ave & Montrose Ave',
#  'Montrose Harbor',
#  'Chicago Ave & Washington St',
#  'Dearborn St & Erie St',
#  'Wentworth Ave & 24th St (Temp)',
#  'Ada St & 113th St',
#  'Indiana Ave & 133rd St',
#  'Wentworth Ave & 35th St',
#  'Mozart St & Jackson Blvd',
#  'Racine Ave & Washington Blvd',
#  'Ashland Ave & 78th St',
#  'Larrabee St & Menomonee St',
#  'Union Ave & Root St',
#  'Morgan St & Lake St',
#  'Campbell Ave & North Ave',
#  'Calumet Ave & 18th St',
#  'Sheffield Ave & Wellington Ave',
#  'Woodlawn Ave & Lake Park Ave',
#  'Kedzie Ave & 57th St',
#  'California Ave & 23rd Pl',
#  'South Shore Dr & 67th St',
#  'Paulina Ave & North Ave',
#  'S Michigan Ave & E 118th St',
#  'Kedzie Ave & Harrison St',
#  'Hastings WH 2',
#  'Homewood Ave & 115th St',
#  'Kildare Ave & Division St',
#  'Lake Park Ave & 47th St',
#  'Carpenter St & Huron St',
#  'Dorchester Ave & 63rd St',
#  'Stewart Ave & 63rd St',
#  'Ravenswood Ave & Irving Park Rd',
#  'Wabash Ave & Wacker Pl',
#  'Logan Blvd & Elston Ave',
#  'Lincolnwood Dr & Central St',
#  'Milwaukee Ave & Grand Ave',
#  'Milwaukee Ave & Wabansia Ave',
#  'Wells St & Concord Ln',
#  'Millennium Park',
#  'Central Park Ave & Elbridge Ave',
#  'Greenwood Ave & 79th St',
#  'N Hampden Ct & W Diversey Ave',
#  'Mayfield & Roosevelt Rd',
#  'Damen Ave & 51st St',
#  'Wentworth Ave & 104th St',
#  'Broadway & Sheridan Rd',
#  'Lincoln Ave & Sunnyside Ave',
#  'Narragansett & Irving Park',
#  'Burnham Greenway & 112th St',
#  'Elizabeth (May) St & Fulton St',
#  'Central Park Ave & Ohio St',
#  'Michigan Ave & Ida B Wells Dr',
#  'Wilton Ave & Diversey Pkwy - Charging',
#  'Eastlake Ter & Rogers Ave',
#  'Racine Ave & 61st St',
#  'Malcolm X College Vaccination Site',
#  'Loomis Blvd & 84th St',
#  'Ogden Ave & Race Ave',
#  'Ogden Ave & Congress Pkwy',
#  'Michigan Ave & Madison St',
#  'Halsted St & Polk St',
#  'Rush St & Cedar St',
#  'Sedgwick St & Huron St',
#  'Ewing Ave & Burnham Greenway',
#  'Western Ave & Lake St',
#  'Lincoln Ave & Roscoe St - Charging',
#  'Desplaines St & Kinzie St',
#  'Pulaski Rd & Lake St',
#  'Indiana Ave & 40th St',
#  'Western Blvd & 48th Pl',
#  'Milwaukee Ave & Rockwell St',
#  'Western Ave & 21st St',
#  'Stony Island Ave & 75th St',
#  'Shields Ave & 31st St',
#  'DuSable Lake Shore Dr & Ohio St',
#  'Michigan Ave & 8th St',
#  'Greenview Ave & Fullerton Ave',
#  'Ashland Ave & 74th St',
#  'N Damen Ave & W Chicago Ave',
#  'Stony Island Ave & South Chicago Ave',
#  'Oglesby Ave & 100th St',
#  'Narragansett & Wrightwood',
#  'Monticello Ave & Chicago Ave',
#  'Clinton St & Madison St',
#  'Lavergne & Fullerton',
#  'Halsted St & 78th St',
#  'Major Taylor Trail & 124th St',
#  'California & 16th St',
#  'Halsted St & Wrightwood Ave',
#  'Elston Ave & Wabansia Ave',
#  'Kedzie Ave & Lake St',
#  'Wentworth Ave & Cermak Rd',
#  'South Chicago Ave & Elliot Ave',
#  'Clinton St & Tilden St',
#  'Emerald Ave & 28th St',
#  'Wabash Ave & 87th St',
#  'Fullerton & Monitor',
#  'Racine Ave & 18th St',
#  'Western Ave & Monroe St',
#  'Sheridan Rd & Buena Ave',
#  'Greenwood Ave & 47th St',
#  'Ellis Ave & 60th St',
#  'Ashland Ave & 63rd St',
#  'Central St Metra',
#  'Komensky Ave & 31st St',
#  'Bradley Park',
#  'Winchester Ave & Elston Ave',
#  'Clark St & Leland Ave',
#  'Wabash Ave & 9th St',
#  'Clark St & Bryn Mawr Ave',
#  'Cottage Grove Ave & 71st St',
#  'Mason Ave & Belmont Ave',
#  'Kilbourn Ave & Irving Park Rd',
#  'Michigan Ave & 114th St',
#  'Ridge Blvd & Howard St',
#  'Prairie Ave & Garfield Blvd',
#  'Rush St & Hubbard St',
#  'Clinton St & Polk St',
#  'Artesian Ave & 55th St',
#  'Prospect Sq & 91st St',
#  'Wells St & Polk St',
#  'Pawel Bialowas - Test- PBSC charging station',
#  'Cicero Ave & Quincy St',
#  'MLK Jr Dr & 56th St',
#  'Kenosha & Wellington',
#  'Kedzie Ave & 52nd St',
#  'Wolcott Ave & Fargo Ave',
#  '351',
#  'N Southport Ave & W Newport Ave',
#  'Kedzie Ave & Chicago Ave',
#  'Clinton St & Lake St',
#  'Lake Shore Dr & Ohio St',
#  'Leavitt St & Lawrence Ave',
#  'Laflin St & Cullerton St',
#  'Ashland Ave & 66th St',
#  'Bennett Ave & 79th St',
#  'McClurg Ct & Erie St',
#  'Doty Ave & 111th St',
#  'Morgan Ave & 14th Pl',
#  'Stave St & Armitage Ave',
#  'Summit Ave & 86th St',
#  'Yates Blvd & 93rd St',
#  'Larrabee St & Oak St',
#  'Ravenswood Ave & Lawrence Ave',
#  'Sangamon St & Washington Blvd',
#  'Kedzie Ave & 48th Pl',
#  'Dearborn St & Adams St',
#  'May St & 69th St',
#  'Avenue O & 134th St',
#  'Halsted St & 56th St',
#  'State St & Pershing Rd',
#  'Shore Dr & 55th St',
#  'Rockwell St & Fletcher St',
#  'Clark St & Wellington Ave',
#  'California Ave & Winona St',
#  'California Ave & Montrose Ave',
#  'Racine Ave & 13th St',
#  'Winthrop Ave & Lawrence Ave',
#  'Cicero Ave & Flournoy St',
#  'Lawler Ave & 50th St',
#  'Southport Ave & Wellington Ave',
#  'Sayre & Diversey',
#  'Lincoln Ave & Balmoral Ave',
#  'Ellis Ave & 53rd St',
#  'Larrabee St & Webster Ave',
#  'Damen Ave & Leland Ave',
#  'Pulaski Rd & 60th St',
#  'Whipple/Irving Park',
#  'Throop/Hastings Mobile Station',
#  'LaSalle St & Adams St',
#  'Western Ave & Gunnison St',
#  'Komensky Ave & 55th St',
#  'Archer Ave & 43rd St',
#  'Clarendon Ave & Leland Ave',
#  'State St & 35th St',
#  'N Green St & W Lake St',
#  'Kedzie Ave & Bryn Mawr Ave',
#  'DuSable Lake Shore Dr & Wellington Ave',
#  'Franklin St & Jackson Blvd',
#  'Wentworth Ave & 63rd St',
#  'Larrabee St & Kingsbury St',
#  'Clark St & Wrightwood Ave',
#  'Claremont Ave & Hirsch St',
#  'Cottage Grove Ave & 43rd St',
#  'Ellis Ave & 83rd St',
#  'Lake Park Ave & 53rd St',
#  'Larrabee St & North Ave',
#  'Indiana Ave & 103rd St',
#  'Woodlawn Ave & 55th St',
#  'Conservatory Dr & Lake St',
#  'Central Park Ave & 24th St',
#  'California Ave & 21st St',
#  'Mies van der Rohe Way & Chicago Ave',
#  'Clark St & North Ave',
#  'Cottage Grove Ave & 111th Pl',
#  'Whipple St & Irving Park Rd',
#  'Wabash Ave & Adams St',
#  'Damen Ave & Clybourn Ave',
#  'DuSable Lake Shore Dr & Diversey Pkwy',
#  'Larrabee St & Armitage Ave',
#  'Central Park Blvd & 5th Ave',
#  'Spaulding Ave & Division St',
#  'Wood St & Milwaukee Ave',
#  'Pulaski Rd & 51st St',
#  'Wells St & Huron St',
#  'Noble St & Milwaukee Ave',
#  'Rainbow Beach',
#  'Throop St & Taylor St',
#  'Marine Dr & Ainslie St',
#  'Western Ave & Congress Pkwy',
#  'Canal St & Harrison St',
#  'Canal St & Madison St',
#  'South Chicago Ave & 83rd St',
#  'Sheffield Ave & Willow St',
#  'Francisco Ave & 47th St',
#  'California Ave & Cortez St',
#  'Halsted St & 111th St',
#  'Jeffery Blvd & 76th St',
#  'Shields Ave & 28th Pl',
#  'Dauphin Ave & 103rd St',
#  'Lamon Ave & Chicago Ave',
#  'Cottage Grove Ave & 67th St',
#  'Kildare Ave & 47th St',
#  'Bissell St & Armitage Ave',
#  'Calumet Park',
#  'N Damen Ave & W Wabansia St',
#  'Francisco Ave & Foster Ave',
#  'Western Ave & Lunt Ave',
#  'Cottage Grove Ave & 51st St',
#  'Chicago State University',
#  'Pulaski Rd & Congress Pkwy',
#  'Damen Ave & Foster Ave',
#  'Wabash Ave & 83rd St',
#  'Avondale Ave & Irving Park Rd',
#  'DuSable Lake Shore Dr & North Blvd',
#  'N Clark St & W Elm St',
#  'Keeler Ave & Roosevelt Rd',
#  'May St & Taylor St',
#  'Franklin St & Lake St',
#  'Keystone Ave & Montrose Ave',
#  'Field Museum',
#  'Clark St & Lunt Ave',
#  'Orleans St & Merchandise Mart Plaza',
#  'Lincoln Ave & Roscoe St',
#  'Hoyne Ave & 47th St',
#  'Clark St & Elmdale Ave',
#  'Fairbanks St & Superior St',
#  'Ping Tom Park (East)',
#  'State St & 79th St',
#  'Lake Shore Dr & Belmont Ave',
#  'Green St & Madison St',
#  'Clark St & Winnemac Ave',
#  'Lincoln Park Conservatory',
#  'Western & 28th - Velasquez Institute Vaccination Site',
#  'Paulina St & Howard St',
#  'Jeffery Blvd & 71st St',
#  'Blackstone Ave & Hyde Park Blvd',
#  'Canal St & Taylor St',
#  'LaSalle St & Illinois St',
#  'Desplaines St & Jackson Blvd',
#  'Central St & Girard Ave',
#  'Sheridan Rd & Loyola Ave',
#  'Homan Ave & Fillmore St',
#  'Cottage Grove Ave & 78th St',
#  'Western Ave & 111th St',
#  'Kimbark Ave & 53rd St',
#  'North Ave & New England Ave',
#  'Stony Island Ave & 64th St',
#  'Long Ave & North Ave',
#  'Phillips Ave & 79th St',
#  'Burling St & Diversey Pkwy',
#  'Lawndale Ave & 30th St',
#  'Clark St & Grace St',
#  'Morgan St & 31st St',
#  'Kimball Ave & Belmont Ave',
#  'Leavitt St & Archer Ave',
#  'Lincoln Ave & Winona St',
#  'Ada St & Washington Blvd',
#  'Kedzie Ave & Palmer Ct',
#  'Maryland Ave & 104th St',
#  'Marquette Ave & 89th St',
#  'Western Ave & Division St',
#  'Franklin St & Adams St (Temp)',
#  'Michigan Ave & 18th St',
#  'Morgan St & 18th St',
#  'Clarendon Ave & Junior Ter',
#  'Phillips Ave & 83rd St',
#  'Aberdeen St & Jackson Blvd',
#  'Elmwood Ave & Austin St',
#  'Francisco Ave & Bloomingdale Ave',
#  'Halsted & 63rd - Kennedy-King Vaccination Site',
#  'Emerald Ave & 31st St',
#  'Kenton Ave & Madison St',
#  'Kedzie Ave & Milwaukee Ave',
#  'MLK Jr Dr & 29th St',
#  'Wacker Dr & Washington St',
#  'Plainfield & Irving Park',
#  'Cornell Ave & Hyde Park Blvd',
#  'Orleans St & Hubbard St',
#  'Hegewisch Metra Station',
#  'Sacramento Ave & Pershing Rd',
#  'Elston Ave & Henderson St',
#  'Dodge Ave & Main St',
#  'Ashland Ave & Lake St',
#  'Canal St & Adams St',
#  'Leavitt St & Belmont Ave',
#  'Lawndale Ave & 111th St',
#  'California Ave & Fletcher St',
#  'Clark St & Touhy Ave',
#  'Western Ave & Walton St',
#  'Rhodes Ave & 32nd St',
#  'Ritchie Ct & Banks St',
#  'St Louis Ave & Norman Bobbins Ave',
#  'Kostner Ave & 63rd St',
#  'California Ave & Byron St',
#  'Major Ave & Bloomingdale Ave',
#  'Leavitt St & Addison St',
#  'Calumet Ave & 21st St',
#  'Hoyne Ave & Balmoral Ave',
#  'Avenue O & 118th St',
#  'Augusta Blvd & Laramie Ave',
#  'Damen Ave & Chicago Ave',
#  'University Ave & 57th St',
#  'Wells St & Walton St',
#  'Lincoln Ave & Belle Plaine Ave',
#  'Lincoln Ave & Waveland Ave',
#  'Canal St & Jackson Blvd',
#  'Oakley Ave & Irving Park Rd',
#  'Base - 2132 W Hubbard Warehouse',
#  'Albany Ave & Montrose Ave',
#  'Jefferson St & Monroe St',
#  'Dauphin Ave & 87th St',
#  'Lawndale Ave & 16th St',
#  'Desplaines St & Randolph St',
#  'Racine Ave & Congress Pkwy',
#  'MLK Jr Dr & 83rd St',
#  'Long Ave & Belmont Ave',
#  'Lakefront Trail & Bryn Mawr Ave',
#  'Kedzie Ave & 110th St',
#  'Austin Blvd & Chicago Ave',
#  'Princeton Ave & Garfield Blvd',
#  'Spaulding Ave & Armitage Ave',
#  'Halsted St & 35th St',
#  'St. Louis Ave & Balmoral Ave',
#  'Clark St & Lake St',
#  'Clinton St & Jackson Blvd',
#  'Racine Ave & Randolph St',
#  'Clark St & Drummond Pl',
#  'Sheridan Rd & Irving Park Rd',
#  'Damen Ave & Cortland St',
#  'Halsted St & Roosevelt Rd',
#  'Clark St & Jarvis Ave',
#  'State St & Van Buren St',
#  'Broadway & Waveland Ave',
#  'State St & 123rd St',
#  'Lavergne Ave & 46th St',
#  'Peoria St & Jackson Blvd',
#  'Bosworth Ave & Howard St',
#  'Eberhart Ave & 91st St',
#  'Clark St & Schiller St',
#  'Milwaukee Ave & Fullerton Ave',
#  'Austin Blvd & Lake St',
#  'LaSalle St & Jackson Blvd',
#  'Warren Park West',
#  'Aberdeen St & Monroe St',
#  'Dodge Ave & Mulford St',
#  'Kingsbury St & Erie St',
#  'Field Blvd & South Water St',
#  'DuSable Museum',
#  'Kedzie Ave & 24th St',
#  'Laramie Ave & Madison St',
#  'Dearborn St & Monroe St',
#  'Halsted St & 59th St',
#  'Spaulding Ave & 16th St',
#  'Marshfield Ave & 59th St',
#  'Rhodes Ave & 71st St',
#  'Washtenaw Ave & Ogden Ave',
#  'Lake Shore Dr & Wellington Ave',
#  'State St & 33rd St',
#  'Vernon Ave & 107th St',
#  'Tripp Ave & 15th St',
#  'Harlem Ave & Grace St',
#  'Clark St & Berwyn Ave',
#  'Sheffield Ave & Fullerton Ave',
#  'University Library (NU)',
#  'Halsted St & Willow St',
#  'Wolcott (Ravenswood) Ave & Montrose Ave',
#  'Clinton St & Washington Blvd',
#  'Sheridan Rd & Lawrence Ave',
#  'Green St & Randolph St',
#  'Cottage Grove Ave & 47th St',
#  'Glenwood Ave & Morse Ave',
#  'Western Ave & 104th St',
#  'Parkside Ave & Armitage Ave',
#  'Narragansett & McLean',
#  'Oak Park & Wellington',
#  'Campbell Ave & Fullerton Ave',
#  'Halsted St & Clybourn Ave',
#  'Kedzie Ave & Roosevelt Rd',
#  'Lamon Ave & Belmont Ave',
#  'Sacramento Blvd & Fulton Ave',
#  'State St & Harrison St',
#  'Western Ave & Howard St',
#  'Damen Ave & Melrose Ave',
#  'Indiana Ave & 26th St',
#  'Menard Ave & Division St',
#  'May St & Cullerton St',
#  'Kildare Ave & Montrose Ave',
#  'Clinton St & 18th St',
#  'Albany Ave & 26th St',
#  'Stony Island Ave & 67th St',
#  'Broadway & Berwyn Ave',
#  'Sawyer Ave & Irving Park Rd',
#  'Cornell Dr & Hayes Dr',
#  'Eggleston Ave & 69th St',
#  'Leavitt St & North Ave',
#  'Ashland Ave & Grace St',
#  'Central Ave & Chicago Ave',
#  'Long & Irving Park',
#  'Narragansett Ave & School St',
#  'Sheffield Ave & Webster Ave',
#  'Rush St & Superior St',
#  'Greenview Ave & Jarvis Ave',
#  'Budlong Woods Library',
#  'Franklin St & Monroe St']

# %%
list(set(df_all['end_station_name'].values))
# Out:
# [nan,
#  'Wabash Ave & Roosevelt Rd',
#  'Kostner Ave & Wrightwood Ave',
#  'Aberdeen St & Randolph St',
#  'Elizabeth St & 47th St',
#  'Lake Shore Dr & Diversey Pkwy',
#  'Mies van der Rohe Way & Chestnut St',
#  'St. Louis Ave & Fullerton Ave',
#  'Shedd Aquarium',
#  'Southport Ave & Clark St',
#  'Western Ave & Grace St',
#  'Princeton Ave & 47th St',
#  'Lincoln Ave & Fullerton Ave',
#  'Perry Ave & 69th St',
#  'Warren Park East',
#  'Stockton Dr & Wrightwood Ave',
#  'Halsted St & 37th St',
#  'Southport Ave & Irving Park Rd',
#  'Central Park Ave & North Ave',
#  'California Ave & 36th St',
#  'Milwaukee Ave & Cuyler Ave',
#  'Broadway & Belmont Ave',
#  'Humboldt Blvd & Armitage Ave',
#  'Pulaski Rd & Eddy St (Temp)',
#  'Elston Ave & George St',
#  'Latrobe Ave & Chicago Ave',
#  'Dorchester Ave & 49th St',
#  'Ashland Ave & 13th St',
#  'N Sheffield Ave & W Wellington Ave',
#  'Central Park Ave & Ogden Ave',
#  'Washtenaw Ave & Lawrence Ave',
#  'Halsted St & 69th St',
#  'Troy St & Elston Ave',
#  'Hoyne Ave & 34th St',
#  'Kildare Ave & Chicago Ave',
#  'Lockwood Ave & Wrightwood Ave',
#  'Adler Planetarium',
#  'Houston Ave & 92nd St',
#  'Larrabee St & Division St',
#  'State St & Randolph St',
#  'Hamlin Ave & 62nd Pl',
#  'Clark St & Newport St',
#  'Richmond St & 59th St',
#  'Campbell Ave & Montrose Ave',
#  'Rockwell St & Cermak Rd',
#  'Kedzie Ave & 45th St',
#  'Nordica & Medill',
#  'Kedzie Ave & Foster Ave',
#  'Archer (Damen) Ave & 37th St',
#  'California Ave & Altgeld St',
#  'Stetson Ave & South Water St',
#  'Damen Ave & Madison St',
#  'Artesian Ave & Hubbard St',
#  'W Washington Blvd & N Peoria St',
#  'Roscoe & Harlem',
#  'Wells St & Hubbard St',
#  'Streeter Dr & Grand Ave',
#  'Wentworth Ave & 33rd St',
#  'California Ave & Division St',
#  'Western Ave & Roscoe St',
#  'Western Ave & Granville Ave',
#  'Avenue L & 114th St',
#  'Torrence Ave & 126th Pl',
#  'Central Ave & Parker Ave',
#  'Oketo Ave & Addison St',
#  'Shabbona Park',
#  'Damen Ave & Thomas St (Augusta Blvd)',
#  'Hale Ave & 107th St',
#  'Constance Ave & 95th St',
#  'Burnham Harbor',
#  'Damen Ave & 59th St',
#  'Elston Ave & Cortland St',
#  'Damen Ave & Division St',
#  'Washtenaw Ave & Peterson Ave',
#  'South Shore Dr & 71st St',
#  'Greenview Ave & Diversey Pkwy',
#  'Wells St & Elm St',
#  'Pine Grove Ave & Waveland Ave',
#  'Dearborn St & Van Buren St',
#  'Keystone Ave & Fullerton Ave',
#  'Broadway & Ridge Ave',
#  '63rd St Beach',
#  'Indiana Ave & 31st St',
#  'Fort Dearborn Dr & 31st St',
#  'Laramie Ave & Gladys Ave',
#  'Kildare Ave & 55th St',
#  'Dodge Ave & Church St',
#  'Manor Ave & Leland Ave',
#  'Smith Park',
#  'Ashland Ave & Wrightwood Ave',
#  'Halsted St & 18th St (Temp)',
#  'Christiana Ave & Lawrence Ave',
#  'Valli Produce - Evanston Plaza',
#  'Ashland Ave & Pershing Rd',
#  'DuSable Lake Shore Dr & Monroe St',
#  'Kedzie Ave & George St',
#  'Clark St & Chicago Ave',
#  'Cottage Grove Ave & 83rd St',
#  'State St & Kinzie St',
#  'Paulina St & Montrose Ave',
#  'Halsted St & 21st St',
#  'Wells St & Evergreen Ave',
#  'Central Ave & Lake St',
#  'Western Ave & 24th St',
#  'Lake Park Ave & 35th St',
#  'Kildare Ave & 26th St',
#  'Seeley Ave & Roscoe St',
#  'LaSalle St & Washington St',
#  'Elizabeth St & 92nd St',
#  'S Wentworth Ave & W 111th St',
#  'Clybourn Ave & Division St',
#  'La Villita Park (Albany/30th)',
#  'Dearborn Pkwy & Delaware Pl',
#  'New St & Illinois St',
#  'Sacramento Blvd & Addison St',
#  'Walden Pkwy & 100th St',
#  'Central Park & Augusta Blvd',
#  'Lavergne Ave & Division St',
#  'Jeffery Blvd & 67th St',
#  'Dusable Harbor',
#  'Sheffield Ave & Wrightwood Ave',
#  'Wilton Ave & Diversey Pkwy',
#  'Lamon Ave & Armitage Ave',
#  'Panama Ave & Grace St',
#  'Calumet Ave & 71st St',
#  'Harper Ave & 59th St',
#  'Wallace St & 35th St',
#  'Racine Ave & Belmont Ave',
#  'Mulligan Ave & Wellington Ave',
#  'Western Ave & Leland Ave',
#  'Halsted St & Dickens Ave',
#  'Ashland Ave & Chicago Ave',
#  'Stony Island Ave & 82nd St',
#  'Eberhart Ave & 131st St',
#  'Commercial Ave & 100th St',
#  'Austin Blvd & Madison St',
#  'Washtenaw Ave & Madison St',
#  'Clark St & Columbia Ave',
#  'Western Ave & 62nd St',
#  'Chicago Ave & Sheridan Rd',
#  'Michigan Ave & Lake St',
#  'N Shore Channel Trail & Argyle St',
#  'Broadway & Barry Ave',
#  'Fairfield Ave & Roosevelt Rd',
#  'Damen Ave & Pierce Ave',
#  'Shields Ave & 43rd St',
#  'Lake Shore Dr & North Blvd',
#  'Orleans St & Chestnut St (NEXT Apts)',
#  'Indiana Ave & Roosevelt Rd',
#  'Calumet Ave & 33rd St',
#  'W Armitage Ave & N Sheffield Ave',
#  'Kilbourn & Roscoe',
#  'Harding Ave & 26th St',
#  'Paulina St & Flournoy St',
#  'Damen Ave & 33rd St',
#  'Washtenaw Ave & Polk St',
#  'Torrence Ave & 106th St',
#  'Sheridan Rd & Greenleaf Ave',
#  'Ashland Ave & 50th St',
#  'Central Ave & Harrison St',
#  'Talman Ave & Addison St',
#  'Harlem & Irving Park',
#  'Clark St & Randolph St',
#  'Richmond St & Lincoln Ave',
#  'W 103rd St & S Avers Ave',
#  'Lakeview Ave & Fullerton Pkwy',
#  'Racine Ave & 15th St',
#  'Rockwell St & Eastwood Ave',
#  'Kilpatrick Ave & Parker Ave',
#  'Maplewood Ave & Peterson Ave',
#  'Burnham Greenway & 105th St',
#  'Michigan Ave & Pearson St',
#  'Marshfield Ave & Cortland St',
#  'Halsted St & Archer Ave',
#  'Woodlawn & 103rd - Olive Harvey Vaccination Site',
#  'Francisco Ave & Hollywood Ave',
#  'Commercial Ave & 83rd St',
#  'Ashland Ave & Archer Ave',
#  'California Ave & Milwaukee Ave',
#  'Wolcott Ave & Polk St',
#  'Leavitt St & Division St',
#  'Laramie Ave & Kinzie St',
#  'Southport Ave & Belmont Ave',
#  'Ogden Ave & Chicago Ave',
#  'Menard Ave & North Ave',
#  'Woodlawn Ave & 75th St',
#  'S Aberdeen St & W 106th St',
#  'Major Taylor Trail & 115th St',
#  'Hermitage Ave & Polk St',
#  'Whipple St & Roosevelt Rd',
#  'Buckingham Fountain',
#  'Knox Ave & Montrose Ave',
#  'Central Ave & Roscoe St',
#  'Wood St & Augusta Blvd',
#  'Paulina St & 18th St',
#  'Eggleston Ave & 92nd St',
#  'California Ave & North Ave',
#  'Hampden Ct & Diversey Ave',
#  'California Ave & Marquette Rd',
#  'Federal St & Polk St',
#  'State St & Chicago Ave',
#  'Rockwell St & Archer Ave',
#  'Kilbourn & Belden',
#  'Winchester (Ravenswood) Ave & Balmoral Ave',
#  'Cicero Ave & Lake St',
#  'St Louis Ave & 59th St',
#  'Calumet Ave & 51st St',
#  'Albany Ave & Bloomingdale Ave',
#  'Cityfront Plaza Dr & Pioneer Ct',
#  'State St & 29th St',
#  'Eckhart Park',
#  'Halsted St & 47th Pl',
#  'Damen Ave & Walnut (Lake) St',
#  'Francisco Ave & Montrose Ave',
#  'Normal Ave & Archer Ave',
#  'Leamington Ave & Hirsch St',
#  'Halsted St & 96th St',
#  'Troy St & Grace St',
#  'Ashland Ave & Division St',
#  'California Ave & 29th St',
#  'Ashland Ave & Wellington Ave',
#  'Sedgwick St & Webster Ave',
#  'Financial Pl & Ida B Wells Dr',
#  'Broadway & Granville Ave',
#  'Lake Park Ave & 56th St',
#  'Elizabeth St & 59th St',
#  'Tripp Ave & 65th St',
#  'Lincoln Ave & Peterson Ave',
#  'Broadway & Wilson - Truman College Vaccination Site',
#  'Orange & Addison',
#  'Stony Island Ave & 90th St',
#  'Morgan St & Pershing Rd',
#  'Cottage Grove Ave & 63rd St',
#  'Baltimore Ave & 87th St',
#  'Ashland Ave & Belle Plaine Ave',
#  'Ashland Ave & Garfield Blvd',
#  'Damen Ave & Wabansia Ave',
#  'Clyde Ave & 87th St',
#  'MLK Jr Dr & Pershing Rd',
#  'Lincoln Ave & Belmont Ave',
#  'Virginia Ave & Catalpa Ave',
#  'McClurg Ct & Ohio St',
#  'State St & 54th St',
#  'Carpenter St & 63rd St',
#  'Southport Ave & Clybourn Ave',
#  'Eberhart Ave & 61st St',
#  'Damen Ave & Sunnyside Ave',
#  'Greenwood Ave & 97th St',
#  'Ellis Ave & 58th St',
#  'Clark St & Ida B Wells Dr',
#  'Stewart Ave & 83rd St',
#  'Halsted St & Roscoe St',
#  'Wells St & 19th St',
#  'Clark St & Armitage Ave',
#  'Pine Grove Ave & Irving Park Rd',
#  'Damen Ave & Grand Ave',
#  '2112 W Peterson Ave',
#  'Greenwood Ave & 91st St',
#  'Sheffield Ave & Waveland Ave',
#  'Bernard St & Elston Ave',
#  'Walsh Park',
#  'Drake Ave & Addison St',
#  'Michigan Ave & Oak St',
#  'Ellis Ave & 55th St',
#  'Kingsbury St & Kinzie St',
#  'Lincoln Ave & Addison St',
#  'California Ave & Francis Pl (Temp)',
#  'Southport Ave & Roscoe St',
#  'Meade Ave & Diversey Ave',
#  'Western Ave & Fillmore St',
#  'Racine Ave & Fullerton Ave',
#  'Halsted St & Maxwell St',
#  'Evanston Civic Center',
#  'Clinton St & Roosevelt Rd',
#  'Millard Ave & 26th St',
#  'Fairbanks Ct & Grand Ave',
#  'Vincennes Ave & 75th St',
#  'Altgeld Gardens',
#  'Museum of Science and Industry',
#  'Daley Center Plaza',
#  'Long Ave & Belden Ave',
#  'Big Marsh Park',
#  'Oakley Ave & Touhy Ave',
#  'Ashland Ave & McDowell Ave',
#  'W Oakdale Ave & N Broadway',
#  'LaSalle Dr & Huron St',
#  'Western Ave & Winnebago Ave',
#  'Wabash Ave & Cermak Rd',
#  'Ogden Ave & Roosevelt Rd',
#  'Wabash Ave & Grand Ave',
#  'Sacramento Blvd & Franklin Blvd',
#  'WEST CHI-WATSON',
#  '900 W Harrison St',
#  'Kenneth Ave & 50th St',
#  'Sedgwick St & North Ave',
#  'Vernon Ave & 79th St',
#  'Bloomingdale Ave & Harlem Ave',
#  'Dayton St & North Ave',
#  'Ashland Ave & Blackhawk St',
#  'Ravenswood Ave & Berteau Ave',
#  'Clark St & Lincoln Ave',
#  'California Ave & Lake St',
#  'Clark St & Schreiber Ave',
#  'Michigan Ave & Jackson Blvd',
#  'Sacramento Blvd & Polk St',
#  'Maplewood Ave & 59th St',
#  'Meade Ave & Addison St',
#  'Cicero Ave & Grace St',
#  'Damen Ave & Coulter St',
#  'Loomis St & 89th St',
#  'Wood St & Taylor St (Temp)',
#  'Southport Ave & Waveland Ave',
#  'Prairie Ave & 43rd St',
#  'Central Park Ave & Bloomingdale Ave',
#  'Kilpatrick Ave & Grand Ave',
#  'Sedgwick St & Schiller St',
#  'N Shore Channel Trail & Argyle Ave',
#  'Lyft Driver Center Private Rack',
#  'Wood St & Hubbard St',
#  'Spaulding Ave & 63rd St',
#  'DIVVY CASSETTE REPAIR MOBILE STATION',
#  'State St & 95th St',
#  'Sheridan Rd & Noyes St (NU)',
#  'MLK Jr Dr & 63rd St',
#  'Springfield Ave & 47th St',
#  'Racine Ave & 35th St',
#  'Wilton Ave & Belmont Ave',
#  'Wood St & Chicago Ave',
#  'Cherry Ave & Blackhawk St',
#  'Honore St & Division St',
#  'Kedzie Ave & 104th St',
#  'Racine Ave & 65th St',
#  'State St & 76th St',
#  'Halsted St & 104th St',
#  'Damen Ave & Wellington Ave',
#  'Troy St & North Ave',
#  'Stony Island Ave & 71st St',
#  'Canal St & Monroe St',
#  'Damen Ave & Cullerton St',
#  'Albany Ave & Belmont Ave',
#  'Sacramento Ave & 25th St',
#  'Karlov Ave & Madison St',
#  'Kosciuszko Park',
#  'Evans Ave & 75th St',
#  'Southport Ave & Wrightwood Ave',
#  'Franklin St & Chicago Ave',
#  'Damen Ave & Pershing Rd',
#  'Wood St & 35th St',
#  'Kedzie Ave & 21st St',
#  'Seeley Ave & Garfield Blvd',
#  'Lakefront Trail & Wilson Ave',
#  'Columbus Dr & Randolph St',
#  'Halsted St & North Branch St',
#  'Calumet Ave & 35th St',
#  'Western Ave & Ardmore Ave',
#  'Kostner Ave & Lake St',
#  'Sheffield Ave & Kingsbury St',
#  'Albany Ave & 16th St',
#  'Sheridan Rd & Montrose Ave',
#  'Monticello Ave & Irving Park Rd',
#  'Blue Island Ave & 18th St',
#  'Franklin St & Illinois St',
#  'Wabash Ave & 16th St',
#  'Racine Ave & Wrightwood Ave',
#  'Michigan Ave & 14th St',
#  'Morgan St & Polk St',
#  'Clifton Ave & Armitage Ave',
#  'Lincoln Ave & Diversey Pkwy',
#  'Avers Ave & Belmont Ave',
#  'Leavitt St & Armitage Ave',
#  'State St & 19th St',
#  'Pulaski & Ann Lurie Pl',
#  'Kedzie Ave & Leland Ave',
#  'Loomis St & Archer Ave',
#  'Michigan Ave & Washington St',
#  'N Carpenter St & W Lake St',
#  'Kilbourn Ave & Milwaukee Ave',
#  'Loomis St & Jackson Blvd',
#  'Delano Ct & Roosevelt Rd',
#  'Kostner Ave & Adams St',
#  'Cottage Grove Ave & Oakwood Blvd',
#  'Glenwood Ave & Touhy Ave',
#  'Vincennes Ave & 104th St',
#  'Lake Shore Dr & Monroe St',
#  'Commercial Ave & 130th St',
#  'Vernon Ave & 75th St',
#  'Campbell Ave & 51st St',
#  'Theater on the Lake',
#  'East End Ave & 87th St',
#  'Central Ave & Madison St',
#  'Cannon Dr & Fullerton Ave',
#  'Clark St & 9th St (AMLI)',
#  'Halsted St & 73rd St',
#  'Marshfield Ave & 44th St',
#  'Broadway & Argyle St',
#  'MLK Jr Dr & 47th St',
#  'DuSable Lake Shore Dr & Belmont Ave',
#  'Throop St & 52nd St',
#  'Ashland Ave & Grand Ave',
#  'Orleans St & Elm St',
#  'Halsted St & 18th St',
#  'Exchange Ave & 79th St',
#  'Broadway & Thorndale Ave',
#  'Ashland Ave & Augusta Blvd',
#  'Benson Ave & Church St',
#  'Loomis St & Lexington St',
#  'Clarendon Ave & Gordon Ter',
#  'Central Park Ave & Douglas Blvd',
#  'Pulaski Rd & 21st St',
#  'Yates Blvd & 75th St',
#  'Olive Harvey College',
#  'Tripp Ave & 31st St',
#  'Clark St & Elm St',
#  'St. Clair St & Erie St',
#  'Clark St & Montrose Ave',
#  'Racine Ave & Garfield Blvd',
#  'Richmond St & Diversey Ave',
#  'Sheridan Rd & Columbia Ave',
#  'State St & Pearson St',
#  'Ridge Blvd & Touhy Ave',
#  'Leavitt St & Chicago Ave',
#  'Broadway & Cornelia Ave',
#  'Halsted St & 51st St',
#  'Michigan Ave & 71st St',
#  'Rockwell St & 57th St',
#  'McCormick Place',
#  'South Shore Dr & 74th St',
#  'Damen Ave & Charleston St',
#  'California Ave & 26th St',
#  'Fairfield Ave & 44th St',
#  'N Paulina St & Lincoln Ave',
#  'Drake Ave & Montrose Ave',
#  'Montrose Harbor',
#  'Chicago Ave & Washington St',
#  'Dearborn St & Erie St',
#  'Wentworth Ave & 24th St (Temp)',
#  'Ada St & 113th St',
#  'Indiana Ave & 133rd St',
#  'Wentworth Ave & 35th St',
#  'Mozart St & Jackson Blvd',
#  'Racine Ave & Washington Blvd',
#  'Ashland Ave & 78th St',
#  'Larrabee St & Menomonee St',
#  'Union Ave & Root St',
#  'Morgan St & Lake St',
#  'Campbell Ave & North Ave',
#  'Calumet Ave & 18th St',
#  'Sheffield Ave & Wellington Ave',
#  'Woodlawn Ave & Lake Park Ave',
#  'Kedzie Ave & 57th St',
#  'Campbell Ave & Irving Park Rd',
#  'California Ave & 23rd Pl',
#  'South Shore Dr & 67th St',
#  'Paulina Ave & North Ave',
#  'S Michigan Ave & E 118th St',
#  'Kedzie Ave & Harrison St',
#  'Hastings WH 2',
#  'Homewood Ave & 115th St',
#  'Kildare Ave & Division St',
#  'Lake Park Ave & 47th St',
#  'Carpenter St & Huron St',
#  'Dorchester Ave & 63rd St',
#  'Stewart Ave & 63rd St',
#  'Ravenswood Ave & Irving Park Rd',
#  'Wabash Ave & Wacker Pl',
#  'Logan Blvd & Elston Ave',
#  'Lincolnwood Dr & Central St',
#  'Central Park Ave & Elbridge Ave',
#  'Milwaukee Ave & Grand Ave',
#  'Millennium Park',
#  'Wells St & Concord Ln',
#  'Milwaukee Ave & Wabansia Ave',
#  'Greenwood Ave & 79th St',
#  'Mayfield & Roosevelt Rd',
#  'Damen Ave & 51st St',
#  'Wentworth Ave & 104th St',
#  'Broadway & Sheridan Rd',
#  'Lincoln Ave & Sunnyside Ave',
#  'Narragansett & Irving Park',
#  'Burnham Greenway & 112th St',
#  'Elizabeth (May) St & Fulton St',
#  'Central Park Ave & Ohio St',
#  'Michigan Ave & Ida B Wells Dr',
#  'Wilton Ave & Diversey Pkwy - Charging',
#  'Eastlake Ter & Rogers Ave',
#  'Racine Ave & 61st St',
#  'Malcolm X College Vaccination Site',
#  'Loomis Blvd & 84th St',
#  'Ogden Ave & Race Ave',
#  'Ogden Ave & Congress Pkwy',
#  'Michigan Ave & Madison St',
#  'Halsted St & Polk St',
#  'Sedgwick St & Huron St',
#  'Rush St & Cedar St',
#  'Ewing Ave & Burnham Greenway',
#  'Western Ave & Lake St',
#  'Lincoln Ave & Roscoe St - Charging',
#  'Desplaines St & Kinzie St',
#  'Pulaski Rd & Lake St',
#  'Indiana Ave & 40th St',
#  'Western Blvd & 48th Pl',
#  'Milwaukee Ave & Rockwell St',
#  'Western Ave & 21st St',
#  'Stony Island Ave & 75th St',
#  'Shields Ave & 31st St',
#  'DuSable Lake Shore Dr & Ohio St',
#  'Greenview Ave & Fullerton Ave',
#  'Ashland Ave & 74th St',
#  'Michigan Ave & 8th St',
#  'N Damen Ave & W Chicago Ave',
#  'Stony Island Ave & South Chicago Ave',
#  'Oglesby Ave & 100th St',
#  'Narragansett & Wrightwood',
#  'Monticello Ave & Chicago Ave',
#  'Clinton St & Madison St',
#  'Lavergne & Fullerton',
#  'Halsted St & 78th St',
#  'Major Taylor Trail & 124th St',
#  'California & 16th St',
#  'Halsted St & Wrightwood Ave',
#  'Elston Ave & Wabansia Ave',
#  'Kedzie Ave & Lake St',
#  'Wentworth Ave & Cermak Rd',
#  'South Chicago Ave & Elliot Ave',
#  'Clinton St & Tilden St',
#  'Emerald Ave & 28th St',
#  'Wabash Ave & 87th St',
#  'Fullerton & Monitor',
#  'Racine Ave & 18th St',
#  'Western Ave & Monroe St',
#  'Sheridan Rd & Buena Ave',
#  'Greenwood Ave & 47th St',
#  'Ellis Ave & 60th St',
#  'Ashland Ave & 63rd St',
#  'Central St Metra',
#  'Komensky Ave & 31st St',
#  'Bradley Park',
#  'Winchester Ave & Elston Ave',
#  'Clark St & Leland Ave',
#  'Wabash Ave & 9th St',
#  'Clark St & Bryn Mawr Ave',
#  'Cottage Grove Ave & 71st St',
#  'Mason Ave & Belmont Ave',
#  'Kilbourn Ave & Irving Park Rd',
#  'Michigan Ave & 114th St',
#  'Ridge Blvd & Howard St',
#  'Prairie Ave & Garfield Blvd',
#  'Rush St & Hubbard St',
#  'Clinton St & Polk St',
#  'Artesian Ave & 55th St',
#  'Prospect Sq & 91st St',
#  'Wells St & Polk St',
#  'Pawel Bialowas - Test- PBSC charging station',
#  'Cicero Ave & Quincy St',
#  'MLK Jr Dr & 56th St',
#  'Kenosha & Wellington',
#  'Kedzie Ave & 52nd St',
#  'Wolcott Ave & Fargo Ave',
#  'N Southport Ave & W Newport Ave',
#  'Kedzie Ave & Chicago Ave',
#  'Clinton St & Lake St',
#  'Leavitt St & Lawrence Ave',
#  'Lake Shore Dr & Ohio St',
#  'Laflin St & Cullerton St',
#  'Ashland Ave & 66th St',
#  'Bennett Ave & 79th St',
#  'McClurg Ct & Erie St',
#  'Doty Ave & 111th St',
#  'Morgan Ave & 14th Pl',
#  'Stave St & Armitage Ave',
#  'Summit Ave & 86th St',
#  'Yates Blvd & 93rd St',
#  'Larrabee St & Oak St',
#  'Ravenswood Ave & Lawrence Ave',
#  'Sangamon St & Washington Blvd',
#  'Kedzie Ave & 48th Pl',
#  'Dearborn St & Adams St',
#  'Avenue O & 134th St',
#  'May St & 69th St',
#  'State St & Pershing Rd',
#  'Halsted St & 56th St',
#  'Shore Dr & 55th St',
#  'Rockwell St & Fletcher St',
#  'Clark St & Wellington Ave',
#  'California Ave & Winona St',
#  'California Ave & Montrose Ave',
#  'Racine Ave & 13th St',
#  'Winthrop Ave & Lawrence Ave',
#  'Cicero Ave & Flournoy St',
#  'Lawler Ave & 50th St',
#  'Southport Ave & Wellington Ave',
#  'Sayre & Diversey',
#  'Lincoln Ave & Balmoral Ave',
#  'Ellis Ave & 53rd St',
#  'Larrabee St & Webster Ave',
#  'Damen Ave & Leland Ave',
#  'Pulaski Rd & 60th St',
#  'Whipple/Irving Park',
#  'Throop/Hastings Mobile Station',
#  'LaSalle St & Adams St',
#  'Western Ave & Gunnison St',
#  'Komensky Ave & 55th St',
#  'Archer Ave & 43rd St',
#  'State St & 35th St',
#  'Clarendon Ave & Leland Ave',
#  'N Green St & W Lake St',
#  'Kedzie Ave & Bryn Mawr Ave',
#  'DuSable Lake Shore Dr & Wellington Ave',
#  'Franklin St & Jackson Blvd',
#  'Wentworth Ave & 63rd St',
#  'Larrabee St & Kingsbury St',
#  'Clark St & Wrightwood Ave',
#  'Claremont Ave & Hirsch St',
#  'Cottage Grove Ave & 43rd St',
#  'Ellis Ave & 83rd St',
#  'Larrabee St & North Ave',
#  'Lake Park Ave & 53rd St',
#  'Indiana Ave & 103rd St',
#  'Woodlawn Ave & 55th St',
#  'Conservatory Dr & Lake St',
#  'Cottage Grove Ave & 111th Pl',
#  'Central Park Ave & 24th St',
#  'Mies van der Rohe Way & Chicago Ave',
#  'Clark St & North Ave',
#  'California Ave & 21st St',
#  'Whipple St & Irving Park Rd',
#  'Wabash Ave & Adams St',
#  'Damen Ave & Clybourn Ave',
#  'DuSable Lake Shore Dr & Diversey Pkwy',
#  'Larrabee St & Armitage Ave',
#  'Central Park Blvd & 5th Ave',
#  'Spaulding Ave & Division St',
#  'Wood St & Milwaukee Ave',
#  'Pulaski Rd & 51st St',
#  'Wells St & Huron St',
#  'Noble St & Milwaukee Ave',
#  'Rainbow Beach',
#  'Throop St & Taylor St',
#  'Marine Dr & Ainslie St',
#  'South Chicago Ave & 83rd St',
#  'Canal St & Harrison St',
#  'Western Ave & Congress Pkwy',
#  'Canal St & Madison St',
#  'Sheffield Ave & Willow St',
#  'Francisco Ave & 47th St',
#  'California Ave & Cortez St',
#  'Halsted St & 111th St',
#  'Jeffery Blvd & 76th St',
#  'Shields Ave & 28th Pl',
#  'Dauphin Ave & 103rd St',
#  'Lamon Ave & Chicago Ave',
#  'Cottage Grove Ave & 67th St',
#  'Kildare Ave & 47th St',
#  'Bissell St & Armitage Ave',
#  'Calumet Park',
#  'N Damen Ave & W Wabansia St',
#  'Francisco Ave & Foster Ave',
#  'Western Ave & Lunt Ave',
#  'Cottage Grove Ave & 51st St',
#  'Chicago State University',
#  'Pulaski Rd & Congress Pkwy',
#  'Damen Ave & Foster Ave',
#  'Wabash Ave & 83rd St',
#  'Avondale Ave & Irving Park Rd',
#  'DuSable Lake Shore Dr & North Blvd',
#  'N Clark St & W Elm St',
#  'Keeler Ave & Roosevelt Rd',
#  'May St & Taylor St',
#  'Franklin St & Lake St',
#  'Keystone Ave & Montrose Ave',
#  'Field Museum',
#  'Clark St & Lunt Ave',
#  'Orleans St & Merchandise Mart Plaza',
#  'Lincoln Ave & Roscoe St',
#  'Hoyne Ave & 47th St',
#  'Clark St & Elmdale Ave',
#  'Fairbanks St & Superior St',
#  'Ping Tom Park (East)',
#  'Lake Shore Dr & Belmont Ave',
#  'State St & 79th St',
#  'Green St & Madison St',
#  'Clark St & Winnemac Ave',
#  'Lincoln Park Conservatory',
#  'Western & 28th - Velasquez Institute Vaccination Site',
#  'Paulina St & Howard St',
#  'Jeffery Blvd & 71st St',
#  'Blackstone Ave & Hyde Park Blvd',
#  'Canal St & Taylor St',
#  'LaSalle St & Illinois St',
#  'Desplaines St & Jackson Blvd',
#  'Central St & Girard Ave',
#  'Sheridan Rd & Loyola Ave',
#  'Homan Ave & Fillmore St',
#  'Cottage Grove Ave & 78th St',
#  'Western Ave & 111th St',
#  'Kimbark Ave & 53rd St',
#  'North Ave & New England Ave',
#  'Stony Island Ave & 64th St',
#  'Long Ave & North Ave',
#  'Phillips Ave & 79th St',
#  'Burling St & Diversey Pkwy',
#  'Lawndale Ave & 30th St',
#  'Clark St & Grace St',
#  'Morgan St & 31st St',
#  'Kimball Ave & Belmont Ave',
#  'Leavitt St & Archer Ave',
#  'Lincoln Ave & Winona St',
#  'Ada St & Washington Blvd',
#  'Kedzie Ave & Palmer Ct',
#  'Maryland Ave & 104th St',
#  'Marquette Ave & 89th St',
#  'Western Ave & Division St',
#  'Franklin St & Adams St (Temp)',
#  'Michigan Ave & 18th St',
#  'Morgan St & 18th St',
#  'Clarendon Ave & Junior Ter',
#  'Phillips Ave & 83rd St',
#  'Aberdeen St & Jackson Blvd',
#  'Elmwood Ave & Austin St',
#  'Francisco Ave & Bloomingdale Ave',
#  'Halsted & 63rd - Kennedy-King Vaccination Site',
#  'Emerald Ave & 31st St',
#  'Kenton Ave & Madison St',
#  'Kedzie Ave & Milwaukee Ave',
#  'MLK Jr Dr & 29th St',
#  'Wacker Dr & Washington St',
#  'Plainfield & Irving Park',
#  'Cornell Ave & Hyde Park Blvd',
#  'Orleans St & Hubbard St',
#  'Hegewisch Metra Station',
#  'Sacramento Ave & Pershing Rd',
#  'Elston Ave & Henderson St',
#  'Dodge Ave & Main St',
#  'Ashland Ave & Lake St',
#  'Canal St & Adams St',
#  'Leavitt St & Belmont Ave',
#  'Lawndale Ave & 111th St',
#  'California Ave & Fletcher St',
#  'Clark St & Touhy Ave',
#  'Western Ave & Walton St',
#  'Rhodes Ave & 32nd St',
#  'Ritchie Ct & Banks St',
#  'St Louis Ave & Norman Bobbins Ave',
#  'Kostner Ave & 63rd St',
#  'California Ave & Byron St',
#  'Major Ave & Bloomingdale Ave',
#  'Leavitt St & Addison St',
#  'Calumet Ave & 21st St',
#  'Hoyne Ave & Balmoral Ave',
#  'Avenue O & 118th St',
#  'Augusta Blvd & Laramie Ave',
#  'Damen Ave & Chicago Ave',
#  'University Ave & 57th St',
#  'Wells St & Walton St',
#  'Lincoln Ave & Belle Plaine Ave',
#  'Lincoln Ave & Waveland Ave',
#  'Canal St & Jackson Blvd',
#  'Oakley Ave & Irving Park Rd',
#  'Base - 2132 W Hubbard Warehouse',
#  'Albany Ave & Montrose Ave',
#  'Jefferson St & Monroe St',
#  'Dauphin Ave & 87th St',
#  'Lawndale Ave & 16th St',
#  'Desplaines St & Randolph St',
#  'Racine Ave & Congress Pkwy',
#  'MLK Jr Dr & 83rd St',
#  'Long Ave & Belmont Ave',
#  'Lakefront Trail & Bryn Mawr Ave',
#  'Kedzie Ave & 110th St',
#  'Austin Blvd & Chicago Ave',
#  'Princeton Ave & Garfield Blvd',
#  'Spaulding Ave & Armitage Ave',
#  'Halsted St & 35th St',
#  'St. Louis Ave & Balmoral Ave',
#  'Clinton St & Jackson Blvd',
#  'Clark St & Lake St',
#  'Racine Ave & Randolph St',
#  'Clark St & Drummond Pl',
#  'Sheridan Rd & Irving Park Rd',
#  'Damen Ave & Cortland St',
#  'Halsted St & Roosevelt Rd',
#  'Clark St & Jarvis Ave',
#  'State St & Van Buren St',
#  'Broadway & Waveland Ave',
#  'State St & 123rd St',
#  'Lavergne Ave & 46th St',
#  'Peoria St & Jackson Blvd',
#  'Eberhart Ave & 91st St',
#  'Bosworth Ave & Howard St',
#  'Clark St & Schiller St',
#  'Milwaukee Ave & Fullerton Ave',
#  'Austin Blvd & Lake St',
#  'LaSalle St & Jackson Blvd',
#  'Warren Park West',
#  'Aberdeen St & Monroe St',
#  'Dodge Ave & Mulford St',
#  'Kingsbury St & Erie St',
#  'Field Blvd & South Water St',
#  'DuSable Museum',
#  'Kedzie Ave & 24th St',
#  'Laramie Ave & Madison St',
#  'Dearborn St & Monroe St',
#  'Halsted St & 59th St',
#  'Spaulding Ave & 16th St',
#  'Marshfield Ave & 59th St',
#  'Rhodes Ave & 71st St',
#  'Washtenaw Ave & Ogden Ave',
#  'Lake Shore Dr & Wellington Ave',
#  'State St & 33rd St',
#  'Vernon Ave & 107th St',
#  'Tripp Ave & 15th St',
#  'Harlem Ave & Grace St',
#  'Clark St & Berwyn Ave',
#  'Sheffield Ave & Fullerton Ave',
#  'University Library (NU)',
#  'Halsted St & Willow St',
#  'Wolcott (Ravenswood) Ave & Montrose Ave',
#  'Clinton St & Washington Blvd',
#  'Sheridan Rd & Lawrence Ave',
#  'Green St & Randolph St',
#  'Cottage Grove Ave & 47th St',
#  'Glenwood Ave & Morse Ave',
#  'Western Ave & 104th St',
#  'Parkside Ave & Armitage Ave',
#  'Narragansett & McLean',
#  'Oak Park & Wellington',
#  'Campbell Ave & Fullerton Ave',
#  'Halsted St & Clybourn Ave',
#  'Kedzie Ave & Roosevelt Rd',
#  'Lamon Ave & Belmont Ave',
#  'Sacramento Blvd & Fulton Ave',
#  'State St & Harrison St',
#  'Western Ave & Howard St',
#  'Damen Ave & Melrose Ave',
#  'Indiana Ave & 26th St',
#  'Menard Ave & Division St',
#  'May St & Cullerton St',
#  'Kildare Ave & Montrose Ave',
#  'Clinton St & 18th St',
#  'Albany Ave & 26th St',
#  'Stony Island Ave & 67th St',
#  'Broadway & Berwyn Ave',
#  'Sawyer Ave & Irving Park Rd',
#  'Cornell Dr & Hayes Dr',
#  'Ashland Ave & Grace St',
#  'Eggleston Ave & 69th St',
#  'Leavitt St & North Ave',
#  'Central Ave & Chicago Ave',
#  'Long & Irving Park',
#  'Narragansett Ave & School St',
#  'Sheffield Ave & Webster Ave',
#  'Rush St & Superior St',
#  'Greenview Ave & Jarvis Ave',
#  'Budlong Woods Library',
#  'Franklin St & Monroe St']

# %% [markdown]
# Null values found. Then now is the time to clean the data.

# %% [markdown]
# ## Step 3: Process

# %% [markdown]
# After we have done preparing the data the next step in our analysis process is process the data, mainly cleaning them. The reason why we are doing this is because uncleaned data will disturb the rest of our analysis process in many aspect such as mathematical operations, statistical report, and visualization process.

# %% [markdown]
# #### Guiding questions
# Guiding questions
# 1. What tools are you choosing and why?
# 2. Have you ensured your data’s integrity?
# 3. What steps have you taken to ensure that your data is clean?
# 4. How can you verify that your data is clean and ready to analyze?
# 5. Have you documented your cleaning process so you can review and share those results?
#
# #### Key tasks
# 1. Check the data for errors.
# 2. Choose your tools.
# 3. Transform the data so you can work with it effectively.
# 4. Document the cleaning process.

# %% [markdown]
# #### My Answer to the guiding questions and key tasks:
# ##### Answered after the process phase is done
# 1. I am using numpy and pandas libraries in Python language to clean the data because those are the fields/skills that I am trying to improve.
# 2. I didn't do it for this project.
# 3. Some things that I did in this project:
#     - checking null values and then removing them
#     - checking typos for discrete columns
#     - removing duplicates
#     - removing rows whose time_ended minus time_started gave minus difference (user finishing the service before even start which is illogical)
# 4. With markdown in jupyter notebook like this, yeah.

# %% [markdown]
# ### Cleaning Process
# - NULL values
# - duplication
# - data type & data format of each column is consistent
# - typos
# - For column with discrete values (like member_casual which should only have 2 values), make sure there are no more than specified values

# %% [markdown]
# Useful resources for data cleaning:
# - https://www.acaps.org/sites/acaps/files/resources/files/acaps_technical_brief_data_cleaning_april_2016_0.pdf
# - https://www.ibm.com/docs/en/spss-modeler/18.2.1?topic=data-writing-cleaning-report

# %%
df_all = df_all.drop_duplicates()
df_all = df_all.dropna()
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4630225 entries, 0 to 4630224
# Data columns (total 18 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  Unnamed: 0          float64
#  14  clean_started_at    object
#  15  clean_ended_at      object
#  16  time_spent          object
#  17  distance_in_km      float64
# dtypes: float64(6), object(12)
# memory usage: 671.2+ MB

# %% [markdown]
# Now it has **4 million** rows.

# %% [markdown]
# It will be good to create a column to store a data about how long each rider is using the service. Create a column to store the difference between time started and time ended. But before that we need to make sure the data type is correct before doing the operation.

# %%
print(df_all['started_at'].values)
print(df_all['ended_at'].values)
# Out:
# ['2021-03-16 08:32:30' '2021-03-28 01:26:28' '2021-03-11 21:17:29' ...
#  '2022-02-11 09:01:05' '2022-02-19 23:57:50' '2022-02-28 09:16:33']
# ['2021-03-16 08:36:34' '2021-03-28 01:36:55' '2021-03-11 21:33:53' ...
#  '2022-02-11 09:10:51' '2022-02-20 00:02:34' '2022-02-28 09:28:11']

# %% [markdown]
# It can be seen that the datatype of each of the data is in string. Let's convert it into datetime.datetime data.

# %%
import datetime

def transform_datetime(tgl='2021-03-20 14:10:41'):
    year = int(tgl[:4])
    month = int(tgl[5:7])
    date = int(tgl[8:10])
    hour = int(tgl[11:13])
    minute = int(tgl[14:16])
    second = int(tgl[17:19])
    
    return datetime.datetime(year, month, date, hour, minute, second)

# %%
df_all['clean_started_at'] = df_all['started_at'].apply(lambda x: transform_datetime(x))
df_all['clean_ended_at'] = df_all['ended_at'].apply(lambda x: transform_datetime(x))

# %%
df_all['time_spent'] = df_all['clean_ended_at'] - df_all['clean_started_at']
df_all.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  CFA86D4455AA1030  classic_bike  2021-03-16 08:32:30  2021-03-16 08:36:34
# 1  30D9DC61227D1AF3  classic_bike  2021-03-28 01:26:28  2021-03-28 01:36:55
# 2  846D87A15682A284  classic_bike  2021-03-11 21:17:29  2021-03-11 21:33:53
# 3  994D05AA75A168F2  classic_bike  2021-03-11 13:26:42  2021-03-11 13:55:41
# 4  DF7464FBE92D8308  classic_bike  2021-03-21 09:09:37  2021-03-21 09:27:33
#
#              start_station_name start_station_id  \
# 0  Humboldt Blvd & Armitage Ave            15651
# 1  Humboldt Blvd & Armitage Ave            15651
# 2         Shields Ave & 28th Pl            15443
# 3   Winthrop Ave & Lawrence Ave     TA1308000021
# 4      Glenwood Ave & Touhy Ave              525
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# 0              Stave St & Armitage Ave          13266  41.917513 -87.701809
# 1  Central Park Ave & Bloomingdale Ave          18017  41.917513 -87.701809
# 2                 Halsted St & 35th St   TA1308000043  41.842733 -87.635491
# 3               Broadway & Sheridan Rd          13323  41.968812 -87.657659
# 4            Chicago Ave & Sheridan Rd           E008  42.012701 -87.666058
#
#      end_lat    end_lng member_casual  Unnamed: 0    clean_started_at  \
# 0  41.917741 -87.691392        casual         0.0 2021-03-16 08:32:30
# 1  41.914166 -87.716755        casual         1.0 2021-03-28 01:26:28
# 2  41.830661 -87.647172        casual         2.0 2021-03-11 21:17:29
# 3  41.952833 -87.649993        casual         3.0 2021-03-11 13:26:42
# 4  42.050491 -87.677821        casual         4.0 2021-03-21 09:09:37
#
#        clean_ended_at      time_spent  distance_in_km
# 0 2021-03-16 08:36:34 0 days 00:04:04        0.864535
# 1 2021-03-28 01:36:55 0 days 00:10:27        1.294466
# 2 2021-03-11 21:33:53 0 days 00:16:24        1.655063
# 3 2021-03-11 13:55:41 0 days 00:28:59        1.885180
# 4 2021-03-21 09:27:33 0 days 00:17:56        4.309027

# %% [markdown]
# Now we can do mathematical calculations with the time_spent data.

# %%
all_time_spent_mean = df_all['time_spent'].mean()
all_time_spent_max = df_all['time_spent'].max()
all_time_spent_min = df_all['time_spent'].min()
all_time_spent_std = df_all['time_spent'].std()

print("Casual Rider Statistic")
print("Mean:", all_time_spent_mean)
print("Max:", all_time_spent_max)
print("Min:", all_time_spent_min)
print("Std:", all_time_spent_std)
# Out:
# Casual Rider Statistic
# Mean: 0 days 00:21:37.565555453
# Max: 38 days 20:24:09
# Min: 0 days 00:00:00
# Std: 0 days 03:03:18.792819815

# %% [markdown]
# There is a minus time_spent data. It seems there exist at least 1 row whose start time > end time. We need to check them.

# %%
df_all_minus_time_spent = df_all.loc[df_all['time_spent'].apply(lambda x: x.total_seconds()) < 0]
print(len(df_all_minus_time_spent))
df_all_minus_time_spent
# Out:
# 0
# Empty DataFrame
# Columns: [ride_id, rideable_type, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng, member_casual, Unnamed: 0, clean_started_at, clean_ended_at, time_spent, distance_in_km]
# Index: []

# %% [markdown]
# Those data will be handled by removing them.

# %%
df_all_clean = df_all.drop(df_all_minus_time_spent.index, axis=0)
df_all_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4630225 entries, 0 to 4630224
# Data columns (total 18 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  Unnamed: 0          float64
#  14  clean_started_at    datetime64[ns]
#  15  clean_ended_at      datetime64[ns]
#  16  time_spent          timedelta64[ns]
#  17  distance_in_km      float64
# dtypes: datetime64[ns](2), float64(6), object(9), timedelta64[ns](1)
# memory usage: 800.2+ MB

# %% [markdown]
# Now let's check the time spent column

# %%
df_all_clean_time_spent_mean = df_all_clean['time_spent'].mean()
df_all_clean_time_spent_max = df_all_clean['time_spent'].max()
df_all_clean_time_spent_min = df_all_clean['time_spent'].min()
df_all_clean_time_spent_std = df_all_clean['time_spent'].std()

print("All Rider Time Spent Statistic")
print("Mean:", df_all_clean_time_spent_mean)
print("Max:", df_all_clean_time_spent_max)
print("Min:", df_all_clean_time_spent_min)
print("Std:", df_all_clean_time_spent_std)
# Out:
# All Rider Time Spent Statistic
# Mean: 0 days 00:21:37.565555453
# Max: 38 days 20:24:09
# Min: 0 days 00:00:00
# Std: 0 days 03:03:18.792819815

# %% [markdown]
# It will be good if we have more clearer data about distance. Now create the column that store the data about it by process it with latitude and longitude.

# %%
from geopy.distance import geodesic
import numpy as np

# %%
distance_val = []
baris = 0
for row in df_all_clean.values:
    baris += 1
    # lat start, long start, lat end, long end
    # index: 8, 9, 10, 11
    print(f"Processing row: {baris}  ", end='\r')
    
    lat_start = row[8]
    long_start = row[9]
    lat_end = row[10]
    long_end = row[11]
    
    coords_1 = (lat_start, long_start)
    coords_2 = (lat_end, long_end)
    
    jarak = geodesic(coords_1, coords_2).km
    distance_val.append(jarak)

df_all_clean['distance_in_km'] = np.array(distance_val)
df_all_clean.head()
# Out:
# Processing row: 4630225
#             ride_id rideable_type           started_at             ended_at  \
# 0  CFA86D4455AA1030  classic_bike  2021-03-16 08:32:30  2021-03-16 08:36:34
# 1  30D9DC61227D1AF3  classic_bike  2021-03-28 01:26:28  2021-03-28 01:36:55
# 2  846D87A15682A284  classic_bike  2021-03-11 21:17:29  2021-03-11 21:33:53
# 3  994D05AA75A168F2  classic_bike  2021-03-11 13:26:42  2021-03-11 13:55:41
# 4  DF7464FBE92D8308  classic_bike  2021-03-21 09:09:37  2021-03-21 09:27:33
#
#              start_station_name start_station_id  \
# 0  Humboldt Blvd & Armitage Ave            15651
# 1  Humboldt Blvd & Armitage Ave            15651
# 2         Shields Ave & 28th Pl            15443
# 3   Winthrop Ave & Lawrence Ave     TA1308000021
# 4      Glenwood Ave & Touhy Ave              525
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# 0              Stave St & Armitage Ave          13266  41.917513 -87.701809
# 1  Central Park Ave & Bloomingdale Ave          18017  41.917513 -87.701809
# 2                 Halsted St & 35th St   TA1308000043  41.842733 -87.635491
# 3               Broadway & Sheridan Rd          13323  41.968812 -87.657659
# 4            Chicago Ave & Sheridan Rd           E008  42.012701 -87.666058
#
#      end_lat    end_lng member_casual  Unnamed: 0    clean_started_at  \
# 0  41.917741 -87.691392        casual         0.0 2021-03-16 08:32:30
# 1  41.914166 -87.716755        casual         1.0 2021-03-28 01:26:28
# 2  41.830661 -87.647172        casual         2.0 2021-03-11 21:17:29
# 3  41.952833 -87.649993        casual         3.0 2021-03-11 13:26:42
# 4  42.050491 -87.677821        casual         4.0 2021-03-21 09:09:37
#
#        clean_ended_at      time_spent  distance_in_km
# 0 2021-03-16 08:36:34 0 days 00:04:04        0.864535
# 1 2021-03-28 01:36:55 0 days 00:10:27        1.294466
# 2 2021-03-11 21:33:53 0 days 00:16:24        1.655063
# 3 2021-03-11 13:55:41 0 days 00:28:59        1.885180
# 4 2021-03-21 09:27:33 0 days 00:17:56        4.309027

# %% [markdown]
# ***Small Rant : D\*mn it took around 1 hour. Maybe there is a better way for processing it.***

# %% [markdown]
# Since the data have been cleaned now we can sort columns with discrete values to check some typos.

# %%
sorted(list(set(df_all['start_station_name'].values)))
# Out:
# ['2112 W Peterson Ave',
#  '351',
#  '63rd St Beach',
#  '900 W Harrison St',
#  'Aberdeen St & Jackson Blvd',
#  'Aberdeen St & Monroe St',
#  'Aberdeen St & Randolph St',
#  'Ada St & 113th St',
#  'Ada St & Washington Blvd',
#  'Adler Planetarium',
#  'Albany Ave & 26th St',
#  'Albany Ave & Belmont Ave',
#  'Albany Ave & Bloomingdale Ave',
#  'Albany Ave & Montrose Ave',
#  'Altgeld Gardens',
#  'Archer (Damen) Ave & 37th St',
#  'Archer Ave & 43rd St',
#  'Artesian Ave & 55th St',
#  'Artesian Ave & Hubbard St',
#  'Ashland Ave & 13th St',
#  'Ashland Ave & 50th St',
#  'Ashland Ave & 63rd St',
#  'Ashland Ave & 66th St',
#  'Ashland Ave & 74th St',
#  'Ashland Ave & 78th St',
#  'Ashland Ave & Archer Ave',
#  'Ashland Ave & Augusta Blvd',
#  'Ashland Ave & Belle Plaine Ave',
#  'Ashland Ave & Blackhawk St',
#  'Ashland Ave & Chicago Ave',
#  'Ashland Ave & Division St',
#  'Ashland Ave & Garfield Blvd',
#  'Ashland Ave & Grace St',
#  'Ashland Ave & Grand Ave',
#  'Ashland Ave & Lake St',
#  'Ashland Ave & McDowell Ave',
#  'Ashland Ave & Pershing Rd',
#  'Ashland Ave & Wellington Ave',
#  'Ashland Ave & Wrightwood Ave',
#  'Augusta Blvd & Laramie Ave',
#  'Austin Blvd & Chicago Ave',
#  'Austin Blvd & Lake St',
#  'Austin Blvd & Madison St',
#  'Avenue L & 114th St',
#  'Avenue O & 118th St',
#  'Avenue O & 134th St',
#  'Avers Ave & Belmont Ave',
#  'Avondale Ave & Irving Park Rd',
#  'Baltimore Ave & 87th St',
#  'Base - 2132 W Hubbard Warehouse',
#  'Bennett Ave & 79th St',
#  'Benson Ave & Church St',
#  'Bernard St & Elston Ave',
#  'Big Marsh Park',
#  'Bissell St & Armitage Ave',
#  'Blackstone Ave & Hyde Park Blvd',
#  'Bloomingdale Ave & Harlem Ave',
#  'Blue Island Ave & 18th St',
#  'Bosworth Ave & Howard St',
#  'Bradley Park',
#  'Broadway & Argyle St',
#  'Broadway & Barry Ave',
#  'Broadway & Belmont Ave',
#  'Broadway & Berwyn Ave',
#  'Broadway & Cornelia Ave',
#  'Broadway & Granville Ave',
#  'Broadway & Ridge Ave',
#  'Broadway & Sheridan Rd',
#  'Broadway & Thorndale Ave',
#  'Broadway & Waveland Ave',
#  'Broadway & Wilson - Truman College Vaccination Site',
#  'Buckingham Fountain',
#  'Budlong Woods Library',
#  'Burling St & Diversey Pkwy',
#  'Burnham Greenway & 105th St',
#  'Burnham Greenway & 112th St',
#  'Burnham Harbor',
#  'California Ave & 21st St',
#  'California Ave & 23rd Pl',
#  'California Ave & 26th St',
#  'California Ave & 29th St',
#  'California Ave & 36th St',
#  'California Ave & Altgeld St',
#  'California Ave & Byron St',
#  'California Ave & Cortez St',
#  'California Ave & Division St',
#  'California Ave & Fletcher St',
#  'California Ave & Francis Pl (Temp)',
#  'California Ave & Lake St',
#  'California Ave & Marquette Rd',
#  'California Ave & Milwaukee Ave',
#  'California Ave & Montrose Ave',
#  'California Ave & North Ave',
#  'California Ave & Winona St',
#  'Calumet Ave & 18th St',
#  'Calumet Ave & 21st St',
#  'Calumet Ave & 33rd St',
#  'Calumet Ave & 35th St',
#  'Calumet Ave & 51st St',
#  'Calumet Ave & 71st St',
#  'Calumet Park',
#  'Campbell Ave & 51st St',
#  'Campbell Ave & Fullerton Ave',
#  'Campbell Ave & Montrose Ave',
#  'Campbell Ave & North Ave',
#  'Canal St & Adams St',
#  'Canal St & Harrison St',
#  'Canal St & Jackson Blvd',
#  'Canal St & Madison St',
#  'Canal St & Monroe St',
#  'Canal St & Taylor St',
#  'Cannon Dr & Fullerton Ave',
#  'Carpenter St & 63rd St',
#  'Carpenter St & Huron St',
#  'Central Ave & Chicago Ave',
#  'Central Ave & Harrison St',
#  'Central Ave & Lake St',
#  'Central Ave & Madison St',
#  'Central Ave & Parker Ave',
#  'Central Ave & Roscoe St',
#  'Central Park & Augusta Blvd',
#  'Central Park Ave & 24th St',
#  'Central Park Ave & Bloomingdale Ave',
#  'Central Park Ave & Douglas Blvd',
#  'Central Park Ave & Elbridge Ave',
#  'Central Park Ave & North Ave',
#  'Central Park Ave & Ogden Ave',
#  'Central Park Ave & Ohio St',
#  'Central Park Blvd & 5th Ave',
#  'Central St & Girard Ave',
#  'Central St Metra',
#  'Cherry Ave & Blackhawk St',
#  'Chicago Ave & Sheridan Rd',
#  'Chicago Ave & Washington St',
#  'Chicago State University',
#  'Christiana Ave & Lawrence Ave',
#  'Cicero Ave & Flournoy St',
#  'Cicero Ave & Grace St',
#  'Cicero Ave & Lake St',
#  'Cicero Ave & Quincy St',
#  'Cityfront Plaza Dr & Pioneer Ct',
#  'Claremont Ave & Hirsch St',
#  'Clarendon Ave & Gordon Ter',
#  'Clarendon Ave & Junior Ter',
#  'Clarendon Ave & Leland Ave',
#  'Clark St & 9th St (AMLI)',
#  'Clark St & Armitage Ave',
#  'Clark St & Berwyn Ave',
#  'Clark St & Bryn Mawr Ave',
#  'Clark St & Chicago Ave',
#  'Clark St & Columbia Ave',
#  'Clark St & Drummond Pl',
#  'Clark St & Elm St',
#  'Clark St & Elmdale Ave',
#  'Clark St & Grace St',
#  'Clark St & Ida B Wells Dr',
#  'Clark St & Jarvis Ave',
#  'Clark St & Lake St',
#  'Clark St & Leland Ave',
#  'Clark St & Lincoln Ave',
#  'Clark St & Lunt Ave',
#  'Clark St & Montrose Ave',
#  'Clark St & Newport St',
#  'Clark St & North Ave',
#  'Clark St & Randolph St',
#  'Clark St & Schiller St',
#  'Clark St & Schreiber Ave',
#  'Clark St & Touhy Ave',
#  'Clark St & Wellington Ave',
#  'Clark St & Winnemac Ave',
#  'Clark St & Wrightwood Ave',
#  'Clifton Ave & Armitage Ave',
#  'Clinton St & 18th St',
#  'Clinton St & Jackson Blvd',
#  'Clinton St & Lake St',
#  'Clinton St & Madison St',
#  'Clinton St & Polk St',
#  'Clinton St & Roosevelt Rd',
#  'Clinton St & Tilden St',
#  'Clinton St & Washington Blvd',
#  'Clybourn Ave & Division St',
#  'Clyde Ave & 87th St',
#  'Columbus Dr & Randolph St',
#  'Commercial Ave & 100th St',
#  'Commercial Ave & 130th St',
#  'Commercial Ave & 83rd St',
#  'Conservatory Dr & Lake St',
#  'Constance Ave & 95th St',
#  'Cornell Ave & Hyde Park Blvd',
#  'Cornell Dr & Hayes Dr',
#  'Cottage Grove Ave & 111th Pl',
#  'Cottage Grove Ave & 43rd St',
#  'Cottage Grove Ave & 47th St',
#  'Cottage Grove Ave & 51st St',
#  'Cottage Grove Ave & 63rd St',
#  'Cottage Grove Ave & 67th St',
#  'Cottage Grove Ave & 71st St',
#  'Cottage Grove Ave & 78th St',
#  'Cottage Grove Ave & 83rd St',
#  'Cottage Grove Ave & Oakwood Blvd',
#  'DIVVY CASSETTE REPAIR MOBILE STATION',
#  'Daley Center Plaza',
#  'Damen Ave & 33rd St',
#  'Damen Ave & 51st St',
#  'Damen Ave & 59th St',
#  'Damen Ave & Charleston St',
#  'Damen Ave & Chicago Ave',
#  'Damen Ave & Clybourn Ave',
#  'Damen Ave & Cortland St',
#  'Damen Ave & Coulter St',
#  'Damen Ave & Cullerton St',
#  'Damen Ave & Division St',
#  'Damen Ave & Foster Ave',
#  'Damen Ave & Grand Ave',
#  'Damen Ave & Leland Ave',
#  'Damen Ave & Madison St',
#  'Damen Ave & Melrose Ave',
#  'Damen Ave & Pershing Rd',
#  'Damen Ave & Pierce Ave',
#  'Damen Ave & Sunnyside Ave',
#  'Damen Ave & Thomas St (Augusta Blvd)',
#  'Damen Ave & Wabansia Ave',
#  'Damen Ave & Walnut (Lake) St',
#  'Damen Ave & Wellington Ave',
#  'Dauphin Ave & 103rd St',
#  'Dauphin Ave & 87th St',
#  'Dayton St & North Ave',
#  'Dearborn Pkwy & Delaware Pl',
#  'Dearborn St & Adams St',
#  'Dearborn St & Erie St',
#  'Dearborn St & Monroe St',
#  'Dearborn St & Van Buren St',
#  'Delano Ct & Roosevelt Rd',
#  'Desplaines St & Jackson Blvd',
#  'Desplaines St & Kinzie St',
#  'Desplaines St & Randolph St',
#  'Dodge Ave & Church St',
#  'Dodge Ave & Main St',
#  'Dodge Ave & Mulford St',
#  'Dorchester Ave & 49th St',
#  'Dorchester Ave & 63rd St',
#  'Doty Ave & 111th St',
#  'Drake Ave & Addison St',
#  'Drake Ave & Montrose Ave',
#  'DuSable Lake Shore Dr & Belmont Ave',
#  'DuSable Lake Shore Dr & Diversey Pkwy',
#  'DuSable Lake Shore Dr & Monroe St',
#  'DuSable Lake Shore Dr & North Blvd',
#  'DuSable Lake Shore Dr & Ohio St',
#  'DuSable Lake Shore Dr & Wellington Ave',
#  'DuSable Museum',
#  'Dusable Harbor',
#  'East End Ave & 87th St',
#  'Eastlake Ter & Rogers Ave',
#  'Eberhart Ave & 131st St',
#  'Eberhart Ave & 61st St',
#  'Eberhart Ave & 91st St',
#  'Eckhart Park',
#  'Eggleston Ave & 69th St',
#  'Eggleston Ave & 92nd St',
#  'Elizabeth (May) St & Fulton St',
#  'Elizabeth St & 47th St',
#  'Elizabeth St & 59th St',
#  'Elizabeth St & 92nd St',
#  'Ellis Ave & 53rd St',
#  'Ellis Ave & 55th St',
#  'Ellis Ave & 58th St',
#  'Ellis Ave & 60th St',
#  'Ellis Ave & 83rd St',
#  'Elmwood Ave & Austin St',
#  'Elston Ave & Cortland St',
#  'Elston Ave & George St',
#  'Elston Ave & Henderson St',
#  'Elston Ave & Wabansia Ave',
#  'Emerald Ave & 28th St',
#  'Emerald Ave & 31st St',
#  'Evans Ave & 75th St',
#  'Evanston Civic Center',
#  'Ewing Ave & Burnham Greenway',
#  'Exchange Ave & 79th St',
#  'Fairbanks Ct & Grand Ave',
#  'Fairbanks St & Superior St',
#  'Fairfield Ave & 44th St',
#  'Fairfield Ave & Roosevelt Rd',
#  'Federal St & Polk St',
#  'Field Blvd & South Water St',
#  'Field Museum',
#  'Financial Pl & Ida B Wells Dr',
#  'Fort Dearborn Dr & 31st St',
#  'Francisco Ave & 47th St',
#  'Francisco Ave & Bloomingdale Ave',
#  'Francisco Ave & Foster Ave',
#  'Francisco Ave & Hollywood Ave',
#  'Francisco Ave & Montrose Ave',
#  'Franklin St & Adams St (Temp)',
#  'Franklin St & Chicago Ave',
#  'Franklin St & Illinois St',
#  'Franklin St & Jackson Blvd',
#  'Franklin St & Lake St',
#  'Franklin St & Monroe St',
#  'Fullerton & Monitor',
#  'Glenwood Ave & Morse Ave',
#  'Glenwood Ave & Touhy Ave',
#  'Green St & Madison St',
#  'Green St & Randolph St',
#  'Greenview Ave & Diversey Pkwy',
#  'Greenview Ave & Fullerton Ave',
#  'Greenview Ave & Jarvis Ave',
#  'Greenwood Ave & 47th St',
#  'Greenwood Ave & 79th St',
#  'Greenwood Ave & 91st St',
#  'Greenwood Ave & 97th St',
#  'Hale Ave & 107th St',
#  'Halsted & 63rd - Kennedy-King Vaccination Site',
#  'Halsted St & 104th St',
#  'Halsted St & 111th St',
#  'Halsted St & 18th St',
#  'Halsted St & 18th St (Temp)',
#  'Halsted St & 21st St',
#  'Halsted St & 35th St',
#  'Halsted St & 37th St',
#  'Halsted St & 47th Pl',
#  'Halsted St & 51st St',
#  'Halsted St & 56th St',
#  'Halsted St & 59th St',
#  'Halsted St & 69th St',
#  'Halsted St & 73rd St',
#  'Halsted St & 78th St',
#  'Halsted St & 96th St',
#  'Halsted St & Archer Ave',
#  'Halsted St & Clybourn Ave',
#  'Halsted St & Dickens Ave',
#  'Halsted St & Maxwell St',
#  'Halsted St & North Branch St',
#  'Halsted St & Polk St',
#  'Halsted St & Roosevelt Rd',
#  'Halsted St & Roscoe St',
#  'Halsted St & Willow St',
#  'Halsted St & Wrightwood Ave',
#  'Hamlin Ave & 62nd Pl',
#  'Hampden Ct & Diversey Ave',
#  'Harding Ave & 26th St',
#  'Harlem & Irving Park',
#  'Harlem Ave & Grace St',
#  'Harper Ave & 59th St',
#  'Hastings WH 2',
#  'Hegewisch Metra Station',
#  'Hermitage Ave & Polk St',
#  'Homan Ave & Fillmore St',
#  'Homewood Ave & 115th St',
#  'Honore St & Division St',
#  'Houston Ave & 92nd St',
#  'Hoyne Ave & 34th St',
#  'Hoyne Ave & 47th St',
#  'Hoyne Ave & Balmoral Ave',
#  'Humboldt Blvd & Armitage Ave',
#  'Indiana Ave & 103rd St',
#  'Indiana Ave & 133rd St',
#  'Indiana Ave & 26th St',
#  'Indiana Ave & 31st St',
#  'Indiana Ave & 40th St',
#  'Indiana Ave & Roosevelt Rd',
#  'Jefferson St & Monroe St',
#  'Jeffery Blvd & 67th St',
#  'Jeffery Blvd & 71st St',
#  'Jeffery Blvd & 76th St',
#  'Karlov Ave & Madison St',
#  'Kedzie Ave & 104th St',
#  'Kedzie Ave & 110th St',
#  'Kedzie Ave & 21st St',
#  'Kedzie Ave & 24th St',
#  'Kedzie Ave & 45th St',
#  'Kedzie Ave & 48th Pl',
#  'Kedzie Ave & 52nd St',
#  'Kedzie Ave & 57th St',
#  'Kedzie Ave & Bryn Mawr Ave',
#  'Kedzie Ave & Chicago Ave',
#  'Kedzie Ave & Foster Ave',
#  'Kedzie Ave & George St',
#  'Kedzie Ave & Harrison St',
#  'Kedzie Ave & Lake St',
#  'Kedzie Ave & Leland Ave',
#  'Kedzie Ave & Milwaukee Ave',
#  'Kedzie Ave & Palmer Ct',
#  'Kedzie Ave & Roosevelt Rd',
#  'Keeler Ave & Roosevelt Rd',
#  'Kenneth Ave & 50th St',
#  'Kenosha & Wellington',
#  'Kenton Ave & Madison St',
#  'Keystone Ave & Fullerton Ave',
#  'Keystone Ave & Montrose Ave',
#  'Kilbourn & Belden',
#  'Kilbourn & Roscoe',
#  'Kilbourn Ave & Irving Park Rd',
#  'Kilbourn Ave & Milwaukee Ave',
#  'Kildare Ave & 26th St',
#  'Kildare Ave & 47th St',
#  'Kildare Ave & 55th St',
#  'Kildare Ave & Chicago Ave',
#  'Kildare Ave & Division St',
#  'Kildare Ave & Montrose Ave',
#  'Kilpatrick Ave & Grand Ave',
#  'Kilpatrick Ave & Parker Ave',
#  'Kimball Ave & Belmont Ave',
#  'Kimbark Ave & 53rd St',
#  'Kingsbury St & Erie St',
#  'Kingsbury St & Kinzie St',
#  'Knox Ave & Montrose Ave',
#  'Komensky Ave & 31st St',
#  'Komensky Ave & 55th St',
#  'Kosciuszko Park',
#  'Kostner Ave & 63rd St',
#  'Kostner Ave & Adams St',
#  'Kostner Ave & Lake St',
#  'Kostner Ave & Wrightwood Ave',
#  'LaSalle Dr & Huron St',
#  'LaSalle St & Adams St',
#  'LaSalle St & Illinois St',
#  'LaSalle St & Jackson Blvd',
#  'LaSalle St & Washington St',
#  'Laflin St & Cullerton St',
#  'Lake Park Ave & 35th St',
#  'Lake Park Ave & 47th St',
#  'Lake Park Ave & 53rd St',
#  'Lake Park Ave & 56th St',
#  'Lake Shore Dr & Belmont Ave',
#  'Lake Shore Dr & Diversey Pkwy',
#  'Lake Shore Dr & Monroe St',
#  'Lake Shore Dr & North Blvd',
#  'Lake Shore Dr & Ohio St',
#  'Lake Shore Dr & Wellington Ave',
#  'Lakefront Trail & Bryn Mawr Ave',
#  'Lakefront Trail & Wilson Ave',
#  'Lakeview Ave & Fullerton Pkwy',
#  'Lamon Ave & Armitage Ave',
#  'Lamon Ave & Belmont Ave',
#  'Lamon Ave & Chicago Ave',
#  'Laramie Ave & Gladys Ave',
#  'Laramie Ave & Kinzie St',
#  'Laramie Ave & Madison St',
#  'Larrabee St & Armitage Ave',
#  'Larrabee St & Division St',
#  'Larrabee St & Kingsbury St',
#  'Larrabee St & Menomonee St',
#  'Larrabee St & North Ave',
#  'Larrabee St & Oak St',
#  'Larrabee St & Webster Ave',
#  'Latrobe Ave & Chicago Ave',
#  'Lavergne & Fullerton',
#  'Lavergne Ave & 46th St',
#  'Lavergne Ave & Division St',
#  'Lawler Ave & 50th St',
#  'Lawndale Ave & 111th St',
#  'Lawndale Ave & 16th St',
#  'Lawndale Ave & 30th St',
#  'Leamington Ave & Hirsch St',
#  'Leavitt St & Addison St',
#  'Leavitt St & Archer Ave',
#  'Leavitt St & Armitage Ave',
#  'Leavitt St & Belmont Ave',
#  'Leavitt St & Chicago Ave',
#  'Leavitt St & Division St',
#  'Leavitt St & Lawrence Ave',
#  'Leavitt St & North Ave',
#  'Lincoln Ave & Addison St',
#  'Lincoln Ave & Balmoral Ave',
#  'Lincoln Ave & Belle Plaine Ave',
#  'Lincoln Ave & Belmont Ave',
#  'Lincoln Ave & Diversey Pkwy',
#  'Lincoln Ave & Fullerton Ave',
#  'Lincoln Ave & Peterson Ave',
#  'Lincoln Ave & Roscoe St',
#  'Lincoln Ave & Roscoe St - Charging',
#  'Lincoln Ave & Sunnyside Ave',
#  'Lincoln Ave & Waveland Ave',
#  'Lincoln Ave & Winona St',
#  'Lincoln Park Conservatory',
#  'Lincolnwood Dr & Central St',
#  'Lockwood Ave & Wrightwood Ave',
#  'Logan Blvd & Elston Ave',
#  'Long & Irving Park',
#  'Long Ave & Belden Ave',
#  'Long Ave & Belmont Ave',
#  'Long Ave & North Ave',
#  'Loomis Blvd & 84th St',
#  'Loomis St & 89th St',
#  'Loomis St & Archer Ave',
#  'Loomis St & Jackson Blvd',
#  'Loomis St & Lexington St',
#  'Lyft Driver Center Private Rack',
#  'MLK Jr Dr & 29th St',
#  'MLK Jr Dr & 47th St',
#  'MLK Jr Dr & 56th St',
#  'MLK Jr Dr & 63rd St',
#  'MLK Jr Dr & 83rd St',
#  'MLK Jr Dr & Pershing Rd',
#  'Major Ave & Bloomingdale Ave',
#  'Major Taylor Trail & 115th St',
#  'Major Taylor Trail & 124th St',
#  'Malcolm X College Vaccination Site',
#  'Manor Ave & Leland Ave',
#  'Maplewood Ave & 59th St',
#  'Maplewood Ave & Peterson Ave',
#  'Marine Dr & Ainslie St',
#  'Marquette Ave & 89th St',
#  'Marshfield Ave & 44th St',
#  'Marshfield Ave & 59th St',
#  'Marshfield Ave & Cortland St',
#  'Maryland Ave & 104th St',
#  'Mason Ave & Belmont Ave',
#  'May St & 69th St',
#  'May St & Cullerton St',
#  'May St & Taylor St',
#  'Mayfield & Roosevelt Rd',
#  'McClurg Ct & Erie St',
#  'McClurg Ct & Ohio St',
#  'McCormick Place',
#  'Meade Ave & Addison St',
#  'Meade Ave & Diversey Ave',
#  'Menard Ave & Division St',
#  'Menard Ave & North Ave',
#  'Michigan Ave & 114th St',
#  'Michigan Ave & 14th St',
#  'Michigan Ave & 18th St',
#  'Michigan Ave & 71st St',
#  'Michigan Ave & 8th St',
#  'Michigan Ave & Ida B Wells Dr',
#  'Michigan Ave & Jackson Blvd',
#  'Michigan Ave & Lake St',
#  'Michigan Ave & Madison St',
#  'Michigan Ave & Oak St',
#  'Michigan Ave & Pearson St',
#  'Michigan Ave & Washington St',
#  'Mies van der Rohe Way & Chestnut St',
#  'Mies van der Rohe Way & Chicago Ave',
#  'Millard Ave & 26th St',
#  'Millennium Park',
#  'Milwaukee Ave & Cuyler Ave',
#  'Milwaukee Ave & Fullerton Ave',
#  'Milwaukee Ave & Grand Ave',
#  'Milwaukee Ave & Rockwell St',
#  'Milwaukee Ave & Wabansia Ave',
#  'Monticello Ave & Chicago Ave',
#  'Monticello Ave & Irving Park Rd',
#  'Montrose Harbor',
#  'Morgan Ave & 14th Pl',
#  'Morgan St & 18th St',
#  'Morgan St & 31st St',
#  'Morgan St & Lake St',
#  'Morgan St & Pershing Rd',
#  'Morgan St & Polk St',
#  'Mozart St & Jackson Blvd',
#  'Mulligan Ave & Wellington Ave',
#  'Museum of Science and Industry',
#  'N Carpenter St & W Lake St',
#  'N Clark St & W Elm St',
#  'N Damen Ave & W Chicago Ave',
#  'N Green St & W Lake St',
#  'N Hampden Ct & W Diversey Ave',
#  'N Paulina St & Lincoln Ave',
#  'N Sheffield Ave & W Wellington Ave',
#  'N Shore Channel Trail & Argyle Ave',
#  'N Shore Channel Trail & Argyle St',
#  'N Southport Ave & W Newport Ave',
#  'Narragansett & Irving Park',
#  'Narragansett & McLean',
#  'Narragansett & Wrightwood',
#  'Narragansett Ave & School St',
#  'New St & Illinois St',
#  'Noble St & Milwaukee Ave',
#  'Nordica & Medill',
#  'Normal Ave & Archer Ave',
#  'North Ave & New England Ave',
#  'Oak Park & Wellington',
#  'Oakley Ave & Irving Park Rd',
#  'Oakley Ave & Touhy Ave',
#  'Ogden Ave & Chicago Ave',
#  'Ogden Ave & Congress Pkwy',
#  'Ogden Ave & Race Ave',
#  'Ogden Ave & Roosevelt Rd',
#  'Oglesby Ave & 100th St',
#  'Oketo Ave & Addison St',
#  'Olive Harvey College',
#  'Orange & Addison',
#  'Orleans St & Chestnut St (NEXT Apts)',
#  'Orleans St & Elm St',
#  'Orleans St & Hubbard St',
#  'Orleans St & Merchandise Mart Plaza',
#  'Panama Ave & Grace St',
#  'Parkside Ave & Armitage Ave',
#  'Paulina Ave & North Ave',
#  'Paulina St & 18th St',
#  'Paulina St & Flournoy St',
#  'Paulina St & Howard St',
#  'Paulina St & Montrose Ave',
#  'Pawel Bialowas - Test- PBSC charging station',
#  'Peoria St & Jackson Blvd',
#  'Perry Ave & 69th St',
#  'Phillips Ave & 79th St',
#  'Phillips Ave & 83rd St',
#  'Pine Grove Ave & Irving Park Rd',
#  'Pine Grove Ave & Waveland Ave',
#  'Ping Tom Park (East)',
#  'Plainfield & Irving Park',
#  'Prairie Ave & 43rd St',
#  'Prairie Ave & Garfield Blvd',
#  'Princeton Ave & 47th St',
#  'Princeton Ave & Garfield Blvd',
#  'Prospect Sq & 91st St',
#  'Pulaski & Ann Lurie Pl',
#  'Pulaski Rd & 21st St',
#  'Pulaski Rd & 51st St',
#  'Pulaski Rd & 60th St',
#  'Pulaski Rd & Congress Pkwy',
#  'Pulaski Rd & Eddy St (Temp)',
#  'Pulaski Rd & Lake St',
#  'Racine Ave & 13th St',
#  'Racine Ave & 15th St',
#  'Racine Ave & 18th St',
#  'Racine Ave & 35th St',
#  'Racine Ave & 61st St',
#  'Racine Ave & 65th St',
#  'Racine Ave & Belmont Ave',
#  'Racine Ave & Congress Pkwy',
#  'Racine Ave & Fullerton Ave',
#  'Racine Ave & Garfield Blvd',
#  'Racine Ave & Randolph St',
#  'Racine Ave & Washington Blvd',
#  'Racine Ave & Wrightwood Ave',
#  'Rainbow Beach',
#  'Ravenswood Ave & Berteau Ave',
#  'Ravenswood Ave & Irving Park Rd',
#  'Ravenswood Ave & Lawrence Ave',
#  'Rhodes Ave & 32nd St',
#  'Rhodes Ave & 71st St',
#  'Richmond St & 59th St',
#  'Richmond St & Diversey Ave',
#  'Richmond St & Lincoln Ave',
#  'Ridge Blvd & Howard St',
#  'Ridge Blvd & Touhy Ave',
#  'Ritchie Ct & Banks St',
#  'Rockwell St & 57th St',
#  'Rockwell St & Archer Ave',
#  'Rockwell St & Cermak Rd',
#  'Rockwell St & Eastwood Ave',
#  'Rockwell St & Fletcher St',
#  'Roscoe & Harlem',
#  'Rush St & Cedar St',
#  'Rush St & Hubbard St',
#  'Rush St & Superior St',
#  'S Aberdeen St & W 106th St',
#  'S Michigan Ave & E 118th St',
#  'S Wentworth Ave & W 111th St',
#  'Sacramento Ave & 25th St',
#  'Sacramento Ave & Pershing Rd',
#  'Sacramento Blvd & Addison St',
#  'Sacramento Blvd & Franklin Blvd',
#  'Sacramento Blvd & Fulton Ave',
#  'Sacramento Blvd & Polk St',
#  'Sangamon St & Washington Blvd',
#  'Sawyer Ave & Irving Park Rd',
#  'Sayre & Diversey',
#  'Sedgwick St & Huron St',
#  'Sedgwick St & North Ave',
#  'Sedgwick St & Schiller St',
#  'Sedgwick St & Webster Ave',
#  'Seeley Ave & Garfield Blvd',
#  'Seeley Ave & Roscoe St',
#  'Shedd Aquarium',
#  'Sheffield Ave & Fullerton Ave',
#  'Sheffield Ave & Kingsbury St',
#  'Sheffield Ave & Waveland Ave',
#  'Sheffield Ave & Webster Ave',
#  'Sheffield Ave & Wellington Ave',
#  'Sheffield Ave & Willow St',
#  'Sheffield Ave & Wrightwood Ave',
#  'Sheridan Rd & Buena Ave',
#  'Sheridan Rd & Columbia Ave',
#  'Sheridan Rd & Greenleaf Ave',
#  'Sheridan Rd & Irving Park Rd',
#  'Sheridan Rd & Lawrence Ave',
#  'Sheridan Rd & Loyola Ave',
#  'Sheridan Rd & Montrose Ave',
#  'Sheridan Rd & Noyes St (NU)',
#  'Shields Ave & 28th Pl',
#  'Shields Ave & 31st St',
#  'Shields Ave & 43rd St',
#  'Shore Dr & 55th St',
#  'Smith Park',
#  'South Chicago Ave & 83rd St',
#  'South Chicago Ave & Elliot Ave',
#  'South Shore Dr & 67th St',
#  'South Shore Dr & 71st St',
#  'South Shore Dr & 74th St',
#  'Southport Ave & Belmont Ave',
#  'Southport Ave & Clark St',
#  'Southport Ave & Clybourn Ave',
#  'Southport Ave & Irving Park Rd',
#  'Southport Ave & Roscoe St',
#  'Southport Ave & Waveland Ave',
#  'Southport Ave & Wellington Ave',
#  'Southport Ave & Wrightwood Ave',
#  'Spaulding Ave & 16th St',
#  'Spaulding Ave & 63rd St',
#  'Spaulding Ave & Armitage Ave',
#  'Spaulding Ave & Division St',
#  'Springfield Ave & 47th St',
#  'St Louis Ave & 59th St',
#  'St Louis Ave & Norman Bobbins Ave',
#  'St. Clair St & Erie St',
#  'St. Louis Ave & Balmoral Ave',
#  'St. Louis Ave & Fullerton Ave',
#  'State St & 123rd St',
#  'State St & 19th St',
#  'State St & 29th St',
#  'State St & 33rd St',
#  'State St & 35th St',
#  'State St & 54th St',
#  'State St & 76th St',
#  'State St & 79th St',
#  'State St & 95th St',
#  'State St & Chicago Ave',
#  'State St & Harrison St',
#  'State St & Kinzie St',
#  'State St & Pearson St',
#  'State St & Pershing Rd',
#  'State St & Randolph St',
#  'State St & Van Buren St',
#  'Stave St & Armitage Ave',
#  'Stetson Ave & South Water St',
#  'Stewart Ave & 63rd St',
#  'Stewart Ave & 83rd St',
#  'Stockton Dr & Wrightwood Ave',
#  'Stony Island Ave & 64th St',
#  'Stony Island Ave & 67th St',
#  'Stony Island Ave & 71st St',
#  'Stony Island Ave & 75th St',
#  'Stony Island Ave & 82nd St',
#  'Stony Island Ave & 90th St',
#  'Stony Island Ave & South Chicago Ave',
#  'Streeter Dr & Grand Ave',
#  'Summit Ave & 86th St',
#  'Talman Ave & Addison St',
#  'Theater on the Lake',
#  'Throop St & 52nd St',
#  'Throop St & Taylor St',
#  'Throop/Hastings Mobile Station',
#  'Torrence Ave & 106th St',
#  'Torrence Ave & 126th Pl',
#  'Tripp Ave & 15th St',
#  'Tripp Ave & 31st St',
#  'Tripp Ave & 65th St',
#  'Troy St & Elston Ave',
#  'Troy St & Grace St',
#  'Troy St & North Ave',
#  'Union Ave & Root St',
#  'University Ave & 57th St',
#  'University Library (NU)',
#  'Valli Produce - Evanston Plaza',
#  'Vernon Ave & 107th St',
#  'Vernon Ave & 75th St',
#  'Vernon Ave & 79th St',
#  'Vincennes Ave & 104th St',
#  'Vincennes Ave & 75th St',
#  'Virginia Ave & Catalpa Ave',
#  'W 103rd St & S Avers Ave',
#  'W Armitage Ave & N Sheffield Ave',
#  'W Oakdale Ave & N Broadway',
#  'W Washington Blvd & N Peoria St',
#  'WEST CHI-WATSON',
#  'Wabash Ave & 16th St',
#  'Wabash Ave & 83rd St',
#  'Wabash Ave & 87th St',
#  'Wabash Ave & 9th St',
#  'Wabash Ave & Adams St',
#  'Wabash Ave & Cermak Rd',
#  'Wabash Ave & Grand Ave',
#  'Wabash Ave & Roosevelt Rd',
#  'Wabash Ave & Wacker Pl',
#  'Wacker Dr & Washington St',
#  'Walden Pkwy & 100th St',
#  'Wallace St & 35th St',
#  'Walsh Park',
#  'Warren Park East',
#  'Warren Park West',
#  'Washtenaw Ave & Lawrence Ave',
#  'Washtenaw Ave & Madison St',
#  'Washtenaw Ave & Ogden Ave',
#  'Washtenaw Ave & Peterson Ave',
#  'Washtenaw Ave & Polk St',
#  'Wells St & 19th St',
#  'Wells St & Concord Ln',
#  'Wells St & Elm St',
#  'Wells St & Evergreen Ave',
#  'Wells St & Hubbard St',
#  'Wells St & Huron St',
#  'Wells St & Polk St',
#  'Wells St & Walton St',
#  'Wentworth Ave & 104th St',
#  'Wentworth Ave & 24th St (Temp)',
#  'Wentworth Ave & 33rd St',
#  'Wentworth Ave & 35th St',
#  'Wentworth Ave & 63rd St',
#  'Wentworth Ave & Cermak Rd',
#  'Western & 28th - Velasquez Institute Vaccination Site',
#  'Western Ave & 104th St',
#  'Western Ave & 111th St',
#  'Western Ave & 21st St',
#  'Western Ave & 24th St',
#  'Western Ave & 62nd St',
#  'Western Ave & Ardmore Ave',
#  'Western Ave & Congress Pkwy',
#  'Western Ave & Division St',
#  'Western Ave & Fillmore St',
#  'Western Ave & Grace St',
#  'Western Ave & Granville Ave',
#  'Western Ave & Gunnison St',
#  'Western Ave & Howard St',
#  'Western Ave & Lake St',
#  'Western Ave & Leland Ave',
#  'Western Ave & Lunt Ave',
#  'Western Ave & Monroe St',
#  'Western Ave & Roscoe St',
#  'Western Ave & Walton St',
#  'Western Ave & Winnebago Ave',
#  'Western Blvd & 48th Pl',
#  'Whipple St & Roosevelt Rd',
#  'Whipple/Irving Park',
#  'Wilton Ave & Belmont Ave',
#  'Wilton Ave & Diversey Pkwy',
#  'Wilton Ave & Diversey Pkwy - Charging',
#  'Winchester (Ravenswood) Ave & Balmoral Ave',
#  'Winchester Ave & Elston Ave',
#  'Winthrop Ave & Lawrence Ave',
#  'Wolcott (Ravenswood) Ave & Montrose Ave',
#  'Wolcott Ave & Fargo Ave',
#  'Wolcott Ave & Polk St',
#  'Wood St & 35th St',
#  'Wood St & Augusta Blvd',
#  'Wood St & Chicago Ave',
#  'Wood St & Hubbard St',
#  'Wood St & Milwaukee Ave',
#  'Wood St & Taylor St (Temp)',
#  'Woodlawn & 103rd - Olive Harvey Vaccination Site',
#  'Woodlawn Ave & 55th St',
#  'Woodlawn Ave & 75th St',
#  'Woodlawn Ave & Lake Park Ave',
#  'Yates Blvd & 75th St',
#  'Yates Blvd & 93rd St']

# %%
sorted(list(set(df_all['end_station_name'].values)))
# Out:
# ['2112 W Peterson Ave',
#  '63rd St Beach',
#  '900 W Harrison St',
#  'Aberdeen St & Jackson Blvd',
#  'Aberdeen St & Monroe St',
#  'Aberdeen St & Randolph St',
#  'Ada St & 113th St',
#  'Ada St & Washington Blvd',
#  'Adler Planetarium',
#  'Albany Ave & 26th St',
#  'Albany Ave & Belmont Ave',
#  'Albany Ave & Bloomingdale Ave',
#  'Albany Ave & Montrose Ave',
#  'Altgeld Gardens',
#  'Archer (Damen) Ave & 37th St',
#  'Archer Ave & 43rd St',
#  'Artesian Ave & 55th St',
#  'Artesian Ave & Hubbard St',
#  'Ashland Ave & 13th St',
#  'Ashland Ave & 50th St',
#  'Ashland Ave & 63rd St',
#  'Ashland Ave & 66th St',
#  'Ashland Ave & 74th St',
#  'Ashland Ave & 78th St',
#  'Ashland Ave & Archer Ave',
#  'Ashland Ave & Augusta Blvd',
#  'Ashland Ave & Belle Plaine Ave',
#  'Ashland Ave & Blackhawk St',
#  'Ashland Ave & Chicago Ave',
#  'Ashland Ave & Division St',
#  'Ashland Ave & Garfield Blvd',
#  'Ashland Ave & Grace St',
#  'Ashland Ave & Grand Ave',
#  'Ashland Ave & Lake St',
#  'Ashland Ave & McDowell Ave',
#  'Ashland Ave & Pershing Rd',
#  'Ashland Ave & Wellington Ave',
#  'Ashland Ave & Wrightwood Ave',
#  'Augusta Blvd & Laramie Ave',
#  'Austin Blvd & Chicago Ave',
#  'Austin Blvd & Lake St',
#  'Austin Blvd & Madison St',
#  'Avenue L & 114th St',
#  'Avenue O & 118th St',
#  'Avenue O & 134th St',
#  'Avers Ave & Belmont Ave',
#  'Avondale Ave & Irving Park Rd',
#  'Baltimore Ave & 87th St',
#  'Base - 2132 W Hubbard Warehouse',
#  'Bennett Ave & 79th St',
#  'Benson Ave & Church St',
#  'Bernard St & Elston Ave',
#  'Big Marsh Park',
#  'Bissell St & Armitage Ave',
#  'Blackstone Ave & Hyde Park Blvd',
#  'Bloomingdale Ave & Harlem Ave',
#  'Blue Island Ave & 18th St',
#  'Bosworth Ave & Howard St',
#  'Bradley Park',
#  'Broadway & Argyle St',
#  'Broadway & Barry Ave',
#  'Broadway & Belmont Ave',
#  'Broadway & Berwyn Ave',
#  'Broadway & Cornelia Ave',
#  'Broadway & Granville Ave',
#  'Broadway & Ridge Ave',
#  'Broadway & Sheridan Rd',
#  'Broadway & Thorndale Ave',
#  'Broadway & Waveland Ave',
#  'Broadway & Wilson - Truman College Vaccination Site',
#  'Buckingham Fountain',
#  'Budlong Woods Library',
#  'Burling St & Diversey Pkwy',
#  'Burnham Greenway & 105th St',
#  'Burnham Greenway & 112th St',
#  'Burnham Harbor',
#  'California & 16th St',
#  'California Ave & 21st St',
#  'California Ave & 23rd Pl',
#  'California Ave & 26th St',
#  'California Ave & 29th St',
#  'California Ave & 36th St',
#  'California Ave & Altgeld St',
#  'California Ave & Byron St',
#  'California Ave & Cortez St',
#  'California Ave & Division St',
#  'California Ave & Fletcher St',
#  'California Ave & Francis Pl (Temp)',
#  'California Ave & Lake St',
#  'California Ave & Marquette Rd',
#  'California Ave & Milwaukee Ave',
#  'California Ave & Montrose Ave',
#  'California Ave & North Ave',
#  'California Ave & Winona St',
#  'Calumet Ave & 18th St',
#  'Calumet Ave & 21st St',
#  'Calumet Ave & 33rd St',
#  'Calumet Ave & 35th St',
#  'Calumet Ave & 51st St',
#  'Calumet Ave & 71st St',
#  'Calumet Park',
#  'Campbell Ave & 51st St',
#  'Campbell Ave & Fullerton Ave',
#  'Campbell Ave & Montrose Ave',
#  'Campbell Ave & North Ave',
#  'Canal St & Adams St',
#  'Canal St & Harrison St',
#  'Canal St & Jackson Blvd',
#  'Canal St & Madison St',
#  'Canal St & Monroe St',
#  'Canal St & Taylor St',
#  'Cannon Dr & Fullerton Ave',
#  'Carpenter St & 63rd St',
#  'Carpenter St & Huron St',
#  'Central Ave & Chicago Ave',
#  'Central Ave & Harrison St',
#  'Central Ave & Lake St',
#  'Central Ave & Madison St',
#  'Central Ave & Parker Ave',
#  'Central Ave & Roscoe St',
#  'Central Park & Augusta Blvd',
#  'Central Park Ave & 24th St',
#  'Central Park Ave & Bloomingdale Ave',
#  'Central Park Ave & Douglas Blvd',
#  'Central Park Ave & Elbridge Ave',
#  'Central Park Ave & North Ave',
#  'Central Park Ave & Ogden Ave',
#  'Central Park Ave & Ohio St',
#  'Central Park Blvd & 5th Ave',
#  'Central St & Girard Ave',
#  'Central St Metra',
#  'Cherry Ave & Blackhawk St',
#  'Chicago Ave & Sheridan Rd',
#  'Chicago Ave & Washington St',
#  'Chicago State University',
#  'Christiana Ave & Lawrence Ave',
#  'Cicero Ave & Flournoy St',
#  'Cicero Ave & Grace St',
#  'Cicero Ave & Lake St',
#  'Cicero Ave & Quincy St',
#  'Cityfront Plaza Dr & Pioneer Ct',
#  'Claremont Ave & Hirsch St',
#  'Clarendon Ave & Gordon Ter',
#  'Clarendon Ave & Junior Ter',
#  'Clarendon Ave & Leland Ave',
#  'Clark St & 9th St (AMLI)',
#  'Clark St & Armitage Ave',
#  'Clark St & Berwyn Ave',
#  'Clark St & Bryn Mawr Ave',
#  'Clark St & Chicago Ave',
#  'Clark St & Columbia Ave',
#  'Clark St & Drummond Pl',
#  'Clark St & Elm St',
#  'Clark St & Elmdale Ave',
#  'Clark St & Grace St',
#  'Clark St & Ida B Wells Dr',
#  'Clark St & Jarvis Ave',
#  'Clark St & Lake St',
#  'Clark St & Leland Ave',
#  'Clark St & Lincoln Ave',
#  'Clark St & Lunt Ave',
#  'Clark St & Montrose Ave',
#  'Clark St & Newport St',
#  'Clark St & North Ave',
#  'Clark St & Randolph St',
#  'Clark St & Schiller St',
#  'Clark St & Schreiber Ave',
#  'Clark St & Touhy Ave',
#  'Clark St & Wellington Ave',
#  'Clark St & Winnemac Ave',
#  'Clark St & Wrightwood Ave',
#  'Clifton Ave & Armitage Ave',
#  'Clinton St & 18th St',
#  'Clinton St & Jackson Blvd',
#  'Clinton St & Lake St',
#  'Clinton St & Madison St',
#  'Clinton St & Polk St',
#  'Clinton St & Roosevelt Rd',
#  'Clinton St & Tilden St',
#  'Clinton St & Washington Blvd',
#  'Clybourn Ave & Division St',
#  'Clyde Ave & 87th St',
#  'Columbus Dr & Randolph St',
#  'Commercial Ave & 100th St',
#  'Commercial Ave & 130th St',
#  'Commercial Ave & 83rd St',
#  'Conservatory Dr & Lake St',
#  'Constance Ave & 95th St',
#  'Cornell Ave & Hyde Park Blvd',
#  'Cornell Dr & Hayes Dr',
#  'Cottage Grove Ave & 111th Pl',
#  'Cottage Grove Ave & 43rd St',
#  'Cottage Grove Ave & 47th St',
#  'Cottage Grove Ave & 51st St',
#  'Cottage Grove Ave & 63rd St',
#  'Cottage Grove Ave & 67th St',
#  'Cottage Grove Ave & 71st St',
#  'Cottage Grove Ave & 78th St',
#  'Cottage Grove Ave & 83rd St',
#  'Cottage Grove Ave & Oakwood Blvd',
#  'DIVVY CASSETTE REPAIR MOBILE STATION',
#  'Daley Center Plaza',
#  'Damen Ave & 33rd St',
#  'Damen Ave & 51st St',
#  'Damen Ave & 59th St',
#  'Damen Ave & Charleston St',
#  'Damen Ave & Chicago Ave',
#  'Damen Ave & Clybourn Ave',
#  'Damen Ave & Cortland St',
#  'Damen Ave & Coulter St',
#  'Damen Ave & Cullerton St',
#  'Damen Ave & Division St',
#  'Damen Ave & Foster Ave',
#  'Damen Ave & Grand Ave',
#  'Damen Ave & Leland Ave',
#  'Damen Ave & Madison St',
#  'Damen Ave & Melrose Ave',
#  'Damen Ave & Pershing Rd',
#  'Damen Ave & Pierce Ave',
#  'Damen Ave & Sunnyside Ave',
#  'Damen Ave & Thomas St (Augusta Blvd)',
#  'Damen Ave & Wabansia Ave',
#  'Damen Ave & Walnut (Lake) St',
#  'Damen Ave & Wellington Ave',
#  'Dauphin Ave & 103rd St',
#  'Dauphin Ave & 87th St',
#  'Dayton St & North Ave',
#  'Dearborn Pkwy & Delaware Pl',
#  'Dearborn St & Adams St',
#  'Dearborn St & Erie St',
#  'Dearborn St & Monroe St',
#  'Dearborn St & Van Buren St',
#  'Delano Ct & Roosevelt Rd',
#  'Desplaines St & Jackson Blvd',
#  'Desplaines St & Kinzie St',
#  'Desplaines St & Randolph St',
#  'Dodge Ave & Church St',
#  'Dodge Ave & Main St',
#  'Dodge Ave & Mulford St',
#  'Dorchester Ave & 49th St',
#  'Dorchester Ave & 63rd St',
#  'Doty Ave & 111th St',
#  'Drake Ave & Addison St',
#  'Drake Ave & Montrose Ave',
#  'DuSable Lake Shore Dr & Belmont Ave',
#  'DuSable Lake Shore Dr & Diversey Pkwy',
#  'DuSable Lake Shore Dr & Monroe St',
#  'DuSable Lake Shore Dr & North Blvd',
#  'DuSable Lake Shore Dr & Ohio St',
#  'DuSable Lake Shore Dr & Wellington Ave',
#  'DuSable Museum',
#  'Dusable Harbor',
#  'East End Ave & 87th St',
#  'Eastlake Ter & Rogers Ave',
#  'Eberhart Ave & 131st St',
#  'Eberhart Ave & 61st St',
#  'Eberhart Ave & 91st St',
#  'Eckhart Park',
#  'Eggleston Ave & 69th St',
#  'Eggleston Ave & 92nd St',
#  'Elizabeth (May) St & Fulton St',
#  'Elizabeth St & 47th St',
#  'Elizabeth St & 59th St',
#  'Elizabeth St & 92nd St',
#  'Ellis Ave & 53rd St',
#  'Ellis Ave & 55th St',
#  'Ellis Ave & 58th St',
#  'Ellis Ave & 60th St',
#  'Ellis Ave & 83rd St',
#  'Elmwood Ave & Austin St',
#  'Elston Ave & Cortland St',
#  'Elston Ave & George St',
#  'Elston Ave & Henderson St',
#  'Elston Ave & Wabansia Ave',
#  'Emerald Ave & 28th St',
#  'Emerald Ave & 31st St',
#  'Evans Ave & 75th St',
#  'Evanston Civic Center',
#  'Ewing Ave & Burnham Greenway',
#  'Exchange Ave & 79th St',
#  'Fairbanks Ct & Grand Ave',
#  'Fairbanks St & Superior St',
#  'Fairfield Ave & 44th St',
#  'Fairfield Ave & Roosevelt Rd',
#  'Federal St & Polk St',
#  'Field Blvd & South Water St',
#  'Field Museum',
#  'Financial Pl & Ida B Wells Dr',
#  'Fort Dearborn Dr & 31st St',
#  'Francisco Ave & 47th St',
#  'Francisco Ave & Bloomingdale Ave',
#  'Francisco Ave & Foster Ave',
#  'Francisco Ave & Hollywood Ave',
#  'Francisco Ave & Montrose Ave',
#  'Franklin St & Adams St (Temp)',
#  'Franklin St & Chicago Ave',
#  'Franklin St & Illinois St',
#  'Franklin St & Jackson Blvd',
#  'Franklin St & Lake St',
#  'Franklin St & Monroe St',
#  'Fullerton & Monitor',
#  'Glenwood Ave & Morse Ave',
#  'Glenwood Ave & Touhy Ave',
#  'Green St & Madison St',
#  'Green St & Randolph St',
#  'Greenview Ave & Diversey Pkwy',
#  'Greenview Ave & Fullerton Ave',
#  'Greenview Ave & Jarvis Ave',
#  'Greenwood Ave & 47th St',
#  'Greenwood Ave & 79th St',
#  'Greenwood Ave & 91st St',
#  'Greenwood Ave & 97th St',
#  'Hale Ave & 107th St',
#  'Halsted & 63rd - Kennedy-King Vaccination Site',
#  'Halsted St & 104th St',
#  'Halsted St & 111th St',
#  'Halsted St & 18th St',
#  'Halsted St & 18th St (Temp)',
#  'Halsted St & 21st St',
#  'Halsted St & 35th St',
#  'Halsted St & 37th St',
#  'Halsted St & 47th Pl',
#  'Halsted St & 51st St',
#  'Halsted St & 56th St',
#  'Halsted St & 59th St',
#  'Halsted St & 69th St',
#  'Halsted St & 73rd St',
#  'Halsted St & 78th St',
#  'Halsted St & 96th St',
#  'Halsted St & Archer Ave',
#  'Halsted St & Clybourn Ave',
#  'Halsted St & Dickens Ave',
#  'Halsted St & Maxwell St',
#  'Halsted St & North Branch St',
#  'Halsted St & Polk St',
#  'Halsted St & Roosevelt Rd',
#  'Halsted St & Roscoe St',
#  'Halsted St & Willow St',
#  'Halsted St & Wrightwood Ave',
#  'Hamlin Ave & 62nd Pl',
#  'Hampden Ct & Diversey Ave',
#  'Harding Ave & 26th St',
#  'Harlem & Irving Park',
#  'Harlem Ave & Grace St',
#  'Harper Ave & 59th St',
#  'Hastings WH 2',
#  'Hegewisch Metra Station',
#  'Hermitage Ave & Polk St',
#  'Homan Ave & Fillmore St',
#  'Homewood Ave & 115th St',
#  'Honore St & Division St',
#  'Houston Ave & 92nd St',
#  'Hoyne Ave & 34th St',
#  'Hoyne Ave & 47th St',
#  'Hoyne Ave & Balmoral Ave',
#  'Humboldt Blvd & Armitage Ave',
#  'Indiana Ave & 103rd St',
#  'Indiana Ave & 133rd St',
#  'Indiana Ave & 26th St',
#  'Indiana Ave & 31st St',
#  'Indiana Ave & 40th St',
#  'Indiana Ave & Roosevelt Rd',
#  'Jefferson St & Monroe St',
#  'Jeffery Blvd & 67th St',
#  'Jeffery Blvd & 71st St',
#  'Jeffery Blvd & 76th St',
#  'Karlov Ave & Madison St',
#  'Kedzie Ave & 104th St',
#  'Kedzie Ave & 110th St',
#  'Kedzie Ave & 21st St',
#  'Kedzie Ave & 24th St',
#  'Kedzie Ave & 45th St',
#  'Kedzie Ave & 48th Pl',
#  'Kedzie Ave & 52nd St',
#  'Kedzie Ave & 57th St',
#  'Kedzie Ave & Bryn Mawr Ave',
#  'Kedzie Ave & Chicago Ave',
#  'Kedzie Ave & Foster Ave',
#  'Kedzie Ave & George St',
#  'Kedzie Ave & Harrison St',
#  'Kedzie Ave & Lake St',
#  'Kedzie Ave & Leland Ave',
#  'Kedzie Ave & Milwaukee Ave',
#  'Kedzie Ave & Palmer Ct',
#  'Kedzie Ave & Roosevelt Rd',
#  'Keeler Ave & Roosevelt Rd',
#  'Kenneth Ave & 50th St',
#  'Kenosha & Wellington',
#  'Kenton Ave & Madison St',
#  'Keystone Ave & Fullerton Ave',
#  'Keystone Ave & Montrose Ave',
#  'Kilbourn & Belden',
#  'Kilbourn & Roscoe',
#  'Kilbourn Ave & Irving Park Rd',
#  'Kilbourn Ave & Milwaukee Ave',
#  'Kildare Ave & 26th St',
#  'Kildare Ave & 55th St',
#  'Kildare Ave & Chicago Ave',
#  'Kildare Ave & Division St',
#  'Kildare Ave & Montrose Ave',
#  'Kilpatrick Ave & Grand Ave',
#  'Kilpatrick Ave & Parker Ave',
#  'Kimball Ave & Belmont Ave',
#  'Kimbark Ave & 53rd St',
#  'Kingsbury St & Erie St',
#  'Kingsbury St & Kinzie St',
#  'Knox Ave & Montrose Ave',
#  'Komensky Ave & 31st St',
#  'Komensky Ave & 55th St',
#  'Kosciuszko Park',
#  'Kostner Ave & 63rd St',
#  'Kostner Ave & Adams St',
#  'Kostner Ave & Lake St',
#  'Kostner Ave & Wrightwood Ave',
#  'LaSalle Dr & Huron St',
#  'LaSalle St & Adams St',
#  'LaSalle St & Illinois St',
#  'LaSalle St & Jackson Blvd',
#  'LaSalle St & Washington St',
#  'Laflin St & Cullerton St',
#  'Lake Park Ave & 35th St',
#  'Lake Park Ave & 47th St',
#  'Lake Park Ave & 53rd St',
#  'Lake Park Ave & 56th St',
#  'Lake Shore Dr & Belmont Ave',
#  'Lake Shore Dr & Diversey Pkwy',
#  'Lake Shore Dr & Monroe St',
#  'Lake Shore Dr & North Blvd',
#  'Lake Shore Dr & Ohio St',
#  'Lake Shore Dr & Wellington Ave',
#  'Lakefront Trail & Bryn Mawr Ave',
#  'Lakefront Trail & Wilson Ave',
#  'Lakeview Ave & Fullerton Pkwy',
#  'Lamon Ave & Armitage Ave',
#  'Lamon Ave & Belmont Ave',
#  'Lamon Ave & Chicago Ave',
#  'Laramie Ave & Gladys Ave',
#  'Laramie Ave & Kinzie St',
#  'Laramie Ave & Madison St',
#  'Larrabee St & Armitage Ave',
#  'Larrabee St & Division St',
#  'Larrabee St & Kingsbury St',
#  'Larrabee St & Menomonee St',
#  'Larrabee St & North Ave',
#  'Larrabee St & Oak St',
#  'Larrabee St & Webster Ave',
#  'Latrobe Ave & Chicago Ave',
#  'Lavergne & Fullerton',
#  'Lavergne Ave & 46th St',
#  'Lavergne Ave & Division St',
#  'Lawler Ave & 50th St',
#  'Lawndale Ave & 111th St',
#  'Lawndale Ave & 16th St',
#  'Lawndale Ave & 30th St',
#  'Leamington Ave & Hirsch St',
#  'Leavitt St & Addison St',
#  'Leavitt St & Archer Ave',
#  'Leavitt St & Armitage Ave',
#  'Leavitt St & Belmont Ave',
#  'Leavitt St & Chicago Ave',
#  'Leavitt St & Division St',
#  'Leavitt St & Lawrence Ave',
#  'Leavitt St & North Ave',
#  'Lincoln Ave & Addison St',
#  'Lincoln Ave & Balmoral Ave',
#  'Lincoln Ave & Belle Plaine Ave',
#  'Lincoln Ave & Belmont Ave',
#  'Lincoln Ave & Diversey Pkwy',
#  'Lincoln Ave & Fullerton Ave',
#  'Lincoln Ave & Peterson Ave',
#  'Lincoln Ave & Roscoe St',
#  'Lincoln Ave & Roscoe St - Charging',
#  'Lincoln Ave & Sunnyside Ave',
#  'Lincoln Ave & Waveland Ave',
#  'Lincoln Ave & Winona St',
#  'Lincoln Park Conservatory',
#  'Lincolnwood Dr & Central St',
#  'Lockwood Ave & Wrightwood Ave',
#  'Logan Blvd & Elston Ave',
#  'Long & Irving Park',
#  'Long Ave & Belden Ave',
#  'Long Ave & Belmont Ave',
#  'Long Ave & North Ave',
#  'Loomis Blvd & 84th St',
#  'Loomis St & 89th St',
#  'Loomis St & Archer Ave',
#  'Loomis St & Jackson Blvd',
#  'Loomis St & Lexington St',
#  'MLK Jr Dr & 29th St',
#  'MLK Jr Dr & 47th St',
#  'MLK Jr Dr & 56th St',
#  'MLK Jr Dr & 63rd St',
#  'MLK Jr Dr & 83rd St',
#  'MLK Jr Dr & Pershing Rd',
#  'Major Ave & Bloomingdale Ave',
#  'Major Taylor Trail & 115th St',
#  'Major Taylor Trail & 124th St',
#  'Malcolm X College Vaccination Site',
#  'Manor Ave & Leland Ave',
#  'Maplewood Ave & 59th St',
#  'Maplewood Ave & Peterson Ave',
#  'Marine Dr & Ainslie St',
#  'Marquette Ave & 89th St',
#  'Marshfield Ave & 44th St',
#  'Marshfield Ave & 59th St',
#  'Marshfield Ave & Cortland St',
#  'Maryland Ave & 104th St',
#  'Mason Ave & Belmont Ave',
#  'May St & 69th St',
#  'May St & Cullerton St',
#  'May St & Taylor St',
#  'Mayfield & Roosevelt Rd',
#  'McClurg Ct & Erie St',
#  'McClurg Ct & Ohio St',
#  'McCormick Place',
#  'Meade Ave & Addison St',
#  'Meade Ave & Diversey Ave',
#  'Menard Ave & Division St',
#  'Menard Ave & North Ave',
#  'Michigan Ave & 114th St',
#  'Michigan Ave & 14th St',
#  'Michigan Ave & 18th St',
#  'Michigan Ave & 71st St',
#  'Michigan Ave & 8th St',
#  'Michigan Ave & Ida B Wells Dr',
#  'Michigan Ave & Jackson Blvd',
#  'Michigan Ave & Lake St',
#  'Michigan Ave & Madison St',
#  'Michigan Ave & Oak St',
#  'Michigan Ave & Pearson St',
#  'Michigan Ave & Washington St',
#  'Mies van der Rohe Way & Chestnut St',
#  'Mies van der Rohe Way & Chicago Ave',
#  'Millard Ave & 26th St',
#  'Millennium Park',
#  'Milwaukee Ave & Cuyler Ave',
#  'Milwaukee Ave & Fullerton Ave',
#  'Milwaukee Ave & Grand Ave',
#  'Milwaukee Ave & Rockwell St',
#  'Milwaukee Ave & Wabansia Ave',
#  'Monticello Ave & Chicago Ave',
#  'Monticello Ave & Irving Park Rd',
#  'Montrose Harbor',
#  'Morgan Ave & 14th Pl',
#  'Morgan St & 18th St',
#  'Morgan St & 31st St',
#  'Morgan St & Lake St',
#  'Morgan St & Pershing Rd',
#  'Morgan St & Polk St',
#  'Mozart St & Jackson Blvd',
#  'Mulligan Ave & Wellington Ave',
#  'Museum of Science and Industry',
#  'N Carpenter St & W Lake St',
#  'N Clark St & W Elm St',
#  'N Damen Ave & W Chicago Ave',
#  'N Damen Ave & W Wabansia St',
#  'N Green St & W Lake St',
#  'N Paulina St & Lincoln Ave',
#  'N Sheffield Ave & W Wellington Ave',
#  'N Shore Channel Trail & Argyle Ave',
#  'N Shore Channel Trail & Argyle St',
#  'N Southport Ave & W Newport Ave',
#  'Narragansett & Irving Park',
#  'Narragansett & McLean',
#  'Narragansett & Wrightwood',
#  'Narragansett Ave & School St',
#  'New St & Illinois St',
#  'Noble St & Milwaukee Ave',
#  'Nordica & Medill',
#  'Normal Ave & Archer Ave',
#  'North Ave & New England Ave',
#  'Oak Park & Wellington',
#  'Oakley Ave & Irving Park Rd',
#  'Oakley Ave & Touhy Ave',
#  'Ogden Ave & Chicago Ave',
#  'Ogden Ave & Congress Pkwy',
#  'Ogden Ave & Race Ave',
#  'Ogden Ave & Roosevelt Rd',
#  'Oglesby Ave & 100th St',
#  'Oketo Ave & Addison St',
#  'Olive Harvey College',
#  'Orange & Addison',
#  'Orleans St & Chestnut St (NEXT Apts)',
#  'Orleans St & Elm St',
#  'Orleans St & Hubbard St',
#  'Orleans St & Merchandise Mart Plaza',
#  'Panama Ave & Grace St',
#  'Parkside Ave & Armitage Ave',
#  'Paulina Ave & North Ave',
#  'Paulina St & 18th St',
#  'Paulina St & Flournoy St',
#  'Paulina St & Howard St',
#  'Paulina St & Montrose Ave',
#  'Pawel Bialowas - Test- PBSC charging station',
#  'Peoria St & Jackson Blvd',
#  'Perry Ave & 69th St',
#  'Phillips Ave & 79th St',
#  'Phillips Ave & 83rd St',
#  'Pine Grove Ave & Irving Park Rd',
#  'Pine Grove Ave & Waveland Ave',
#  'Ping Tom Park (East)',
#  'Plainfield & Irving Park',
#  'Prairie Ave & 43rd St',
#  'Prairie Ave & Garfield Blvd',
#  'Princeton Ave & 47th St',
#  'Princeton Ave & Garfield Blvd',
#  'Prospect Sq & 91st St',
#  'Pulaski & Ann Lurie Pl',
#  'Pulaski Rd & 21st St',
#  'Pulaski Rd & 51st St',
#  'Pulaski Rd & 60th St',
#  'Pulaski Rd & Congress Pkwy',
#  'Pulaski Rd & Eddy St (Temp)',
#  'Pulaski Rd & Lake St',
#  'Racine Ave & 13th St',
#  'Racine Ave & 15th St',
#  'Racine Ave & 18th St',
#  'Racine Ave & 35th St',
#  'Racine Ave & 61st St',
#  'Racine Ave & 65th St',
#  'Racine Ave & Belmont Ave',
#  'Racine Ave & Congress Pkwy',
#  'Racine Ave & Fullerton Ave',
#  'Racine Ave & Garfield Blvd',
#  'Racine Ave & Randolph St',
#  'Racine Ave & Washington Blvd',
#  'Racine Ave & Wrightwood Ave',
#  'Rainbow Beach',
#  'Ravenswood Ave & Berteau Ave',
#  'Ravenswood Ave & Irving Park Rd',
#  'Ravenswood Ave & Lawrence Ave',
#  'Rhodes Ave & 32nd St',
#  'Rhodes Ave & 71st St',
#  'Richmond St & 59th St',
#  'Richmond St & Diversey Ave',
#  'Richmond St & Lincoln Ave',
#  'Ridge Blvd & Howard St',
#  'Ridge Blvd & Touhy Ave',
#  'Ritchie Ct & Banks St',
#  'Rockwell St & 57th St',
#  'Rockwell St & Archer Ave',
#  'Rockwell St & Cermak Rd',
#  'Rockwell St & Eastwood Ave',
#  'Rockwell St & Fletcher St',
#  'Roscoe & Harlem',
#  'Rush St & Cedar St',
#  'Rush St & Hubbard St',
#  'Rush St & Superior St',
#  'S Aberdeen St & W 106th St',
#  'S Michigan Ave & E 118th St',
#  'S Wentworth Ave & W 111th St',
#  'Sacramento Ave & 25th St',
#  'Sacramento Ave & Pershing Rd',
#  'Sacramento Blvd & Addison St',
#  'Sacramento Blvd & Franklin Blvd',
#  'Sacramento Blvd & Fulton Ave',
#  'Sacramento Blvd & Polk St',
#  'Sangamon St & Washington Blvd',
#  'Sawyer Ave & Irving Park Rd',
#  'Sayre & Diversey',
#  'Sedgwick St & Huron St',
#  'Sedgwick St & North Ave',
#  'Sedgwick St & Schiller St',
#  'Sedgwick St & Webster Ave',
#  'Seeley Ave & Garfield Blvd',
#  'Seeley Ave & Roscoe St',
#  'Shedd Aquarium',
#  'Sheffield Ave & Fullerton Ave',
#  'Sheffield Ave & Kingsbury St',
#  'Sheffield Ave & Waveland Ave',
#  'Sheffield Ave & Webster Ave',
#  'Sheffield Ave & Wellington Ave',
#  'Sheffield Ave & Willow St',
#  'Sheffield Ave & Wrightwood Ave',
#  'Sheridan Rd & Buena Ave',
#  'Sheridan Rd & Columbia Ave',
#  'Sheridan Rd & Greenleaf Ave',
#  'Sheridan Rd & Irving Park Rd',
#  'Sheridan Rd & Lawrence Ave',
#  'Sheridan Rd & Loyola Ave',
#  'Sheridan Rd & Montrose Ave',
#  'Sheridan Rd & Noyes St (NU)',
#  'Shields Ave & 28th Pl',
#  'Shields Ave & 31st St',
#  'Shields Ave & 43rd St',
#  'Shore Dr & 55th St',
#  'Smith Park',
#  'South Chicago Ave & 83rd St',
#  'South Chicago Ave & Elliot Ave',
#  'South Shore Dr & 67th St',
#  'South Shore Dr & 71st St',
#  'South Shore Dr & 74th St',
#  'Southport Ave & Belmont Ave',
#  'Southport Ave & Clark St',
#  'Southport Ave & Clybourn Ave',
#  'Southport Ave & Irving Park Rd',
#  'Southport Ave & Roscoe St',
#  'Southport Ave & Waveland Ave',
#  'Southport Ave & Wellington Ave',
#  'Southport Ave & Wrightwood Ave',
#  'Spaulding Ave & 16th St',
#  'Spaulding Ave & 63rd St',
#  'Spaulding Ave & Armitage Ave',
#  'Spaulding Ave & Division St',
#  'Springfield Ave & 47th St',
#  'St Louis Ave & 59th St',
#  'St Louis Ave & Norman Bobbins Ave',
#  'St. Clair St & Erie St',
#  'St. Louis Ave & Balmoral Ave',
#  'St. Louis Ave & Fullerton Ave',
#  'State St & 123rd St',
#  'State St & 19th St',
#  'State St & 29th St',
#  'State St & 33rd St',
#  'State St & 35th St',
#  'State St & 54th St',
#  'State St & 76th St',
#  'State St & 79th St',
#  'State St & 95th St',
#  'State St & Chicago Ave',
#  'State St & Harrison St',
#  'State St & Kinzie St',
#  'State St & Pearson St',
#  'State St & Pershing Rd',
#  'State St & Randolph St',
#  'State St & Van Buren St',
#  'Stave St & Armitage Ave',
#  'Stetson Ave & South Water St',
#  'Stewart Ave & 63rd St',
#  'Stewart Ave & 83rd St',
#  'Stockton Dr & Wrightwood Ave',
#  'Stony Island Ave & 64th St',
#  'Stony Island Ave & 67th St',
#  'Stony Island Ave & 71st St',
#  'Stony Island Ave & 75th St',
#  'Stony Island Ave & 82nd St',
#  'Stony Island Ave & 90th St',
#  'Stony Island Ave & South Chicago Ave',
#  'Streeter Dr & Grand Ave',
#  'Summit Ave & 86th St',
#  'Talman Ave & Addison St',
#  'Theater on the Lake',
#  'Throop St & 52nd St',
#  'Throop St & Taylor St',
#  'Throop/Hastings Mobile Station',
#  'Torrence Ave & 106th St',
#  'Torrence Ave & 126th Pl',
#  'Tripp Ave & 15th St',
#  'Tripp Ave & 31st St',
#  'Tripp Ave & 65th St',
#  'Troy St & Elston Ave',
#  'Troy St & Grace St',
#  'Troy St & North Ave',
#  'Union Ave & Root St',
#  'University Ave & 57th St',
#  'University Library (NU)',
#  'Valli Produce - Evanston Plaza',
#  'Vernon Ave & 107th St',
#  'Vernon Ave & 75th St',
#  'Vernon Ave & 79th St',
#  'Vincennes Ave & 104th St',
#  'Vincennes Ave & 75th St',
#  'Virginia Ave & Catalpa Ave',
#  'W 103rd St & S Avers Ave',
#  'W Armitage Ave & N Sheffield Ave',
#  'W Oakdale Ave & N Broadway',
#  'W Washington Blvd & N Peoria St',
#  'WEST CHI-WATSON',
#  'Wabash Ave & 16th St',
#  'Wabash Ave & 83rd St',
#  'Wabash Ave & 87th St',
#  'Wabash Ave & 9th St',
#  'Wabash Ave & Adams St',
#  'Wabash Ave & Cermak Rd',
#  'Wabash Ave & Grand Ave',
#  'Wabash Ave & Roosevelt Rd',
#  'Wabash Ave & Wacker Pl',
#  'Wacker Dr & Washington St',
#  'Walden Pkwy & 100th St',
#  'Wallace St & 35th St',
#  'Walsh Park',
#  'Warren Park East',
#  'Warren Park West',
#  'Washtenaw Ave & Lawrence Ave',
#  'Washtenaw Ave & Madison St',
#  'Washtenaw Ave & Ogden Ave',
#  'Washtenaw Ave & Peterson Ave',
#  'Washtenaw Ave & Polk St',
#  'Wells St & 19th St',
#  'Wells St & Concord Ln',
#  'Wells St & Elm St',
#  'Wells St & Evergreen Ave',
#  'Wells St & Hubbard St',
#  'Wells St & Huron St',
#  'Wells St & Polk St',
#  'Wells St & Walton St',
#  'Wentworth Ave & 104th St',
#  'Wentworth Ave & 24th St (Temp)',
#  'Wentworth Ave & 33rd St',
#  'Wentworth Ave & 35th St',
#  'Wentworth Ave & 63rd St',
#  'Wentworth Ave & Cermak Rd',
#  'Western & 28th - Velasquez Institute Vaccination Site',
#  'Western Ave & 104th St',
#  'Western Ave & 111th St',
#  'Western Ave & 21st St',
#  'Western Ave & 24th St',
#  'Western Ave & 62nd St',
#  'Western Ave & Ardmore Ave',
#  'Western Ave & Congress Pkwy',
#  'Western Ave & Division St',
#  'Western Ave & Fillmore St',
#  'Western Ave & Grace St',
#  'Western Ave & Granville Ave',
#  'Western Ave & Gunnison St',
#  'Western Ave & Howard St',
#  'Western Ave & Lake St',
#  'Western Ave & Leland Ave',
#  'Western Ave & Lunt Ave',
#  'Western Ave & Monroe St',
#  'Western Ave & Roscoe St',
#  'Western Ave & Walton St',
#  'Western Ave & Winnebago Ave',
#  'Western Blvd & 48th Pl',
#  'Whipple St & Irving Park Rd',
#  'Whipple St & Roosevelt Rd',
#  'Whipple/Irving Park',
#  'Wilton Ave & Belmont Ave',
#  'Wilton Ave & Diversey Pkwy',
#  'Wilton Ave & Diversey Pkwy - Charging',
#  'Winchester (Ravenswood) Ave & Balmoral Ave',
#  'Winchester Ave & Elston Ave',
#  'Winthrop Ave & Lawrence Ave',
#  'Wolcott (Ravenswood) Ave & Montrose Ave',
#  'Wolcott Ave & Fargo Ave',
#  'Wolcott Ave & Polk St',
#  'Wood St & 35th St',
#  'Wood St & Augusta Blvd',
#  'Wood St & Chicago Ave',
#  'Wood St & Hubbard St',
#  'Wood St & Milwaukee Ave',
#  'Wood St & Taylor St (Temp)',
#  'Woodlawn & 103rd - Olive Harvey Vaccination Site',
#  'Woodlawn Ave & 55th St',
#  'Woodlawn Ave & 75th St',
#  'Woodlawn Ave & Lake Park Ave',
#  'Yates Blvd & 75th St',
#  'Yates Blvd & 93rd St']

# %% [markdown]
# ***I will save the data to csv so that I don't need to preprocess that all over again just in case. wtf***

# %%
df_all_clean.to_csv('dataset/cleaned-trip-data.csv')
print("cleaned dataframe saved!")
# Out:
# cleaned dataframe saved!

# %% [markdown]
# We already have cleaned the data and prepare the necessary columns that we need for our analysis. Now it's safe to split the data to analyze pattern between the casual riders and member riders.

# %% [markdown]
# ## Step 4: Analyze

# %% [markdown]
# Now we have cleaned our data we can use it to analyze and finding some insights from the data to answer our objectives.

# %% [markdown]
# #### Guiding questions
# 1. How should you organize your data to perform analysis on it?
# 2. Has your data been properly formatted?
# 3. What surprises did you discover in the data?
# 4. What trends or relationships did you find in the data?
# 5. How will these insights help answer your business questions?
#
# #### Key tasks
# 1. Aggregate your data so it’s useful and accessible.
# 2. Organize and format your data.
# 3. Perform calculations.
# 4. Identify trends and relationships.
#
# #### My Answer to the guiding questions and key tasks:
# 1. Creating new columns for ride distance and ride duration
# 2. Yes
# 3. Direct comparison between 2 categories gave 2 most common stations, but after applying behavioural filter (ride distance and ride duration) to the casual dataset 1 station shot the ranking.
# 4. Some are:
#     - Casual riders tend to ride longer than member riders
#     - Casual riders tent to ride farther than member riders
#     - Casual riders that behave similarly with average member riders have 3 most common starting stations
# 5. Marketing team can decide on which places that would potentially convert the most casual riders into member riders

# %% [markdown]
# ### Analysis for each type of riders
# ##### What I have been thinking for this case
# - Check the time usage of each rides
# - Check the distance traveled (https://stackoverflow.com/questions/19412462/getting-distance-between-two-points-based-on-latitude-longitude)
# - Check the most starting station (https://datascientyst.com/get-most-frequent-values-pandas-dataframe/)
# - Check the most ending station
# - Check the the altitude/height of each starting and ending places and also the difference in altitude between those 2 places for each ride because riding in different altitude level may give different feelings, but the data is not exist

# %% [markdown]
# First get the cleaned data

# %%
import pandas as pd

df_all_clean = pd.read_csv('dataset/cleaned-trip-data.csv')

# %%
df_all_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4630225 entries, 0 to 4630224
# Data columns (total 18 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  Unnamed: 0          float64
#  14  clean_started_at    datetime64[ns]
#  15  clean_ended_at      datetime64[ns]
#  16  time_spent          timedelta64[ns]
#  17  distance_in_km      float64
# dtypes: datetime64[ns](2), float64(6), object(9), timedelta64[ns](1)
# memory usage: 800.2+ MB

# %%
# retrieve dataframe for rows of member riders
member = df_all_clean.where(df_all_clean['member_casual'] == 'member').dropna()

# %%
member.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2577769 entries, 6 to 4630224
# Data columns (total 18 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  Unnamed: 0          float64
#  14  clean_started_at    datetime64[ns]
#  15  clean_ended_at      datetime64[ns]
#  16  time_spent          timedelta64[ns]
#  17  distance_in_km      float64
# dtypes: datetime64[ns](2), float64(6), object(9), timedelta64[ns](1)
# memory usage: 373.7+ MB

# %%
# retrieve dataframe for rows of casual riders
casual = df_all_clean.where(df_all_clean['member_casual'] == 'casual').dropna()

# %%
casual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2052456 entries, 0 to 4630222
# Data columns (total 18 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          object
#  3   ended_at            object
#  4   start_station_name  object
#  5   start_station_id    object
#  6   end_station_name    object
#  7   end_station_id      object
#  8   start_lat           float64
#  9   start_lng           float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  Unnamed: 0          float64
#  14  clean_started_at    datetime64[ns]
#  15  clean_ended_at      datetime64[ns]
#  16  time_spent          timedelta64[ns]
#  17  distance_in_km      float64
# dtypes: datetime64[ns](2), float64(6), object(9), timedelta64[ns](1)
# memory usage: 297.5+ MB

# %% [markdown]
# ### Casual Analysis

# %%
casual_time_spent_mean = casual['time_spent'].mean()
casual_time_spent_max = casual['time_spent'].max()
casual_time_spent_min = casual['time_spent'].min()
casual_time_spent_std = casual['time_spent'].std()

print("Casual Rider Time Spent Statistic")
print("Count:", len(casual))
print("Mean:", casual_time_spent_mean)
print("Max:", casual_time_spent_max)
print("Min:", casual_time_spent_min)
print("Std:", casual_time_spent_std)
# Out:
# Casual Rider Time Spent Statistic
# Count: 2052456
# Mean: 0 days 00:32:24.284466025
# Max: 38 days 20:24:09
# Min: 0 days 00:00:00
# Std: 0 days 04:34:16.115614304

# %%
casual.loc[casual['time_spent'] == casual_time_spent_max]
# Out:
#                   ride_id rideable_type           started_at  \
# 1461307  F043F0F6A1AA4F85   docked_bike  2021-06-05 02:27:26
#
#                     ended_at      start_station_name start_station_id  \
# 1461307  2021-07-13 22:51:35  Michigan Ave & Lake St     TA1305000011
#
#                            end_station_name end_station_id  start_lat  \
# 1461307  Malcolm X College Vaccination Site            631  41.886024
#
#          start_lng    end_lat    end_lng member_casual  Unnamed: 0  \
# 1461307 -87.624117  41.877618 -87.673895        casual    595683.0
#
#            clean_started_at      clean_ended_at       time_spent  \
# 1461307 2021-06-05 02:27:26 2021-07-13 22:51:35 38 days 20:24:09
#
#          distance_in_km
# 1461307        4.235945

# %%
casual.loc[casual['time_spent'] == casual_time_spent_min]
# Out:
#                   ride_id  rideable_type           started_at  \
# 208810   6DF29AE1FBE4AEF4    docked_bike  2021-04-25 17:37:07
# 224171   EDB619E8797A7368  electric_bike  2021-04-23 11:30:54
# 742763   262538B35C75FE26   classic_bike  2021-05-14 12:26:57
# 775628   CE18D76DF022BAE5   classic_bike  2021-05-31 02:03:59
# 834096   EEB35F4AB8A6B542    docked_bike  2021-05-23 15:46:20
# 834131   F1CF8D9ED8718F1D  electric_bike  2021-05-25 17:05:11
# 857250   346F78BAF9406CD4   classic_bike  2021-05-22 11:32:44
# 934372   0DE77A10D43D2B3D   classic_bike  2021-05-27 14:51:06
# 1027785  BE185F3203C9B7E1    docked_bike  2021-06-06 21:13:05
# 1068657  0D2FB40F506DBBA0  electric_bike  2021-06-02 20:05:23
# 1160731  972A46A896000D12   classic_bike  2021-06-12 19:31:22
# 1388305  24A320272B352A8B   classic_bike  2021-06-18 19:13:35
# 1451082  059702C43727F9DA  electric_bike  2021-06-24 19:00:36
# 1674611  A8714397CF341E97   classic_bike  2021-07-17 17:13:06
# 1687051  FA4DAC61BD7C4DC8  electric_bike  2021-07-26 09:52:14
# 1770683  80E0F13913F38DFB   classic_bike  2021-07-09 03:12:27
# 1942396  5DCD139957011A31   classic_bike  2021-07-13 16:22:11
# 2086952  D0231786A81FD516   classic_bike  2021-07-25 09:13:18
# 2108478  77BD53CEDEE4E7B1   classic_bike  2021-07-31 22:55:54
# 2286092  FE2F91D8E78B0321   classic_bike  2021-08-28 15:16:45
# 2306158  560DD42224738118   classic_bike  2021-08-30 18:00:25
# 2306646  55DD1A6120FCBD22   classic_bike  2021-08-13 19:54:57
# 2496612  C8605155BD11DC8D   classic_bike  2021-08-08 19:06:56
# 2778661  6DDDE4D93C58C05B   classic_bike  2021-08-19 18:29:43
# 2907358  7B5A0B99271E1DB8   classic_bike  2021-08-13 20:25:56
# 2998442  74BFD8D41928FEAD   classic_bike  2021-09-29 12:00:06
# 3066476  8B8CB2879D0A664F  electric_bike  2021-09-19 22:38:04
# 3254305  17AF3F96D0F4FF45  electric_bike  2021-09-26 12:42:50
# 3272870  6092FF5A8437CB4F   classic_bike  2021-09-01 17:06:24
# 3285525  7E8BDEE052DDB6B9   classic_bike  2021-09-28 17:39:07
# 3478019  0C32DAA0DDCAA66B  electric_bike  2021-09-05 15:16:10
# 3821622  5537F3D604ED21B5   classic_bike  2021-10-09 11:10:47
# 4009788  74F046B581DC3225   classic_bike  2021-10-09 14:58:03
# 4580966  2CF1A9AEEB7A2BC1  electric_bike  2022-02-17 09:39:01
#
#                     ended_at              start_station_name start_station_id  \
# 208810   2021-04-25 17:37:07          Wabash Ave & Wacker Pl     TA1307000131
# 224171   2021-04-23 11:30:54            Clinton St & Lake St            13021
# 742763   2021-05-14 12:26:57              Shore Dr & 55th St     TA1308000009
# 775628   2021-05-31 02:03:59            Broadway & Barry Ave            13137
# 834096   2021-05-23 15:46:20         Bernard St & Elston Ave            18016
# 834131   2021-05-25 17:05:11            McClurg Ct & Erie St     KA1503000041
# 857250   2021-05-22 11:32:44                  Shedd Aquarium            15544
# 934372   2021-05-27 14:51:06     Lincoln Ave & Fullerton Ave     TA1309000058
# 1027785  2021-06-06 21:13:05            Broadway & Argyle St            13108
# 1068657  2021-06-02 20:05:23               Adler Planetarium            13431
# 1160731  2021-06-12 19:31:22          Leavitt St & North Ave     TA1308000005
# 1388305  2021-06-18 19:13:35                 Montrose Harbor     TA1308000012
# 1451082  2021-06-24 19:00:36           Green St & Madison St     TA1307000120
# 1674611  2021-07-17 17:13:06      Indiana Ave & Roosevelt Rd           SL-005
# 1687051  2021-07-26 09:52:14     Pulaski Rd & Eddy St (Temp)     KA1504000141
# 1770683  2021-07-09 03:12:27     Racine Ave & Wrightwood Ave     TA1309000059
# 1942396  2021-07-13 16:22:11          Damen Ave & Pierce Ave     TA1305000041
# 2086952  2021-07-25 09:13:18  Valli Produce - Evanston Plaza              599
# 2108478  2021-07-31 22:55:54       Larrabee St & Webster Ave            13193
# 2286092  2021-08-28 15:16:45           Broadway & Berwyn Ave            13109
# 2306158  2021-08-30 18:00:25         Streeter Dr & Grand Ave            13022
# 2306646  2021-08-13 19:54:57         Streeter Dr & Grand Ave            13022
# 2496612  2021-08-08 19:06:56         Lincoln Ave & Winona St     KA1504000078
# 2778661  2021-08-19 18:29:43           Wells St & Concord Ln     TA1308000050
# 2907358  2021-08-13 20:25:56         Lincoln Ave & Roscoe St     TA1307000138
# 2998442  2021-09-29 12:00:06           Broadway & Berwyn Ave            13109
# 3066476  2021-09-19 22:38:04             Morgan St & 31st St     TA1308000046
# 3254305  2021-09-26 12:42:50          Clark St & Randolph St     TA1305000030
# 3272870  2021-09-01 17:06:24          Michigan Ave & Lake St     TA1305000011
# 3285525  2021-09-28 17:39:07       Halsted St & Clybourn Ave              331
# 3478019  2021-09-05 15:16:10  Sheffield Ave & Wrightwood Ave     TA1309000023
# 3821622  2021-10-09 11:10:47  Ashland Ave & Belle Plaine Ave            13249
# 4009788  2021-10-09 14:58:03         Streeter Dr & Grand Ave            13022
# 4580966  2022-02-17 09:39:01     Desplaines St & Randolph St            15535
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 208810           Wabash Ave & Wacker Pl   TA1307000131  41.886875 -87.626030
# 224171             Clinton St & Lake St          13021  41.885323 -87.642098
# 742763               Shore Dr & 55th St   TA1308000009  41.795212 -87.580715
# 775628             Broadway & Barry Ave          13137  41.937582 -87.644098
# 834096          Bernard St & Elston Ave          18016  41.949923 -87.713949
# 834131             McClurg Ct & Erie St   KA1503000041  41.894303 -87.618291
# 857250                   Shedd Aquarium          15544  41.867226 -87.615355
# 934372      Lincoln Ave & Fullerton Ave   TA1309000058  41.925905 -87.649260
# 1027785            Broadway & Argyle St          13108  41.973815 -87.659660
# 1068657               Adler Planetarium          13431  41.866217 -87.607284
# 1160731          Leavitt St & North Ave   TA1308000005  41.910509 -87.682389
# 1388305                 Montrose Harbor   TA1308000012  41.963982 -87.638181
# 1451082           Green St & Madison St   TA1307000120  41.881636 -87.648899
# 1674611      Indiana Ave & Roosevelt Rd         SL-005  41.867888 -87.623041
# 1687051     Pulaski Rd & Eddy St (Temp)   KA1504000141  41.946264 -87.731133
# 1770683     Racine Ave & Wrightwood Ave   TA1309000059  41.928887 -87.658971
# 1942396          Damen Ave & Pierce Ave   TA1305000041  41.909396 -87.677692
# 2086952  Valli Produce - Evanston Plaza            599  42.039742 -87.699413
# 2108478       Larrabee St & Webster Ave          13193  41.921822 -87.644140
# 2286092           Broadway & Berwyn Ave          13109  41.978353 -87.659753
# 2306158         Streeter Dr & Grand Ave          13022  41.892278 -87.612043
# 2306646         Streeter Dr & Grand Ave          13022  41.892278 -87.612043
# 2496612         Lincoln Ave & Winona St   KA1504000078  41.974911 -87.692503
# 2778661           Wells St & Concord Ln   TA1308000050  41.912133 -87.634656
# 2907358         Lincoln Ave & Roscoe St   TA1307000138  41.943340 -87.670970
# 2998442           Broadway & Berwyn Ave          13109  41.978353 -87.659753
# 3066476             Morgan St & 31st St   TA1308000046  41.837751 -87.651232
# 3254305          Clark St & Randolph St   TA1305000030  41.882802 -87.630838
# 3272870          Michigan Ave & Lake St   TA1305000011  41.886024 -87.624117
# 3285525       Halsted St & Clybourn Ave            331  41.909668 -87.648128
# 3478019  Sheffield Ave & Wrightwood Ave   TA1309000023  41.928644 -87.653775
# 3821622  Ashland Ave & Belle Plaine Ave          13249  41.956057 -87.668835
# 4009788         Streeter Dr & Grand Ave          13022  41.892278 -87.612043
# 4580966     Desplaines St & Randolph St          15535  41.884596 -87.644444
#
#            end_lat    end_lng member_casual  Unnamed: 0    clean_started_at  \
# 208810   41.886875 -87.626030        casual      3186.0 2021-04-25 17:37:07
# 224171   41.885393 -87.642070        casual     22429.0 2021-04-23 11:30:54
# 742763   41.795212 -87.580715        casual    270011.0 2021-05-14 12:26:57
# 775628   41.937582 -87.644098        casual    304839.0 2021-05-31 02:03:59
# 834096   41.949923 -87.713949        casual    366677.0 2021-05-23 15:46:20
# 834131   41.894320 -87.618176        casual    366712.0 2021-05-25 17:05:11
# 857250   41.867226 -87.615355        casual    391467.0 2021-05-22 11:32:44
# 934372   41.925905 -87.649260        casual    474451.0 2021-05-27 14:51:06
# 1027785  41.973815 -87.659660        casual     85506.0 2021-06-06 21:13:05
# 1068657  41.866217 -87.607284        casual    126706.0 2021-06-02 20:05:23
# 1160731  41.910509 -87.682389        casual    224611.0 2021-06-12 19:31:22
# 1388305  41.963982 -87.638181        casual    517197.0 2021-06-18 19:13:35
# 1451082  41.881619 -87.648918        casual    584239.0 2021-06-24 19:00:36
# 1674611  41.867888 -87.623041        casual    114313.0 2021-07-17 17:13:06
# 1687051  41.946248 -87.731136        casual    127236.0 2021-07-26 09:52:14
# 1770683  41.928887 -87.658971        casual    217901.0 2021-07-09 03:12:27
# 1942396  41.909396 -87.677692        casual    401001.0 2021-07-13 16:22:11
# 2086952  42.039742 -87.699413        casual    610462.0 2021-07-25 09:13:18
# 2108478  41.921822 -87.644140        casual    633420.0 2021-07-31 22:55:54
# 2286092  41.978353 -87.659753        casual     49901.0 2021-08-28 15:16:45
# 2306158  41.892278 -87.612043        casual     70676.0 2021-08-30 18:00:25
# 2306646  41.892278 -87.612043        casual     71164.0 2021-08-13 19:54:57
# 2496612  41.974911 -87.692503        casual    289814.0 2021-08-08 19:06:56
# 2778661  41.912133 -87.634656        casual    588859.0 2021-08-19 18:29:43
# 2907358  41.943340 -87.670970        casual    780276.0 2021-08-13 20:25:56
# 2998442  41.978353 -87.659753        casual     77523.0 2021-09-29 12:00:06
# 3066476  41.837751 -87.651232        casual    151918.0 2021-09-19 22:38:04
# 3254305  41.883207 -87.630950        casual    351744.0 2021-09-26 12:42:50
# 3272870  41.886024 -87.624117        casual    371774.0 2021-09-01 17:06:24
# 3285525  41.909668 -87.648128        casual    385211.0 2021-09-28 17:39:07
# 3478019  41.928650 -87.653778        casual    591205.0 2021-09-05 15:16:10
# 3821622  41.956057 -87.668835        casual    312765.0 2021-10-09 11:10:47
# 4009788  41.892278 -87.612043        casual    594532.0 2021-10-09 14:58:03
# 4580966  41.884616 -87.644571        casual     43620.0 2022-02-17 09:39:01
#
#              clean_ended_at time_spent  distance_in_km
# 208810  2021-04-25 17:37:07     0 days        0.000000
# 224171  2021-04-23 11:30:54     0 days        0.008143
# 742763  2021-05-14 12:26:57     0 days        0.000000
# 775628  2021-05-31 02:03:59     0 days        0.000000
# 834096  2021-05-23 15:46:20     0 days        0.000000
# 834131  2021-05-25 17:05:11     0 days        0.009728
# 857250  2021-05-22 11:32:44     0 days        0.000000
# 934372  2021-05-27 14:51:06     0 days        0.000000
# 1027785 2021-06-06 21:13:05     0 days        0.000000
# 1068657 2021-06-02 20:05:23     0 days        0.000000
# 1160731 2021-06-12 19:31:22     0 days        0.000000
# 1388305 2021-06-18 19:13:35     0 days        0.000000
# 1451082 2021-06-24 19:00:36     0 days        0.002477
# 1674611 2021-07-17 17:13:06     0 days        0.000000
# 1687051 2021-07-26 09:52:14     0 days        0.001786
# 1770683 2021-07-09 03:12:27     0 days        0.000000
# 1942396 2021-07-13 16:22:11     0 days        0.000000
# 2086952 2021-07-25 09:13:18     0 days        0.000000
# 2108478 2021-07-31 22:55:54     0 days        0.000000
# 2286092 2021-08-28 15:16:45     0 days        0.000000
# 2306158 2021-08-30 18:00:25     0 days        0.000000
# 2306646 2021-08-13 19:54:57     0 days        0.000000
# 2496612 2021-08-08 19:06:56     0 days        0.000000
# 2778661 2021-08-19 18:29:43     0 days        0.000000
# 2907358 2021-08-13 20:25:56     0 days        0.000000
# 2998442 2021-09-29 12:00:06     0 days        0.000000
# 3066476 2021-09-19 22:38:04     0 days        0.000000
# 3254305 2021-09-26 12:42:50     0 days        0.045934
# 3272870 2021-09-01 17:06:24     0 days        0.000000
# 3285525 2021-09-28 17:39:07     0 days        0.000000
# 3478019 2021-09-05 15:16:10     0 days        0.000699
# 3821622 2021-10-09 11:10:47     0 days        0.000000
# 4009788 2021-10-09 14:58:03     0 days        0.000000
# 4580966 2022-02-17 09:39:01     0 days        0.010778

# %% [markdown]
# These exactly 0 difference in time spent **could probably mean something** depending on how ease the access for rides like missclick in a software.

# %%
casual_time_spent_seconds = casual['time_spent'].apply(lambda x: x.total_seconds())

# %%
casual_time_spent_seconds
# Out:
# 0           244.0
# 1           627.0
# 2           984.0
# 3          1739.0
# 4          1076.0
#             ...
# 4630207     565.0
# 4630213    3033.0
# 4630219    1078.0
# 4630221     489.0
# 4630222     586.0
# Name: time_spent, Length: 2052456, dtype: float64

# %% [markdown]
# Now check out the data about distance of casual riders

# %%
casual_distance_mean = casual['distance_in_km'].mean()
casual_distance_max = casual['distance_in_km'].max()
casual_distance_min = casual['distance_in_km'].min()
casual_distance_std = casual['distance_in_km'].std()

print("Casual Rider Distance Statistic")
print("Mean:", casual_distance_mean)
print("Max:", casual_distance_max)
print("Min:", casual_distance_min)
print("Std:", casual_distance_std)
# Out:
# Casual Rider Distance Statistic
# Mean: 2.179273687433695
# Max: 1192.2456023420611
# Min: 0.0
# Std: 2.1437260909483213

# %% [markdown]
# We can also check start and end station to see where is the station that casual riders usually use the services the most

# %%
casual_starting_top10 = casual.groupby(['start_station_name'], sort=True).count().sort_values(by=['ride_id'], ascending=False)[:10]['ride_id']
casual_starting_top10
# Out:
# start_station_name
# Streeter Dr & Grand Ave              64586
# Millennium Park                      32171
# Michigan Ave & Oak St                28650
# Shedd Aquarium                       22613
# Theater on the Lake                  20565
# Wells St & Concord Ln                18917
# Lake Shore Dr & Monroe St            18789
# Clark St & Lincoln Ave               16250
# DuSable Lake Shore Dr & Monroe St    15935
# Wells St & Elm St                    15830
# Name: ride_id, dtype: int64

# %%
casual_startloc = {}
for key, val in casual_starting_top10.items():
    casual_startloc[key] = val
    
casual_startloc
# Out:
# {'Streeter Dr & Grand Ave': 64586,
#  'Millennium Park': 32171,
#  'Michigan Ave & Oak St': 28650,
#  'Shedd Aquarium': 22613,
#  'Theater on the Lake': 20565,
#  'Wells St & Concord Ln': 18917,
#  'Lake Shore Dr & Monroe St': 18789,
#  'Clark St & Lincoln Ave': 16250,
#  'DuSable Lake Shore Dr & Monroe St': 15935,
#  'Wells St & Elm St': 15830}

# %%
plt.figure(figsize=(15, 10))
casual_starting_top10.plot(kind='bar')
plt.xticks(rotation=45, size=20, ha='right')
plt.yticks(size=15)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000., 60000., 70000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ### Member Analysis

# %%
member_time_spent_mean = member['time_spent'].mean()
member_time_spent_max = member['time_spent'].max()
member_time_spent_min = member['time_spent'].min()
member_time_spent_std = member['time_spent'].std()

print("Member Rider Time Spent Statistic")
print("Count:", len(member))
print("Mean:", member_time_spent_mean)
print("Max:", member_time_spent_max)
print("Min:", member_time_spent_min)
print("Std:", member_time_spent_std)
# Out:
# Member Rider Time Spent Statistic
# Count: 2577769
# Mean: 0 days 00:13:02.638846227
# Max: 1 days 00:55:38
# Min: 0 days 00:00:00
# Std: 0 days 00:17:18.434169030

# %%
member.loc[member['time_spent'] == member_time_spent_max]
# Out:
#                   ride_id rideable_type           started_at  \
# 1541204  1E1F59A64365E939  classic_bike  2021-06-12 20:13:13
#
#                     ended_at    start_station_name start_station_id  \
# 1541204  2021-06-13 21:08:51  Paulina St & 18th St     TA1307000159
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 1541204  Wabash Ave & Grand Ave   TA1307000117  41.857901 -87.668745
#
#            end_lat    end_lng member_casual  Unnamed: 0    clean_started_at  \
# 1541204  41.891466 -87.626761        member    680741.0 2021-06-12 20:13:13
#
#              clean_ended_at      time_spent  distance_in_km
# 1541204 2021-06-13 21:08:51 1 days 00:55:38        5.103475

# %%
member.loc[member['time_spent'] == member_time_spent_min]
# Out:
#                   ride_id  rideable_type           started_at  \
# 49944    48013AE627711DB0   classic_bike  2021-03-24 19:32:44
# 58833    650661065904F60B   classic_bike  2021-03-05 08:10:51
# 282384   4CE43CE32F29966A   classic_bike  2021-04-27 17:29:35
# 474113   AC08005905191F56   classic_bike  2021-04-26 19:33:18
# 561545   26C9636FC8CD4339   classic_bike  2021-05-26 08:38:51
# 565843   016F9E1FE0011416   classic_bike  2021-05-24 18:41:38
# 623275   501EE8BE1F6F3E13  electric_bike  2021-05-21 19:09:12
# 708207   6645C2AD2852AEFF   classic_bike  2021-05-22 13:22:50
# 755696   86AB818A11DC85B8   classic_bike  2021-05-07 14:07:12
# 816456   C20A0E9176255245   classic_bike  2021-05-30 13:32:17
# 829121   A98F57CCF03327E4   classic_bike  2021-05-22 19:00:48
# 921670   86D98028752EB3A1   classic_bike  2021-05-30 13:55:45
# 923225   AA6AD272B11619EE   classic_bike  2021-05-25 07:52:29
# 1010717  9D5797261E298A08   classic_bike  2021-06-30 16:39:51
# 1168363  7CCC599CE13EC0E2   classic_bike  2021-06-15 17:37:50
# 1341416  6CC677CC7A269A61   classic_bike  2021-06-06 11:40:18
# 1373389  C251161F9F04C489   classic_bike  2021-06-01 23:00:48
# 1381424  5D5675A54C50E7EB   classic_bike  2021-06-25 13:24:56
# 1561756  D9DEE9CEF21AE165   classic_bike  2021-06-21 10:07:35
# 1633134  CCCF93E09080ADA5   classic_bike  2021-07-20 09:42:58
# 1753445  A4F0CEEE2CACE722   classic_bike  2021-07-28 12:50:27
# 1760836  ECAA3A6D2F0FD627   classic_bike  2021-07-20 09:02:12
# 1942220  006657D7A97F5732  electric_bike  2021-07-13 21:21:23
# 2050121  13655968B9A0E0C8   classic_bike  2021-07-04 16:14:42
# 2163470  1276C965C4784601   classic_bike  2021-07-16 06:23:21
# 2169050  412BBDCAF07E4D5D   classic_bike  2021-07-29 18:33:14
# 2180063  48101CA25A4FD76D   classic_bike  2021-07-03 21:35:04
# 2220350  7F69E0CA1E52D08E   classic_bike  2021-07-18 11:00:02
# 2244248  AB8344C091E7F283   classic_bike  2021-07-27 17:41:13
# 2284318  FCA3A0A1C527D8C6   classic_bike  2021-08-13 17:53:42
# 2803238  022BA7AB20610C45   classic_bike  2021-08-11 18:59:33
# 2952286  26425AD2A79DB7A8   classic_bike  2021-09-14 15:01:34
# 3083648  E6B7496F362E98A5   classic_bike  2021-09-10 18:52:05
# 3146149  000571A6E9B98C73   classic_bike  2021-09-09 20:17:31
# 3246311  B1F225DC9BA4AAB0   classic_bike  2021-09-12 17:32:36
# 3269504  0640A2A0D4A2CD86   classic_bike  2021-09-25 20:43:04
# 3311984  1C00E7445599C55A   classic_bike  2021-09-18 20:26:23
# 3316464  AB0227900FBBA279   classic_bike  2021-09-04 15:53:04
# 3376143  84D8C8E8FDCBBFB0  electric_bike  2021-09-12 17:29:00
# 3493465  8590ABC3CD2BBC35   classic_bike  2021-09-22 18:51:46
# 3659106  681AEE011573E275   classic_bike  2021-10-12 19:02:04
# 3705527  2C166E8669DC4F28   classic_bike  2021-10-04 13:10:43
# 3732522  AC7D3D39695F448A   classic_bike  2021-10-30 09:30:07
# 3766701  23174211C3B6A904   classic_bike  2021-10-05 08:48:04
# 4339823  D0EC4FF4822C75D5   classic_bike  2021-12-12 16:32:15
# 4345844  0A3055D2697FD60F   classic_bike  2021-12-01 17:36:30
# 4570990  6174209419E9E4F4   classic_bike  2022-02-17 14:20:58
# 4590163  21582FCE30A61620   classic_bike  2022-02-16 14:32:32
# 4612350  CF76E9E68F30EE55   classic_bike  2022-02-24 07:41:45
#
#                     ended_at                   start_station_name  \
# 49944    2021-03-24 19:32:44            Clark St & Wellington Ave
# 58833    2021-03-05 08:10:51          Lake Shore Dr & Belmont Ave
# 282384   2021-04-27 17:29:35              Clark St & Armitage Ave
# 474113   2021-04-26 19:33:18              Streeter Dr & Grand Ave
# 561545   2021-05-26 08:38:51            Columbus Dr & Randolph St
# 565843   2021-05-24 18:41:38            Clark St & Wellington Ave
# 623275   2021-05-21 19:09:12                Wells St & Hubbard St
# 708207   2021-05-22 13:22:50                  Morgan St & Lake St
# 755696   2021-05-07 14:07:12            Michigan Ave & Pearson St
# 816456   2021-05-30 13:32:17              Streeter Dr & Grand Ave
# 829121   2021-05-22 19:00:48                   Wells St & Polk St
# 921670   2021-05-30 13:55:45             Fairbanks Ct & Grand Ave
# 923225   2021-05-25 07:52:29           Clybourn Ave & Division St
# 1010717  2021-06-30 16:39:51                 Wallace St & 35th St
# 1168363  2021-06-15 17:37:50             Loomis St & Lexington St
# 1341416  2021-06-06 11:40:18              Streeter Dr & Grand Ave
# 1373389  2021-06-01 23:00:48          Pulaski Rd & Eddy St (Temp)
# 1381424  2021-06-25 13:24:56              Damen Ave & Melrose Ave
# 1561756  2021-06-21 10:07:35             Kingsbury St & Kinzie St
# 1633134  2021-07-20 09:42:58             Halsted St & Dickens Ave
# 1753445  2021-07-28 12:50:27               Clark St & Drummond Pl
# 1760836  2021-07-20 09:02:12             Halsted St & Dickens Ave
# 1942220  2021-07-13 21:21:23             Wells St & Evergreen Ave
# 2050121  2021-07-04 16:14:42             Peoria St & Jackson Blvd
# 2163470  2021-07-16 06:23:21               Michigan Ave & 18th St
# 2169050  2021-07-29 18:33:14   DuSable Lake Shore Dr & North Blvd
# 2180063  2021-07-03 21:35:04                       Shedd Aquarium
# 2220350  2021-07-18 11:00:02              Streeter Dr & Grand Ave
# 2244248  2021-07-27 17:41:13                Wells St & Concord Ln
# 2284318  2021-08-13 17:53:42         Clinton St & Washington Blvd
# 2803238  2021-08-11 18:59:33             Kingsbury St & Kinzie St
# 2952286  2021-09-14 15:01:34             Campbell Ave & North Ave
# 3083648  2021-09-10 18:52:05                  Theater on the Lake
# 3146149  2021-09-09 20:17:31       Southport Ave & Irving Park Rd
# 3246311  2021-09-12 17:32:36                   Daley Center Plaza
# 3269504  2021-09-25 20:43:04            Artesian Ave & Hubbard St
# 3311984  2021-09-18 20:26:23           Racine Ave & Fullerton Ave
# 3316464  2021-09-04 15:53:04   DuSable Lake Shore Dr & North Blvd
# 3376143  2021-09-12 17:29:00                  Wabash Ave & 9th St
# 3493465  2021-09-22 18:51:46            Sedgwick St & Webster Ave
# 3659106  2021-10-12 19:02:04                Ashland Ave & Lake St
# 3705527  2021-10-04 13:10:43             University Ave & 57th St
# 3732522  2021-10-30 09:30:07                State St & Pearson St
# 3766701  2021-10-05 08:48:04             Western Ave & Leland Ave
# 4339823  2021-12-12 16:32:15  Mies van der Rohe Way & Chicago Ave
# 4345844  2021-12-01 17:36:30            Clinton St & Jackson Blvd
# 4570990  2022-02-17 14:20:58             University Ave & 57th St
# 4590163  2022-02-16 14:32:32                  Canal St & Adams St
# 4612350  2022-02-24 07:41:45           Ashland Ave & Blackhawk St
#
#         start_station_id                     end_station_name end_station_id  \
# 49944       TA1307000136            Clark St & Wellington Ave   TA1307000136
# 58833       TA1309000049          Lake Shore Dr & Belmont Ave   TA1309000049
# 282384             13146              Clark St & Armitage Ave          13146
# 474113             13022              Streeter Dr & Grand Ave          13022
# 561545             13263            Columbus Dr & Randolph St          13263
# 565843      TA1307000136            Clark St & Wellington Ave   TA1307000136
# 623275      TA1307000151                Wells St & Hubbard St   TA1307000151
# 708207      TA1306000015                  Morgan St & Lake St   TA1306000015
# 755696             13034            Michigan Ave & Pearson St          13034
# 816456             13022              Streeter Dr & Grand Ave          13022
# 829121            SL-011                   Wells St & Polk St         SL-011
# 921670      TA1305000003             Fairbanks Ct & Grand Ave   TA1305000003
# 923225      TA1307000115           Clybourn Ave & Division St   TA1307000115
# 1010717     TA1308000045                 Wallace St & 35th St   TA1308000045
# 1168363            13332             Loomis St & Lexington St          13332
# 1341416            13022              Streeter Dr & Grand Ave          13022
# 1373389     KA1504000141          Pulaski Rd & Eddy St (Temp)   KA1504000141
# 1381424            13143              Damen Ave & Melrose Ave          13143
# 1561756     KA1503000043             Kingsbury St & Kinzie St   KA1503000043
# 1633134            13192             Halsted St & Dickens Ave          13192
# 1753445     TA1307000142               Clark St & Drummond Pl   TA1307000142
# 1760836            13192             Halsted St & Dickens Ave          13192
# 1942220     TA1308000049             Wells St & Evergreen Ave   TA1308000049
# 2050121            13158             Peoria St & Jackson Blvd          13158
# 2163470            13150               Michigan Ave & 18th St          13150
# 2169050           LF-005   DuSable Lake Shore Dr & North Blvd         LF-005
# 2180063            15544                       Shedd Aquarium          15544
# 2220350            13022              Streeter Dr & Grand Ave          13022
# 2244248     TA1308000050                Wells St & Concord Ln   TA1308000050
# 2284318           WL-012         Clinton St & Washington Blvd         WL-012
# 2803238     KA1503000043             Kingsbury St & Kinzie St   KA1503000043
# 2952286            13257             Campbell Ave & North Ave          13257
# 3083648     TA1308000001                  Theater on the Lake   TA1308000001
# 3146149     TA1309000043       Southport Ave & Irving Park Rd   TA1309000043
# 3246311     TA1306000010                   Daley Center Plaza   TA1306000010
# 3269504            15664            Artesian Ave & Hubbard St          15664
# 3311984     TA1306000026           Racine Ave & Fullerton Ave   TA1306000026
# 3316464           LF-005   DuSable Lake Shore Dr & North Blvd         LF-005
# 3376143     TA1309000010                  Wabash Ave & 9th St   TA1309000010
# 3493465            13191            Sedgwick St & Webster Ave          13191
# 3659106            13073                Ashland Ave & Lake St          13073
# 3705527     KA1503000071             University Ave & 57th St   KA1503000071
# 3732522     TA1307000061                State St & Pearson St   TA1307000061
# 3766701     TA1307000140             Western Ave & Leland Ave   TA1307000140
# 4339823            13338  Mies van der Rohe Way & Chicago Ave          13338
# 4345844              638            Clinton St & Jackson Blvd            638
# 4570990     KA1503000071             University Ave & 57th St   KA1503000071
# 4590163            13011                  Canal St & Adams St          13011
# 4612350            13224           Ashland Ave & Blackhawk St          13224
#
#          start_lat  start_lng    end_lat    end_lng member_casual  Unnamed: 0  \
# 49944    41.936497 -87.647539  41.936497 -87.647539        member     49967.0
# 58833    41.940775 -87.639192  41.940775 -87.639192        member     58856.0
# 282384   41.918306 -87.636282  41.918306 -87.636282        member    104176.0
# 474113   41.892278 -87.612043  41.892278 -87.612043        member    307392.0
# 561545   41.884728 -87.619521  41.884728 -87.619521        member     62345.0
# 565843   41.936497 -87.647539  41.936497 -87.647539        member     66697.0
# 623275   41.889904 -87.634132  41.889908 -87.634092        member    128782.0
# 708207   41.885483 -87.652305  41.885483 -87.652305        member    218242.0
# 755696   41.897660 -87.623510  41.897660 -87.623510        member    283932.0
# 816456   41.892278 -87.612043  41.892278 -87.612043        member    347875.0
# 829121   41.872596 -87.633502  41.872596 -87.633502        member    361282.0
# 921670   41.891847 -87.620580  41.891847 -87.620580        member    461091.0
# 923225   41.904613 -87.640552  41.904613 -87.640552        member    462647.0
# 1010717  41.830629 -87.641290  41.830629 -87.641290        member     68356.0
# 1168363  41.872187 -87.661501  41.872187 -87.661501        member    232397.0
# 1341416  41.892278 -87.612043  41.892278 -87.612043        member    467070.0
# 1373389  41.946264 -87.731023  41.946264 -87.731023        member    501226.0
# 1381424  41.940600 -87.678500  41.940600 -87.678500        member    509760.0
# 1561756  41.889177 -87.638506  41.889177 -87.638506        member    705474.0
# 1633134  41.919936 -87.648830  41.919936 -87.648830        member     72282.0
# 1753445  41.931248 -87.644336  41.931248 -87.644336        member    200387.0
# 1760836  41.919936 -87.648830  41.919936 -87.648830        member    208002.0
# 1942220  41.906841 -87.634997  41.906760 -87.635036        member    400825.0
# 2050121  41.877642 -87.649618  41.877642 -87.649618        member    516454.0
# 2163470  41.857813 -87.624550  41.857813 -87.624550        member    693660.0
# 2169050  41.911722 -87.626804  41.911722 -87.626804        member    699905.0
# 2180063  41.867226 -87.615355  41.867226 -87.615355        member    711293.0
# 2220350  41.892278 -87.612043  41.892278 -87.612043        member    754776.0
# 2244248  41.912133 -87.634656  41.912133 -87.634656        member    779958.0
# 2284318  41.883380 -87.641170  41.883380 -87.641170        member     48045.0
# 2803238  41.889177 -87.638506  41.889177 -87.638506        member    648663.0
# 2952286  41.910535 -87.689556  41.910535 -87.689556        member     28168.0
# 3083648  41.926277 -87.630834  41.926277 -87.630834        member    170653.0
# 3146149  41.954177 -87.664358  41.954177 -87.664358        member    236983.0
# 3246311  41.884241 -87.629634  41.884241 -87.629634        member    343495.0
# 3269504  41.889492 -87.688219  41.889492 -87.688219        member    368130.0
# 3311984  41.925563 -87.658404  41.925563 -87.658404        member    413487.0
# 3316464  41.911722 -87.626804  41.911722 -87.626804        member    418203.0
# 3376143  41.870768 -87.625795  41.870827 -87.625826        member    481554.0
# 3493465  41.922167 -87.638888  41.922167 -87.638888        member    607979.0
# 3659106  41.885920 -87.667170  41.885920 -87.667170        member    136588.0
# 3705527  41.791478 -87.599861  41.791478 -87.599861        member    186440.0
# 3732522  41.897448 -87.628722  41.897448 -87.628722        member    216405.0
# 3766701  41.966400 -87.688704  41.966400 -87.688704        member    253462.0
# 4339823  41.896945 -87.621758  41.896945 -87.621758        member     57078.0
# 4345844  41.878317 -87.640981  41.878317 -87.640981        member     63359.0
# 4570990  41.791478 -87.599861  41.791478 -87.599861        member     32092.0
# 4590163  41.879255 -87.639904  41.879255 -87.639904        member     53169.0
# 4612350  41.907066 -87.667252  41.907066 -87.667252        member     76829.0
#
#            clean_started_at      clean_ended_at time_spent  distance_in_km
# 49944   2021-03-24 19:32:44 2021-03-24 19:32:44     0 days        0.000000
# 58833   2021-03-05 08:10:51 2021-03-05 08:10:51     0 days        0.000000
# 282384  2021-04-27 17:29:35 2021-04-27 17:29:35     0 days        0.000000
# 474113  2021-04-26 19:33:18 2021-04-26 19:33:18     0 days        0.000000
# 561545  2021-05-26 08:38:51 2021-05-26 08:38:51     0 days        0.000000
# 565843  2021-05-24 18:41:38 2021-05-24 18:41:38     0 days        0.000000
# 623275  2021-05-21 19:09:12 2021-05-21 19:09:12     0 days        0.003311
# 708207  2021-05-22 13:22:50 2021-05-22 13:22:50     0 days        0.000000
# 755696  2021-05-07 14:07:12 2021-05-07 14:07:12     0 days        0.000000
# 816456  2021-05-30 13:32:17 2021-05-30 13:32:17     0 days        0.000000
# 829121  2021-05-22 19:00:48 2021-05-22 19:00:48     0 days        0.000000
# 921670  2021-05-30 13:55:45 2021-05-30 13:55:45     0 days        0.000000
# 923225  2021-05-25 07:52:29 2021-05-25 07:52:29     0 days        0.000000
# 1010717 2021-06-30 16:39:51 2021-06-30 16:39:51     0 days        0.000000
# 1168363 2021-06-15 17:37:50 2021-06-15 17:37:50     0 days        0.000000
# 1341416 2021-06-06 11:40:18 2021-06-06 11:40:18     0 days        0.000000
# 1373389 2021-06-01 23:00:48 2021-06-01 23:00:48     0 days        0.000000
# 1381424 2021-06-25 13:24:56 2021-06-25 13:24:56     0 days        0.000000
# 1561756 2021-06-21 10:07:35 2021-06-21 10:07:35     0 days        0.000000
# 1633134 2021-07-20 09:42:58 2021-07-20 09:42:58     0 days        0.000000
# 1753445 2021-07-28 12:50:27 2021-07-28 12:50:27     0 days        0.000000
# 1760836 2021-07-20 09:02:12 2021-07-20 09:02:12     0 days        0.000000
# 1942220 2021-07-13 21:21:23 2021-07-13 21:21:23     0 days        0.009504
# 2050121 2021-07-04 16:14:42 2021-07-04 16:14:42     0 days        0.000000
# 2163470 2021-07-16 06:23:21 2021-07-16 06:23:21     0 days        0.000000
# 2169050 2021-07-29 18:33:14 2021-07-29 18:33:14     0 days        0.000000
# 2180063 2021-07-03 21:35:04 2021-07-03 21:35:04     0 days        0.000000
# 2220350 2021-07-18 11:00:02 2021-07-18 11:00:02     0 days        0.000000
# 2244248 2021-07-27 17:41:13 2021-07-27 17:41:13     0 days        0.000000
# 2284318 2021-08-13 17:53:42 2021-08-13 17:53:42     0 days        0.000000
# 2803238 2021-08-11 18:59:33 2021-08-11 18:59:33     0 days        0.000000
# 2952286 2021-09-14 15:01:34 2021-09-14 15:01:34     0 days        0.000000
# 3083648 2021-09-10 18:52:05 2021-09-10 18:52:05     0 days        0.000000
# 3146149 2021-09-09 20:17:31 2021-09-09 20:17:31     0 days        0.000000
# 3246311 2021-09-12 17:32:36 2021-09-12 17:32:36     0 days        0.000000
# 3269504 2021-09-25 20:43:04 2021-09-25 20:43:04     0 days        0.000000
# 3311984 2021-09-18 20:26:23 2021-09-18 20:26:23     0 days        0.000000
# 3316464 2021-09-04 15:53:04 2021-09-04 15:53:04     0 days        0.000000
# 3376143 2021-09-12 17:29:00 2021-09-12 17:29:00     0 days        0.006949
# 3493465 2021-09-22 18:51:46 2021-09-22 18:51:46     0 days        0.000000
# 3659106 2021-10-12 19:02:04 2021-10-12 19:02:04     0 days        0.000000
# 3705527 2021-10-04 13:10:43 2021-10-04 13:10:43     0 days        0.000000
# 3732522 2021-10-30 09:30:07 2021-10-30 09:30:07     0 days        0.000000
# 3766701 2021-10-05 08:48:04 2021-10-05 08:48:04     0 days        0.000000
# 4339823 2021-12-12 16:32:15 2021-12-12 16:32:15     0 days        0.000000
# 4345844 2021-12-01 17:36:30 2021-12-01 17:36:30     0 days        0.000000
# 4570990 2022-02-17 14:20:58 2022-02-17 14:20:58     0 days        0.000000
# 4590163 2022-02-16 14:32:32 2022-02-16 14:32:32     0 days        0.000000
# 4612350 2022-02-24 07:41:45 2022-02-24 07:41:45     0 days        0.000000

# %%
member_time_spent_seconds = member['time_spent'].apply(lambda x: x.total_seconds())

# %%
member_time_spent_seconds
# Out:
# 6           692.0
# 7           539.0
# 8           279.0
# 9           907.0
# 10         1094.0
#             ...
# 4630217      99.0
# 4630218     843.0
# 4630220     977.0
# 4630223     284.0
# 4630224     698.0
# Name: time_spent, Length: 2577769, dtype: float64

# %% [markdown]
# Check the data about distance for member riders

# %%
member_distance_mean = member['distance_in_km'].mean()
member_distance_max = member['distance_in_km'].max()
member_distance_min = member['distance_in_km'].min()
member_distance_std = member['distance_in_km'].std()

print("Member Rider Distance Statistic")
print("Mean:", member_distance_mean)
print("Max:", member_distance_max)
print("Min:", member_distance_min)
print("Std:", member_distance_std)
# Out:
# Member Rider Distance Statistic
# Mean: 2.073394651965077
# Max: 31.531601476976515
# Min: 0.0
# Std: 1.7867972003802148

# %% [markdown]
# Now check the start and end station to see where is the station that member riders usually use the services the most

# %%
member_starting_top10 = member.groupby(['start_station_name'], sort=True).count().sort_values(by=['ride_id'], ascending=False)[:10]['ride_id']
member_starting_top10
# Out:
# start_station_name
# Clark St & Elm St            23961
# Kingsbury St & Kinzie St     23629
# Wells St & Concord Ln        23051
# Wells St & Elm St            20394
# Dearborn St & Erie St        18518
# St. Clair St & Erie St       18321
# Wells St & Huron St          18250
# Broadway & Barry Ave         17060
# Clinton St & Madison St      17041
# Desplaines St & Kinzie St    16262
# Name: ride_id, dtype: int64

# %%
member_startloc = {}
for key, val in member_starting_top10.items():
    member_startloc[key] = val
    
member_startloc
# Out:
# {'Clark St & Elm St': 23961,
#  'Kingsbury St & Kinzie St': 23629,
#  'Wells St & Concord Ln': 23051,
#  'Wells St & Elm St': 20394,
#  'Dearborn St & Erie St': 18518,
#  'St. Clair St & Erie St': 18321,
#  'Wells St & Huron St': 18250,
#  'Broadway & Barry Ave': 17060,
#  'Clinton St & Madison St': 17041,
#  'Desplaines St & Kinzie St': 16262}

# %%
plt.figure(figsize=(15, 10))
member_starting_top10.plot(kind='bar')
plt.xticks(rotation=45, size=15, ha='right')
plt.yticks(size=15)
# Out:
# (array([    0.,  5000., 10000., 15000., 20000., 25000., 30000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ### Now all the materials for comparison have been prepared, it's time to do further analysis between the 2 categories

# %% [markdown]
# ### Analysis between common starting locations
#
# I would like to know the places that have the most rides so that when the marketing team work on those places, it would potentially achieve much better conversion number.
#
# For starting stations between 2 category of riders, the top 10 most common places are:
#
# | **Casual** Starting Station          | Count | **Member** Starting Station  | Count |
# | :--                                  |  ---  | :--                          |  ---  |
# | Streeter Dr & Grand Ave              | 64586 | Clark St & Elm St            | 23961 |
# | Millennium Park                      | 32171 | Kingsbury St & Kinzie St     | 23629 |
# | Michigan Ave & Oak St                | 28650 | **Wells St & Concord Ln**        | 23051 |
# | Shedd Aquarium                       | 22613 | **Wells St & Elm St**            | 20394 |
# | Theater on the Lake                  | 20565 | Dearborn St & Erie St        | 18518 |
# | **Wells St & Concord Ln**                | 18917 | St. Clair St & Erie St       | 18321 |
# | Lake Shore Dr & Monroe St            | 18789 | Wells St & Huron St          | 18250 |
# | Clark St & Lincoln Ave               | 16250 | Broadway & Barry Ave         | 17060 |
# | DuSable Lake Shore Dr & Monroe St    | 15935 | Clinton St & Madison St      | 17041 |
# | **Wells St & Elm St**                    | 15830 | Desplaines St & Kinzie St    | 16262 |
#
# It can be seen that 2 starting stations in member category:
# 1. Wells St & Concord Ln (3th in member riders group)
# 2. Wells St & Elm st (4th in member riders group)
#
# are also in the casual starting station category (6th and 10th respectively). These 2 stations are **potential locations** for our marketing campaign to turn our casual riders into member riders.
#
# Because (I don't exactly know about any of these places at all) the places which have the most count of rides probably filled with people who have more than average incomes. So in the behavioural analysis I will use the top 10 member starting locations data as basis to be compared.

# %% [markdown]
# ### Analysis of starting locations of casual riders whose ride time is around the same with the average member riders

# %% [markdown]
# We have seen that:
#
# **Casual Rider Time Spent Statistic** <br>
# Mean: 0 days 00:32:24.284466025 <br>
# Count: 2052456 <br>
# Max: 38 days 20:24:09 <br>
# Min: 0 days 00:00:00 <br>
# Std: 0 days 04:34:16.115614304 <br>
#
# **Member Rider Time Spent Statistic** <br>
# Mean: 0 days 00:13:02.638846227 <br>
# Count: 2577769 <br>
# Max: 1 days 00:55:38 <br>
# Min: 0 days 00:00:00 <br>
# Std: 0 days 00:17:18.434169030 <br>
#
# We have around equally amount of data, but the time spent using the services are much longer on casual rider side. Maybe if we want to convert casual rider to a member we need to focus on the people who uses the service with similar amount of time with the average of member rider, instead of trying to convince casual riders who more frequently use the services. This insight sounds weird but at least that's what the data tells.
#
# For our marketing campaign maybe we can promote our services in the places where it is the most common for people to use our services as long as our average member rider.

# %%
duration_search_range = (member_time_spent_mean - member_time_spent_std, member_time_spent_mean + member_time_spent_std)
duration_search_range
# Out:
# (Timedelta('-1 days +23:55:44.204677197'),
#  Timedelta('0 days 00:30:21.073015257'))

# %% [markdown]
# Since the first difference is less than 0 then let's just focus on the upper limit

# %%
casual_duration_filtered = casual.where(
    casual_time_spent_seconds < duration_search_range[1].total_seconds()
).dropna()

# %%
casual_top_10_most_starting_stations_duration_filtered = casual_duration_filtered.groupby(['start_station_name'], sort=True) \
.count() \
.sort_values(by=['ride_id'], ascending=False)[:10]['ride_id']

# %%
casual_top_10_most_starting_stations_duration_filtered
# Out:
# start_station_name
# Streeter Dr & Grand Ave    35608
# Wells St & Concord Ln      16569
# Millennium Park            16129
# Michigan Ave & Oak St      15802
# Wells St & Elm St          14358
# Clark St & Elm St          13584
# Shedd Aquarium             13556
# Theater on the Lake        13220
# Clark St & Lincoln Ave     13168
# Clark St & Armitage Ave    12100
# Name: ride_id, dtype: int64

# %%
similar_duration = {}
for key, val in casual_top_10_most_starting_stations_duration_filtered.items():
    similar_duration[key] = val
similar_duration
# Out:
# {'Streeter Dr & Grand Ave': 35608,
#  'Wells St & Concord Ln': 16569,
#  'Millennium Park': 16129,
#  'Michigan Ave & Oak St': 15802,
#  'Wells St & Elm St': 14358,
#  'Clark St & Elm St': 13584,
#  'Shedd Aquarium': 13556,
#  'Theater on the Lake': 13220,
#  'Clark St & Lincoln Ave': 13168,
#  'Clark St & Armitage Ave': 12100}

# %%
fig, ax = plt.subplots(figsize=(15, 10))
# plt.figure(figsize=(15, 10))
casual_top_10_most_starting_stations_duration_filtered.plot(kind='bar')
# plt.xticks(rotation=45, size=15, ha='right')
plt.ylabel('')
plt.xlabel('')
plt.xticks(size=16)
plt.yticks(size=16, rotation=90)
# Out:
# (array([    0.,  5000., 10000., 15000., 20000., 25000., 30000., 35000.,
#         40000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# | **Casual** Riders With Around Similar Duration With Average Member Riders Starting Station          | Count | **Member** Riders Starting Station  | Count |
# | :--                                  |  ---  | :--                          |  ---  |
# | Streeter Dr & Grand Ave              | 35608 | **Clark St & Elm St**            | 23961 |
# | **Wells St & Concord Ln**                | 16569 | Kingsbury St & Kinzie St     | 23629 |
# | Millennium Park                      | 16129 | **Wells St & Concord Ln**        | 23051 |
# | Michigan Ave & Oak St                | 15802 | **Wells St & Elm St**            | 20394 |
# | **Wells St & Elm St**                    | 14358 | Dearborn St & Erie St        | 18518 |
# | **Clark St & Elm St**                    | 13584 | St. Clair St & Erie St       | 18321 |
# | Shedd Aquarium                       | 13556 | Wells St & Huron St          | 18250 |
# | Theater on the Lake                  | 13220 | Broadway & Barry Ave         | 17060 |
# | Clark St & Lincoln Ave               | 13168 | Clinton St & Madison St      | 17041 |
# | Clark St & Armitage Ave              | 12100 | Desplaines St & Kinzie St    | 16262 |
#
# Now there are 3 starting stations that shares top 10 places of both categories:
# 1. Clark St & Elm St (1st in member riders)
# 2. Wells St & Concord Ln (3rd in member riders)
# 3. Wells St & Elm St (4th in member riders)
#
# After we investigated the behaviour of casual riders and filter the casual riders data, compared to prior analysis of the top 10 most common places, now *Clark St & Elm St* that ranks first in the member riders category also appears in the filtered casual riders category. This place now becomes a **potential location** for our marketing team based on the similar behaviour of casual riders that started from this place with the average member riders.

# %% [markdown]
# ### Analysis of starting locations of casual riders whose ride distance is around the same with the average member riders

# %% [markdown]
# Using the same logic with analysing time spent for rides data

# %%
max_distance_range = member_distance_mean + member_distance_std
min_distance_range = member_distance_mean - member_distance_std

# %%
casual_distance_filtered = casual.where(
    (casual['distance_in_km'] < max_distance_range) & (casual['distance_in_km'] > min_distance_range)
).dropna()

# %%
print(len(casual))
print(len(casual_distance_filtered))
# Out:
# 2052456
# 1506074

# %%
casual_top_10_most_starting_stations_distance_filtered = casual_distance_filtered.groupby(['start_station_name'], sort=True) \
.count() \
.sort_values(by=['ride_id'], ascending=False)[:10]['ride_id']

# %%
similar_distance = {}
for key, val in casual_top_10_most_starting_stations_distance_filtered.items():
    similar_distance[key] = val
similar_distance
# Out:
# {'Streeter Dr & Grand Ave': 40528,
#  'Millennium Park': 22826,
#  'Shedd Aquarium': 17745,
#  'Michigan Ave & Oak St': 17240,
#  'Wells St & Concord Ln': 15826,
#  'Wells St & Elm St': 13769,
#  'Clark St & Lincoln Ave': 12825,
#  'Clark St & Elm St': 12598,
#  'Lake Shore Dr & Monroe St': 12207,
#  'Clark St & Armitage Ave': 11955}

# %%
plt.figure(figsize=(15, 10))
casual_top_10_most_starting_stations_distance_filtered.plot(kind='bar')
plt.xticks(rotation=45, size=15, ha='right')
plt.yticks(size=15)
# Out:
# (array([    0.,  5000., 10000., 15000., 20000., 25000., 30000., 35000.,
#         40000., 45000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# | **Casual** Riders With Around Similar Distance Travel With Average Member Riders Starting Station          | Count | **Member** Riders Starting Station  | Count |
# | :--                                  |  ---  | :--                          |  ---  |
# | Streeter Dr & Grand Ave              | 40528 | **Clark St & Elm St**            | 23961 |
# | Millennium Park                      | 22826 | Kingsbury St & Kinzie St     | 23629 |
# | Shedd Aquarium                       | 17745 | **Wells St & Concord Ln**        | 23051 |
# | Michigan Ave & Oak St                | 17240 | **Wells St & Elm St**            | 20394 |
# | **Wells St & Concord Ln**                | 15826 | Dearborn St & Erie St        | 18518 |
# | **Wells St & Elm St**                    | 13769 | St. Clair St & Erie St       | 18321 |
# | Clark St & Lincoln Ave               | 12825 | Wells St & Huron St          | 18250 |
# | **Clark St & Elm St**                    | 12598 | Broadway & Barry Ave         | 17060 |
# | Lake Shore Dr & Monroe St            | 12207 | Clinton St & Madison St      | 17041 |
# | Clark St & Armitage Ave              | 11955 | Desplaines St & Kinzie St    | 16262 |
#
# Again, the 3 same stations as prior analysis with duration of rides.

# %% [markdown]
# With these analyses, **Clark St & Elm St**, **Wells St & Concord Ln**, and **Wells St & Elm St** are the potential locations for our marketing team to convert casual riders into member riders the most compared to another stations.
#
# But since, as the director of marketing has pointed out (in project description), that casual riders are already aware of the Cyclistic program, then the marketing/advertising strategy towards people around those stations need to be different compared to trying to attract new people (something like discount offer).

# %% [markdown]
# ### Combining both behaviours as filter for casual data (Curiousity)

# %%
casual_distance_duration_filtered = casual.where(
    (casual['distance_in_km'] < max_distance_range) & (casual['distance_in_km'] > min_distance_range) & \
    (casual_time_spent_seconds < duration_search_range[1].total_seconds())
).dropna()

# %%
casual_top_10_starting_locations_distance_duration_filtered = casual_distance_duration_filtered.groupby(['start_station_name'], sort=True) \
.count() \
.sort_values(by=['ride_id'], ascending=False)[:10]['ride_id']

# %%
casual_top_10_starting_locations_distance_duration_filtered
# Out:
# start_station_name
# Streeter Dr & Grand Ave     26092
# Wells St & Concord Ln       14527
# Wells St & Elm St           12982
# Millennium Park             12953
# Clark St & Elm St           11620
# Michigan Ave & Oak St       11409
# Shedd Aquarium              11399
# Clark St & Lincoln Ave      11339
# Clark St & Armitage Ave     10421
# Wells St & Evergreen Ave    10082
# Name: ride_id, dtype: int64

# %%
similar_duration_distance = {}
for key, val in casual_top_10_starting_locations_distance_duration_filtered.items():
    similar_duration_distance[key] = val
similar_duration_distance
# Out:
# {'Streeter Dr & Grand Ave': 26092,
#  'Wells St & Concord Ln': 14527,
#  'Wells St & Elm St': 12982,
#  'Millennium Park': 12953,
#  'Clark St & Elm St': 11620,
#  'Michigan Ave & Oak St': 11409,
#  'Shedd Aquarium': 11399,
#  'Clark St & Lincoln Ave': 11339,
#  'Clark St & Armitage Ave': 10421,
#  'Wells St & Evergreen Ave': 10082}

# %%
plt.figure(figsize=(15, 10))
casual_top_10_starting_locations_distance_duration_filtered.plot(kind='bar')
plt.xticks(rotation=45, size=15, ha='right')
plt.yticks(size=15)
# Out:
# (array([    0.,  5000., 10000., 15000., 20000., 25000., 30000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# **Clark St & Elm St**, **Wells St & Concord Ln**, and **Wells St & Elm St** are still the potential locations for our marketing team to convert casual riders into member riders the most compared to another stations.

# %% [markdown]
# ## Step 5: Share

# %% [markdown]
# Now we have finished our analysis we need to share our findings to show the important people in order for them to consider it and make business decisions.
#
# Description from the project detail:
#
# Now that you have performed your analysis and gained some insights into your data, create visualizations to share your
# findings. Moreno has reminded you that they should be sophisticated and polished in order to effectively communicate to the
# executive team.

# %% [markdown]
# #### Guiding questions
# 1. Were you able to answer the question of how annual members and casual riders use Cyclistic bikes differently?
# 2. What story does your data tell?
# 3. How do your findings relate to your original question?
# 4. Who is your audience? What is the best way to communicate with them?
# 5. Can data visualization help you share your findings?
# 6. Is your presentation accessible to your audience?
#
# #### Key tasks
# 1. Determine the best way to share your findings.
# 2. Create effective data visualizations.
# 3. Present your findings.
# 4. Ensure your work is accessible.
#
# #### My Answer to the guiding questions and key tasks:
# 1. Casual riders tend to ride longer (time and distance wise) than (annual) members.
# 2. Casual riders that behave almost similarly with average member riders mostly can be found in 3 starting stations: **Clark St & Elm St**, **Wells St & Concord Ln**, and **Wells St & Elm St**.
# 3. The original question was identifying the difference between casual riders and member riders, but after behavioral analysis these 3 places have been found to be the place where many of their casual riders behave almost similarly with member riders.
# 4. Marketing Team.
# 5. Not really. Just comparison table is enough.
# 6. Yes

# %% [markdown]
# ## Step 6: Act

# %% [markdown]
# In the final step of data analysis project is to share our findings to show the stakeholders. Creating a report and presentation are 2 ways of doing it.
#
# Description from the project detail:
#
# Now that you have finished creating your visualizations, act on your findings. Prepare the deliverables Morena asked you to
# create, including the three top recommendations based on your analysis.

# %% [markdown]
# #### Guiding Questions
# 1. What is your final conclusion based on your analysis?
# 2. How could your team and business apply your insights?
# 3. What next steps would you or your stakeholders take based on your findings?
# 4. Is there additional data you could use to expand on your findings?
#
# #### Key Tasks
# 1. Create your portfolio.
# 2. Add your case study.
# 3. Practice presenting your case study to a friend or family member.
#
# #### My Answer to the guiding questions and key tasks:
# 1. Cyclistic Marketing Team could focus on their marketing strategy towards 3 places:
#     - lark St & Elm St
#     - Wells St & Concord Ln
#     - Wells St & Elm St
# 2. Focusing their marketing strategy and effort on the suggested places
# 3. Marketing team choosing the recommended places for their potential locations
# 4. Data about altitude could help giving greater insight regarding users' preference riding in high altitude area and low altitude area.

# %% [markdown]
# ## DELIVERABLES / REPORT
# The deliverables Morena asked
#
# ### Expected Report after answering business questions:
# 1. A clear statement of the business task
# 2. A description of all data sources used
# 3. Documentation of any cleaning or manipulation of data
# 4. A summary of your analysis
# 5. Supporting visualizations and key findings
# 6. Your top three recommendations based on your analysis
#
# ### Report
# 1. Find out how casual riders and member riders rides differently and use data to turn casual riders into member riders
# 2. Data were obtained from this [link](https://divvy-tripdata.s3.amazonaws.com/index.html) and has been made available by Motivate International Inc. under this [license](https://www.divvybikes.com/data-license-agreement).
# 3. Drop null values, drop duplicates, changing string date to datetime type, creating new columns to contain distance in kilometers.
# 4. In order to maximize the number of conversion of casual riders to member riders we need to know first how each category of riders behave when using our services. The behaviour of riders that can be seen after processing the data are 'how long riders of each group usually ride?' and 'how far riders of each group usually ride?'. Turns out casual riders tend to ride longer and farther than member riders, so we don't need to look at casual riders who use our service the most but instead to the places where casual riders that behave similary with member riders start their rides the most because one theory that member riders usually start at certain place is maybe because average income of people living around that area is higher than some/many areas hence they area able to become member of Cyclistic. By filtering casual riders' starting stations and compare it with top 10 member riders' most starting stations we are able know that there are 3 stations that are at the top 10 in filtered casual riders' ranking and deserve to have our marketing team attention. Those 3 stations are: Lark St & Elm St, Wells St & Concord Ln, Wells St & Elm St.
# 5. Rather than focusing on casual riders who rides longer/farther, we should instead focus on casual riders who behave similarly with average member riders
# 6. Clark St & Elm St, Wells St & Concord Ln, Wells St & Elm St
